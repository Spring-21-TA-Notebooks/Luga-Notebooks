# %% [markdown]
# ## Lab8 Web Scraping

# %% [markdown]
# Reference: https://www.dataquest.io/blog/web-scraping-python-using-beautiful-soup/

# %% [markdown]
# ### The Components of a Web Page
# Before we start writing code, we need to understand a little bit about the structure of a web page. We'll use the site's structure to write code that gets us the data we want to scrape, so understanding that structure is an important first step for any web scraping project.
# When we visit a web page, our web browser makes a request to a web server. This request is called a GET request, since we’re getting files from the server. The server then sends back files that tell our browser how to render the page for us. These files will typically include:
#
# 1. HTML — the main part of the page.
# 2. CSS — used to add styling to make the page look nicer.
# 3. JS — Javascript files add interactivity to web pages.
# 4. Images — image formats, such as JPG and PNG, allow web pages to show pictures.
#
# After our browser receives all the files, it renders the page and displays it to us.
# There’s a lot that happens behind the scenes to render a page nicely, but we don’t need to worry about most of it when we’re web scraping. When we perform web scraping, we’re interested in the main content of the web page, so we look primarily at the HTML.

# %% [markdown]
# HTML:
#
# HyperText Markup Language (HTML) is the language that web pages are created in. HTML isn’t a programming language, like Python, though. It’s a markup language that tells a browser how to display content.
#
# HTML consists of elements called tags. The most basic tag is the <html> tag. This tag tells the web browser that everything inside of it is HTML. We can make a simple HTML document just using this tag:

# %% [markdown]
# Tags:
#
# p - the children of the body tag
#
# a - add some extra text and hyperlinks
#
# div — indicates a division, or area, of the page.
#
# b — bolds any text inside.
#
# i — italicizes any text inside.
#
# table — creates a table.
#
# form — creates an input form.

# %% [markdown]
# ### Workflow
# 1. Request the content (source code) of a specific URL from the server
# 2. Download the content that is returned
# 3. Observe the page structure & Identify the elements of the page that are part of the table we want
# 4. Extract and (if necessary) reformat those elements into a dataset we can analyze or use in whatever way we require.

# %% [markdown]
# ### Useful tools
# Google developer tool: Chrome - view - developer - developer tool
#
# Double/right click - inspect

# %%
import requests
import bs4
from bs4 import BeautifulSoup
import re

# %%
url = 'https://harris.uchicago.edu/academics/programs-degrees/degrees/master-public-policy-mpp'
page = requests.get(url)

# %%
soup = BeautifulSoup(page.content, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html dir="ltr" lang="en" prefix="content: http://purl.org/rss/1.0/modules/content/  dc: http://purl.org/dc/terms/  foaf: http://xmlns.com/foaf/0.1/  og: http://ogp.me/ns#  rdfs: http://www.w3.org/2000/01/rdf-schema#  schema: http://schema.org/  sioc: http://rdfs.org/sioc/ns#  sioct: http://rdfs.org/sioc/types#  skos: http://www.w3.org/2004/02/skos/core#  xsd: http://www.w3.org/2001/XMLSchema# ">
# <head>
# <!-- Google Tag Manager -->
# <script>(function (w, d, s, l, i) {
#             wl = wl || [];
#             wl.push({'gtm.start': new Date().getTime(), event: 'gtm.js'});
#             var f = d.getElementsByTagName(s)
#             0, j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : '';
#             j.async = true;
#             j.src = 'https://www.googletagmanager.com/gtm.js?id=' + i + dl;
#             f.parentNode.insertBefore(j, f);
#           })(window, document, 'script', 'dataLayer', 'GTM-W7TVBBS');
#         </script>
# <!-- End Google Tag Manager -->
# <meta charset="utf-8"/><script type="text/javascript">(window.NREUM||(NREUM={})).loader_config={licenseKey:"e43e9c38fc",applicationID:"70697360"};window.NREUM||(NREUM={}),__nr_require=function(e,t,n){function r(n){if(!t[n]){var i=t[n]={exports:{}};e[n][0].call(i.exports,function(t){var i=e[n][1][t];return r(i||t)},i,i.exports)}return t[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var i=0;i<n.length;i++)r(n[i]);return r}({1:[function(e,t,n){function r(){}function i(e,t,n){return function(){return o(e,[u.now()].concat(c(arguments)),t?null:this,n),t?void 0:this}}var o=e("handle"),a=e(7),c=e(8),f=e("ee").get("tracer"),u=e("loader"),s=NREUM;"undefined"==typeof window.newrelic&&(newrelic=s);var d=["setPageViewName","setCustomAttribute","setErrorHandler","finished","addToTrace","inlineHit","addRelease"],p="api-",l=p+"ixn-";a(d,function(e,t){s[t]=i(p+t,!0,"api")}),s.addPageAction=i(p+"addPageAction",!0),s.setCurrentRouteName=i(p+"routeName",!0),t.exports=newrelic,s.interaction=function(){return(new r).get()};var m=r.prototype={createTracer:function(e,t){var n={},r=this,i="function"==typeof t;return o(l+"tracer",[u.now(),e,n],r),function(){if(f.emit((i?"":"no-")+"fn-start",[u.now(),r,i],n),i)try{return t.apply(this,arguments)}catch(e){throw f.emit("fn-err",[arguments,this,e],n),e}finally{f.emit("fn-end",[u.now()],n)}}}};a("actionText,setName,setAttribute,save,ignore,onEnd,getContext,end,get".split(","),function(e,t){m[t]=i(l+t)}),newrelic.noticeError=function(e,t){"string"==typeof e&&(e=new Error(e)),o("err",[e,u.now(),!1,t])}},{}],2:[function(e,t,n){function r(){return c.exists&&performance.now?Math.round(performance.now()):(o=Math.max((new Date).getTime(),o))-a}function i(){return o}var o=(new Date).getTime(),a=o,c=e(9);t.exports=r,t.exports.offset=a,t.exports.getLastTimestamp=i},{}],3:[function(e,t,n){function r(e){return!(!e||!e.protocol||"file:"===e.protocol)}t.exports=r},{}],4:[function(e,t,n){function r(e,t){var n=e.getEntries();n.forEach(function(e){"first-paint"===e.name?d("timing",["fp",Math.floor(e.startTime)]):"first-contentful-paint"===e.name&&d("timing",["fcp",Math.floor(e.startTime)])})}function i(e,t){var n=e.getEntries();n.length>0&&d("lcp",[n[n.length-1]])}function o(e){e.getEntries().forEach(function(e){e.hadRecentInput||d("cls",[e])})}function a(e){if(e instanceof m&&!g){var t=Math.round(e.timeStamp),n={type:e.type};t<=p.now()?n.fid=p.now()-t:t>p.offset&&t<=Date.now()?(t-=p.offset,n.fid=p.now()-t):t=p.now(),g=!0,d("timing",["fi",t,n])}}function c(e){d("pageHide",[p.now(),e])}if(!("init"in NREUM&&"page_view_timing"in NREUM.init&&"enabled"in NREUM.init.page_view_timing&&NREUM.init.page_view_timing.enabled===!1)){var f,u,s,d=e("handle"),p=e("loader"),l=e(6),m=NREUM.o.EV;if("PerformanceObserver"in window&&"function"==typeof window.PerformanceObserver){f=new PerformanceObserver(r);try{f.observe({entryTypes:["paint"]})}catch(v){}u=new PerformanceObserver(i);try{u.observe({entryTypes:["largest-contentful-paint"]})}catch(v){}s=new PerformanceObserver(o);try{s.observe({type:"layout-shift",buffered:!0})}catch(v){}}if("addEventListener"in document){var g=!1,w=["click","keydown","mousedown","pointerdown","touchstart"];w.forEach(function(e){document.addEventListener(e,a,!1)})}l(c)}},{}],5:[function(e,t,n){function r(e,t){if(!i)return!1;if(e!==i)return!1;if(!t)return!0;if(!o)return!1;for(var n=o.split("."),r=t.split("."),a=0;a<r.length;a++)if(r[a]!==n[a])return!1;return!0}var i=null,o=null,a=/Version\/(\S+)\s+Safari/;if(navigator.userAgent){var c=navigator.userAgent,f=c.match(a);f&&c.indexOf("Chrome")===-1&&c.indexOf("Chromium")===-1&&(i="Safari",o=f[1])}t.exports={agent:i,version:o,match:r}},{}],6:[function(e,t,n){function r(e){function t(){e(a&&document[a]?document[a]:document[i]?"hidden":"visible")}"addEventListener"in document&&o&&document.addEventListener(o,t,!1)}t.exports=r;var i,o,a;"undefined"!=typeof document.hidden?(i="hidden",o="visibilitychange",a="visibilityState"):"undefined"!=typeof documen ...
# <script>window.google_analytics_domain_name = "none";window.google_analytics_uacct = "UA-32628807-2";(function(i,s,o,g,r,a,m){i["GoogleAnalyticsObject"]=r;i[r]=i[r]||function(){(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)})(window,document,"script","https://www.google-analytics.com/analytics.js","ga");ga("create", "UA-32628807-2", {"cookieDomain":"auto","allowLinker":true});ga("require", "linker");ga("linker:autoLink", ["harris.uchicago.edu, apply-harris.uchicago.edu"]);ga("set", "anonymizeIp", true);ga("send", "pageview");</script>
# <meta content="Across the public and private sectors, a new generation of data-minded leaders is needed to bring fresh thinking and different approaches to the world's most pressing policy challenges." name="description"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=3.0, user-scalable=yes" name="viewport"/>
# <meta content="Drupal 8 (https://www.drupal.org)" name="Generator"/>
# <meta content="width" name="MobileOptimized"/>
# <meta content="true" name="HandheldFriendly"/>
# <link href="/themes/custom/harris_theme/favicon.ico" rel="shortcut icon" type="image/vnd.microsoft.icon"/>
# <link href="https://harris.uchicago.edu/academics/degrees/master-public-policy-mpp" rel="canonical"/>
# <link href="https://harris.uchicago.edu/node/7501" rel="shortlink"/>
# <link href="https://harris.uchicago.edu/academics/degrees/master-public-policy-mpp" rel="revision"/>
# <script defer="" src="/files/google_tag/primary/google_tag.script.js?qsquwr"></script>
# <script>window.a2a_config=window.a2a_config||{};a2a_config.callbacks=[];a2a_config.overlays=[];a2a_config.templates={};</script>
# <title>Master of Public Policy (MPP) | The University of Chicago Harris School of Public Policy</title>
# <link href="/core/assets/vendor/normalize-css/normalize.css?qsquwr" media="all" rel="stylesheet"/>
# <link href="/core/misc/normalize-fixes.css?qsquwr" media="all" rel="stylesheet"/>
# <link href="/libraries/superfish/css/superfish.css?qsquwr" media="all" rel="stylesheet"/>
# <link href="/core/themes/stable/css/system/components/ajax-progress.module.css?qsquwr" media="all" rel="stylesheet"/>
# <link href="/core/themes/stable/css/system/components/align.module.css?qsquwr" media="all" rel="stylesheet"/>
# <link href="/core/themes/stable/css/system/components/autocomplete-loading.module.css?qsquwr" media="all" rel="stylesheet"/>
# <link href="/core/themes/stable/css/system/components/fieldgroup.module.css?qsquwr" media="all" rel="stylesheet"/>
# <link href="/core/themes/stable/css/system/components/container-inline.module.css?qsquwr" media="all" rel="stylesheet"/>
# <link href="/core/themes/stable/css/system/components/clearfix.module.css?qsquwr" media="all" rel="stylesheet"/>
# <link href="/core/themes/stable/css/system/components/details.module.css?qsquwr" media="all" rel="stylesheet"/>
# <link href="/core/themes/stable/css/system/components/hidden.module.css?qsquwr" media="all" rel="stylesheet"/>
# <link href="/core/themes/stable/css/system/components/item-list.module.css?qsquwr" media="all" rel="stylesheet"/>
# <link href="/core/themes/stable/css/system/components/js.module.css?qsquwr" media="all" rel="stylesheet"/>
# <link href="/core/themes/stable/css/system/components/nowrap.module.css?qsquwr" media="all" rel="stylesheet"/>
# <link href="/core/themes/stable/css/system/components/position-container.module.css?qsquwr" media="all" rel="stylesheet"/>
# <link href="/core/themes/stable/css/system/components/progress.module.css?qsquwr" media="all" rel="stylesheet"/>
# <link href="/core/themes/stable/css/system/components/reset-appearance.module.css?qsquwr" media="all" rel="stylesheet"/>
# <link href="/core/themes/stable/css/system/components/resize.module.css?qsquwr" media="all" rel="stylesheet"/>
# <link href="/core/themes/stable/css/system/components/sticky-header.module.css?qsquwr" media="all" rel="stylesheet"/>
# <link href="/core/themes/stable/css/system/components/system-status-counter.css?qsquwr" media="all" rel="stylesheet"/>
# <link href="/core/themes/stable/css/system/components/system-status-report-counters.css?qsquwr" media="all" rel="stylesheet"/>
# <link href="/core/themes/stable/css/system/components/system-status-report-general-info.css?qsquwr" media="all" rel="stylesheet"/>
# <link href="/core/themes/stable/css/system/components/tabledrag.module.css?qsquwr" media="all" rel="stylesheet"/>
# <link href="/core/themes/stable/css/system/components/tablesort.module.css?qsquwr" media="all" rel="stylesheet"/>
# <link href="/core/themes/stable/css/system/components/tree-child.module.css?qsquwr" media="all" rel="stylesheet"/>
# <link href="/core/assets/vendor/jquery.ui/themes/base/core.css?qsquwr" media="all" rel="stylesheet"/>
# <link href="/core/assets/vendor/jquery.ui/themes/base/tabs.css?qsquwr" media="all" rel="stylesheet"/>
# <link href="/core/themes/stable/css/views/views.module.css?qsquwr" media="all" rel="stylesheet"/>
# <link href="/modules/contrib/addtoany/css/addtoany.css?qsquwr" media="all" rel="stylesheet"/>
# <link href="/core/assets/vendor/jquery.ui/themes/base/theme.css?qsquwr" media="all" rel="stylesheet"/>
# <link href="/modules/contrib/paragraphs/css/paragraphs.unpublished.css?qsquwr" media="all" rel="stylesheet"/>
# <link href="/modules/contrib/better_exposed_filters/css/better_exposed_filters.css?qsquwr" media="all" rel="stylesheet"/>
# <link href="/core/themes/classy/css/components/action-links.css?qsquwr" media="all" rel="stylesheet"/>
# <link href="/core/themes/classy/css/components/breadcrumb.css?qsquwr" media="all" rel="stylesheet"/>
# <link href="/core/themes/classy/css/components/button.css?qsquwr" media="all" rel="stylesheet"/>
# <link href="/core/themes/classy/css/components/collapse-processed.css?qsquwr" media="all" rel="stylesheet"/>
# <link href="/core/themes/classy/css/components/container-inline.css?qsquwr" media="all" rel="stylesheet"/>
# <link href="/core/themes/classy/css/components/details.css?qsquwr" media="all" rel="stylesheet"/>
# <link href="/core/themes/classy/css/components/exposed-filters.css?qsquwr" media="all" rel="stylesheet"/>
# <link href="/core/themes/classy/css/components/field.css?qsquwr" media="all" rel="stylesheet"/>
# <link href="/core/themes/classy/css/components/form.css?qsquwr" media="all" rel="stylesheet"/>
# <link href="/core/themes/classy/css/components/icons.css?qsquwr" media="all" rel="stylesheet"/>
# <link href="/core/themes/classy/css/components/inline-form.css?qsquwr" media="all" rel="stylesheet"/>
# <link href="/core/themes/classy/css/components/item-list.css?qsquwr" media="all" rel="stylesheet"/>
# <link href="/core/themes/classy/css/components/link.css?qsquwr" media="all" rel="stylesheet"/>
# <link href="/core/themes/classy/css/components/links.css?qsquwr" media="all" rel="stylesheet"/>
# <link href="/core/themes/classy/css/components/menu.css?qsquwr" media="all" rel="stylesheet"/>
# <link href="/core/themes/classy/css/components/more-link.css?qsquwr" media="all" rel="stylesheet"/>
# <link href="/core/themes/classy/css/components/pager.css?qsquwr" media="all" rel="stylesheet"/>
# <link href="/core/themes/classy/css/components/tabledrag.css?qsquwr" media="all" rel="stylesheet"/>
# <link href="/core/themes/classy/css/components/tableselect.css?qsquwr" media="all" rel="stylesheet"/>
# <link href="/core/themes/classy/css/components/tablesort.css?qsquwr" media="all" rel="stylesheet"/>
# <link href="/core/themes/classy/css/components/tabs.css?qsquwr" media="all" rel="stylesheet"/>
# <link href="/core/themes/classy/css/components/textarea.css?qsquwr" media="all" rel="stylesheet"/>
# <link href="/core/themes/classy/css/components/ui-dialog.css?qsquwr" media="all" rel="stylesheet"/>
# <link href="/core/themes/classy/css/components/messages.css?qsquwr" media="all" rel="stylesheet"/>
# <link href="/core/themes/classy/css/components/progress.css?qsquwr" media="all" rel="stylesheet"/>
# <link href="/core/themes/classy/css/components/node.css?qsquwr" media="all" rel="stylesheet"/>
# <link href="/core/themes/classy/css/components/file.css?qsquwr" media="all" rel="stylesheet"/>
# <link href="/themes/custom/harris_theme/css/styles.css?qsquwr" media="all" rel="stylesheet"/>
# <link href="https://cloud.typography.com/6178934/6584352/css/fonts.css" media="all" rel="stylesheet"/>
# <!--[if lte IE 8]>
# <script src="/core/assets/vendor/html5shiv/html5shiv.min.js?v=3.7.3"></script>
# <![endif]-->
# </head>
# <body class="path-node page-node-type-program node--landing-page--secondary">
# <!-- Google Tag Manager (noscript) -->
# <noscript>
# <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-W7TVBBS" style="display:none;visibility:hidden" width="0"></iframe>
# </noscript>
# <!-- End Google Tag Manager (noscript) -->
# <a class="visually-hidden focusable skip-link" href="#main-content">
#   Skip to main content
# </a>
# <noscript aria-hidden="true"><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-W7TVBBS" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <div class="dialog-off-canvas-main-canvas" data-off-canvas-main-canvas="">
# <header class="header" xmlns="http://www.w3.org/1999/html">
# <div class="utility-navigation__wrap desktop-only">
# <div class="utility-menu">
# <div class="container">
# <nav aria-label="Utility" class="block block-menu navigation menu--utility" role="navigation">
# <h2 class="visually-hidden">Utility</h2>
# <ul class="utility-navigation">
# <li class="search-link utility-navigation__item">
# <a class="utility-navigation__item-link" data-drupal-link-system-path="search" href="/search">Search</a>
# </li>
# <li class="utility-navigation__item">
# <a class="utility-navigation__item-link" data-drupal-link-system-path="user/login" href="/user/login">Log in</a>
# </li>
# <li class="utility-navigation__item">
# <a class="utility-navigation__item-link" data-drupal-link-system-path="directory" href="/directory">Directory</a>
# </li>
# <li class="utility-navigation__item">
# <a accesskey="" class="utility-navigation__item-link" data-drupal-link-system-path="node/3101" href="/hireharris" id="" name="" rel="" style="" target="" title="">Hire Harris</a>
# <div class="utility-navigation__child-container">
# <ul class="utility-navigation__children">
# <li class="utility-navigation__child-item">
# <a accesskey="" data-drupal-link-system-path="node/3081" href="/findtalent" id="" name="" rel="" style="" target="" title="">Find Talent</a>
# </li>
# <li class="utility-navigation__child-item">
# <a accesskey="" data-drupal-link-system-path="node/3051" href="/student-life/career-development" id="" name="" rel="" style="" target="" title="">Find Work</a>
# </li>
# </ul>
# </div></li>
# <li class="utility-navigation__item">
# <a accesskey="" class="utility-navigation__item-link" href="" id="" name="" rel="" style="" target="" title="">Info For</a>
# <div class="utility-navigation__child-container">
# <ul class="utility-navigation__children">
# <li class="utility-navigation__child-item">
# <a accesskey="" data-drupal-link-system-path="node/2881" href="/admissions" id="" name="" rel="" style="" target="" title="">Prospective Students</a>
# </li>
# <li class="utility-navigation__child-item">
# <a accesskey="" data-drupal-link-system-path="node/9871" href="/admitted-students" id="" name="" rel="" style="" target="" title="">Admitted Students (Full-Time)</a>
# </li>
# <li class="utility-navigation__child-item">
# <a accesskey="" data-drupal-link-system-path="node/13076" href="/eveningprogram/admitted-students" id="" name="" rel="" style="" target="" title="">New EMP Students</a>
# </li>
# <li class="utility-navigation__child-item">
# <a accesskey="" data-drupal-link-system-path="node/2966" href="/gateways/current-students" id="" name="" rel="" style="" target="" title="">Current Students</a>
# </li>
# <li class="utility-navigation__child-item">
# <a accesskey="" data-drupal-link-system-path="node/2976" href="/gateways/faculty-staff" id="" name="" rel="" style="" target="" title="">Faculty and Staff</a>
# </li>
# <li class="utility-navigation__child-item">
# <a accesskey="" data-drupal-link-system-path="node/2971" href="/alumni" id="" name="" rel="" style="" target="" title="">Alumni</a>
# </li>
# <li class="utility-navigation__child-item">
# <a accesskey="" data-drupal-link-system-path="node/6571" href="/media" id="" name="" rel="" style="" target="" title="Resources for Media">Media</a>
# </li>
# </ul>
# </div></li>
# <li class="support-link utility-navigation__item">
# <a accesskey="" class="utility-navigation__item-link" data-drupal-link-system-path="node/3106" href="/support-harris" id="" name="" rel="" style="" target="" title="">Support Harris</a>
# <div class="utility-navigation__child-container">
# <ul class="utility-navigation__children">
# <li class="utility-navigation__child-item">
# <a data-drupal-link-system-path="node/3091" href="/support-harris/ways-to-give">Ways to Give</a>
# </li>
# <li class="utility-navigation__child-item">
# <a data-drupal-link-system-path="node/29876" href="/support-harris/harris-society">Harris Society</a>
# </li>
# </ul>
# </div></li>
# </ul>
# </nav>
# </div>
# </div>
# <div class="search-block"> <div class="views-exposed-form bef-exposed-form block block-views block-views-exposed-filter-blocksearch-content-search-content-page" data-drupal-selector="views-exposed-form-search-content-search-content-page" id="block-exposedformsearch-contentsearch-content-page-2">
# <form accept-charset="UTF-8" action="/search" id="views-exposed-form-search-content-search-content-page" method="get">
# <div class="filters clearfix">
# <div class="js-form-item form-item js-form-type-textfield form-type-textfield js-form-item-keys form-item-keys">
# <input class="form-text" data-drupal-selector="edit-keys" id="edit-keys" maxlength="128" name="keys" placeholder="Search" size="30" type="text" value=""/>
# </div>
# <fieldset class="fieldgroup form-composite js-form-item js-form-wrapper form-wrapper" data-drupal-selector="edit-sort-bef-combine" id="edit-sort-bef-combine--wrapper">
# <legend>
# <span class="fieldset-legend">Sort</span>
# <span class="chevron bottom">
# <a href="#"></a>
# </span>
# </legend>
# <div class="fieldset-wrapper">
# <div class="form-radios" id="edit-sort-bef-combine"><div class="form-radios">
# <div class="js-form-item form-item js-form-type-radio form-type-radio js-form-item-sort-bef-combine form-item-sort-bef-combine">
# <input class="form-radio" data-drupal-selector="edit-sort-bef-combine-created-asc" id="edit-sort-bef-combine-created-asc" name="sort_bef_combine" type="radio" value="created_ASC"/>
# <label class="option" for="edit-sort-bef-combine-created-asc">Older first</label>
# </div>
# <div class="js-form-item form-item js-form-type-radio form-type-radio js-form-item-sort-bef-combine form-item-sort-bef-combine">
# <input class="form-radio" data-drupal-selector="edit-sort-bef-combine-created-desc" id="edit-sort-bef-combine-created-desc" name="sort_bef_combine" type="radio" value="created_DESC"/>
# <label class="option" for="edit-sort-bef-combine-created-desc">Most recent</label>
# </div>
# <div class="js-form-item form-item js-form-type-radio form-type-radio js-form-item-sort-bef-combine form-item-sort-bef-combine">
# <input class="form-radio" data-drupal-selector="edit-sort-bef-combine-search-api-relevance-asc" id="edit-sort-bef-combine-search-api-relevance-asc" name="sort_bef_combine" type="radio" value="search_api_relevance_ASC"/>
# <label class="option" for="edit-sort-bef-combine-search-api-relevance-asc">Less relevant</label>
# </div>
# <div class="js-form-item form-item js-form-type-radio form-type-radio js-form-item-sort-bef-combine form-item-sort-bef-combine">
# <input checked="checked" class="form-radio" data-drupal-selector="edit-sort-bef-combine-search-api-relevance-desc" id="edit-sort-bef-combine-search-api-relevance-desc" name="sort_bef_combine" type="radio" value="search_api_relevance_DESC"/>
# <label class="option" for="edit-sort-bef-combine-search-api-relevance-desc">Most relevant</label>
# </div>
# </div>
# </div>
# </div>
# </fieldset>
# <div class="form-actions js-form-wrapper form-wrapper" data-drupal-selector="edit-actions" id="edit-actions"><input class="button--primary button js-form-submit form-submit" data-drupal-selector="edit-submit-search-content" id="edit-submit-search-content" type="submit" value="Search"/>
# </div>
# </div>
# </form>
# </div>
# </div>
# </div>
# <div class="container">
# <a class="brand" href="/">
# <div class="brand__logo">
# <svg height="87" viewbox="0 0 180 87" width="180" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><title>Page 1</title><defs><path d="M0 86.912h179.528V.847H0z" id="a"></path></defs><g fill="none" fill-rule="evenodd"><path d="M17.963 41.241h2.874v5.213h5.3V41.24h2.873v13.172h-2.874v-5.287h-5.3v5.287h-2.873z" fill="#000"></path><g transform="translate(0 .005)"><path d="M37.24 50.851v-.508a4.367 4.367 0 0 0-1.811-.376c-1.214 0-1.96.489-1.96 1.392v.037c0 .772.635 1.224 1.55 1.224 1.324 0 2.22-.734 2.22-1.769zm-6.514.659v-.038c0-2.201 1.66-3.218 4.031-3.218a7.04 7.04 0 0 1 2.445.415v-.17c0-1.185-.728-1.843-2.147-1.843-1.082 0-1.847.207-2.761.545l-.71-2.182c1.102-.49 2.184-.81 3.882-.81 1.55 0 2.669.414 3.378 1.13.746.752 1.082 1.862 1.082 3.217v5.852h-2.743v-1.092c-.69.771-1.642 1.28-3.023 1.28-1.885 0-3.434-1.092-3.434-3.086zm11.122-7.188h2.836v2.032c.58-1.392 1.512-2.295 3.192-2.22v2.991h-.15c-1.885 0-3.042 1.148-3.042 3.557v3.725h-2.836V44.322zm7.278 0h2.836v2.032c.579-1.392 1.512-2.295 3.192-2.22v2.991h-.15c-1.884 0-3.042 1.148-3.042 3.557v3.725h-2.836V44.322z" fill="#000"></path><mask fill="#fff" id="b"><use xlink:href="#a"></use></mask><path d="M56.534 54.407h2.837V44.322h-2.837v10.085zM56.46 43.21h2.986v-2.54H56.46v2.54zm4.273 9.861l1.212-1.881c1.083.79 2.221 1.204 3.154 1.204.821 0 1.194-.3 1.194-.752v-.038c0-.621-.97-.828-2.07-1.166-1.4-.415-2.987-1.073-2.987-3.03v-.038c0-2.05 1.642-3.199 3.658-3.199 1.269 0 2.65.433 3.732 1.167l-1.082 1.976c-.989-.584-1.978-.94-2.706-.94-.691 0-1.045.3-1.045.695v.038c0 .564.951.828 2.034 1.204 1.4.47 3.023 1.148 3.023 2.991v.039c0 2.238-1.66 3.255-3.825 3.255a6.97 6.97 0 0 1-4.292-1.525m17.813-4.666c2.165 0 3.583-1.166 3.583-2.898v-.037c0-1.882-1.4-2.86-3.509-2.86h-3.303v5.795h3.229zm-4.702-7.168h4.888c2.949 0 4.89 1.58 4.89 4.177v.037c0 2.84-2.352 4.309-5.132 4.309h-3.173v4.647h-1.473v-13.17zm11.513 9.483v-6.04h1.437v5.682c0 1.807.97 2.935 2.668 2.935 1.642 0 2.893-1.223 2.893-3.048v-5.57h1.419v9.728h-1.419v-1.693c-.653 1.054-1.642 1.9-3.303 1.9-2.333 0-3.695-1.58-3.695-3.895m19.258-1.147v-.038c0-2.295-1.568-3.764-3.397-3.764-1.791 0-3.489 1.525-3.489 3.745v.038c0 2.258 1.698 3.763 3.49 3.763 1.865 0 3.396-1.393 3.396-3.744m-6.83 2.972v1.863h-1.438V40.672h1.438v5.964c.783-1.166 1.922-2.163 3.695-2.163 2.314 0 4.61 1.844 4.61 5.042v.038c0 3.18-2.278 5.061-4.61 5.061-1.792 0-2.949-.978-3.695-2.07m10.43 1.863h1.438V40.67h-1.438zm4.255.001h1.437v-9.729h-1.437v9.729zm-.093-11.855h1.642v-1.599h-1.642v1.6zm3.62 7.037v-.037c0-2.747 2.127-5.08 4.945-5.08 1.829 0 2.967.771 3.863 1.73l-.953 1.016c-.764-.808-1.622-1.467-2.93-1.467-1.958 0-3.45 1.675-3.45 3.764v.037c0 2.107 1.529 3.782 3.544 3.782 1.232 0 2.183-.62 2.949-1.449l.914.866c-.97 1.091-2.127 1.881-3.937 1.881-2.818 0-4.945-2.314-4.945-5.042m17.195-1.186c2.165 0 3.583-1.166 3.583-2.898v-.037c0-1.882-1.4-2.86-3.508-2.86h-3.304v5.795h3.23zm-4.703-7.168h4.89c2.948 0 4.889 1.58 4.889 4.177v.037c0 2.84-2.351 4.309-5.132 4.309h-3.173v4.647h-1.474v-13.17zm19.464 8.353v-.037c0-2.088-1.549-3.801-3.583-3.801-2.09 0-3.527 1.713-3.527 3.764v.037c0 2.088 1.53 3.782 3.564 3.782 2.09 0 3.546-1.694 3.546-3.744m-8.584 0v-.038c0-2.747 2.127-5.08 5.038-5.08 2.893 0 5.02 2.295 5.02 5.043v.037c0 2.747-2.146 5.08-5.057 5.08-2.893 0-5.001-2.295-5.001-5.042m12.129 4.816h1.438V40.67h-1.438zm4.254.001h1.437v-9.729h-1.437v9.729zm-.093-11.855h1.643v-1.599h-1.643v1.6zm3.621 7.037v-.037c0-2.747 2.126-5.08 4.944-5.08 1.83 0 2.968.771 3.863 1.73l-.952 1.016c-.765-.808-1.623-1.467-2.93-1.467-1.959 0-3.451 1.675-3.451 3.764v.037c0 2.107 1.53 3.782 3.545 3.782 1.231 0 2.183-.62 2.948-1.449l.915.866c-.97 1.091-2.128 1.881-3.938 1.881-2.818 0-4.945-2.314-4.945-5.042m10.443 7.394l.485-1.148c.468.245.897.357 1.512.357.859 0 1.4-.45 1.978-1.824l-4.385-9.69h1.587l3.507 8.11 3.099-8.11h1.53l-4.05 10.047c-.821 2.014-1.754 2.747-3.21 2.747-.802 0-1.4-.17-2.053-.489" fill="#000" mask="url(#b)"></path><path d="M58.011 74.59l3.26 7.984a42.732 42.732 0 0 0  ...
# <img alt="The University of Chicago Harris School of Public Policy" class="affixed-logo-img" src=""/>
# <h1 class="element-invisible">The University of Chicago Harris School of Public Policy</h1>
# </div>
# </a>
# <span class="menu-button"></span>
# <div class="main-navigation__wrap">
# <div class="block block-superfish block-superfishmain" id="block-mainnavigation">
# <ul class="menu sf-menu sf-main sf-horizontal sf-style-none" id="superfish-main">
# <li class="sf-depth-1 menuparent" id="main-menu-link-contentd54c2690-c3cf-4a5b-8f38-81a8e84dcc94"><a accesskey="" class="sf-depth-1 menuparent" href="/about" id="" name="" rel="" style="" target="" title="">About</a><div class="main-navigation__cta"><div class="main-navigation__cta-container"><h3 class="main-navigation__cta-title">Considering Applying?</h3><p class="main-navigation__cta-statement">Get a jump start now by creating an account with our simple online tool.</p><div class="cta-wrapper"><div class="button"><a href="https://apply-harris.uchicago.edu/apply/">Get Started</a></div></div><p class="main-navigation__cta-note">Still have questions? Check out <a class="main-navigation__cta-note-link" href="/admissions">Admissions</a> for details on requirements, deadlines, and financial aid.</p></div></div><ul><li class="sf-depth-2 menuparent" id="main-menu-link-content020983d0-3324-423d-a28b-d16ee42b2240"><a accesskey="" class="sf-depth-2 menuparent" href="/about/who-we-are" id="" name="" rel="" style="" target="" title="">Who We Are</a><div class="main-navigation__cta"><div class="main-navigation__cta-container"><h3 class="main-navigation__cta-title">Considering Applying?</h3><p class="main-navigation__cta-statement">Get a jump start now by creating an account with our simple online tool.</p><div class="cta-wrapper"><div class="button"><a href="https://apply-harris.uchicago.edu/apply/">Get Started</a></div></div><p class="main-navigation__cta-note">Still have questions? Check out <a class="main-navigation__cta-note-link" href="/admissions">Admissions</a> for details on requirements, deadlines, and financial aid.</p></div></div><ul><li class="sf-depth-3 sf-no-children" id="main-menu-link-contentd7fcffa7-cc90-4e63-a5e9-7c8ad175c323"><a class="sf-depth-3" href="/about/who-we-are/our-principles">Our Principles</a></li><li class="sf-depth-3 sf-no-children" id="main-menu-link-content6fe2ae85-c72b-476b-9ef3-63de056fdf8e"><a accesskey="" class="sf-depth-3" href="/about/who-we-are/harris-by-the-numbers" id="" name="" rel="" style="" target="" title="">Harris By The Numbers</a></li><li class="sf-depth-3 sf-no-children" id="main-menu-link-content7526ceb4-191d-47b5-95b1-ae7c36a3364b"><a accesskey="" class="sf-depth-3" href="/about/who-we-are/career-outcomes-report" id="" name="" rel="" style="" target="" title="">Career Outcomes Report</a></li></ul></li><li class="sf-depth-2 menuparent" id="main-menu-link-content0b811255-7ed0-49a9-8339-e0d8ea36ae4f"><a accesskey="" class="sf-depth-2 menuparent" href="/about/keller-center" id="" name="" rel="" style="" target="" title="">The Keller Center</a><div class="main-navigation__cta"><div class="main-navigation__cta-container"><h3 class="main-navigation__cta-title">Considering Applying?</h3><p class="main-navigation__cta-statement">Get a jump start now by creating an account with our simple online tool.</p><div class="cta-wrapper"><div class="button"><a href="https://apply-harris.uchicago.edu/apply/">Get Started</a></div></div><p class="main-navigation__cta-note">Still have questions? Check out <a class="main-navigation__cta-note-link" href="/admissions">Admissions</a> for details on requirements, deadlines, and financial aid.</p></div></div><ul><li class="sf-depth-3 sf-no-children" id="main-menu-link-content97f43b74-9db2-4b2d-8a09-3d12d2019919"><a class="sf-depth-3" href="/about/keller-center/the-future-of-policy">The Future of Policy</a></li><li class="sf-depth-3 sf-no-children" id="main-menu-link-content1b53dafc-5868-4154-8979-97e6def36033"><a class="sf-depth-3" href="/about/keller-center/your-impact">Your Impact</a></li><li class="sf-depth-3 sf-no-children" id="main-menu-link-contentfa8c1d08-edd5-4785-8df7-ce9702563d4c"><a class="sf-depth-3" href="/about/keller-center/design-sustainability">Design &amp; Sustainability</a></li><li class="sf-depth-3 sf-no-children" id="main-menu-link-content3802b80b-703b-4762-b02d-4f33ac8e7884"><a accesskey="" class="sf-depth-3" href="/about/keller-center/pres ...
# </ul>
# </div>
# <div class="utility-navigation__wrap mobile-only">
# <div class="utility-menu">
# <div class="container">
# <nav aria-label="Utility" class="block block-menu navigation menu--utility" role="navigation">
# <h2 class="visually-hidden">Utility</h2>
# <ul class="utility-navigation">
# <li class="search-link utility-navigation__item">
# <a class="utility-navigation__item-link" data-drupal-link-system-path="search" href="/search">Search</a>
# </li>
# <li class="utility-navigation__item">
# <a class="utility-navigation__item-link" data-drupal-link-system-path="user/login" href="/user/login">Log in</a>
# </li>
# <li class="utility-navigation__item">
# <a class="utility-navigation__item-link" data-drupal-link-system-path="directory" href="/directory">Directory</a>
# </li>
# <li class="utility-navigation__item">
# <a accesskey="" class="utility-navigation__item-link" data-drupal-link-system-path="node/3101" href="/hireharris" id="" name="" rel="" style="" target="" title="">Hire Harris</a>
# <div class="utility-navigation__child-container">
# <ul class="utility-navigation__children">
# <li class="utility-navigation__child-item">
# <a accesskey="" data-drupal-link-system-path="node/3081" href="/findtalent" id="" name="" rel="" style="" target="" title="">Find Talent</a>
# </li>
# <li class="utility-navigation__child-item">
# <a accesskey="" data-drupal-link-system-path="node/3051" href="/student-life/career-development" id="" name="" rel="" style="" target="" title="">Find Work</a>
# </li>
# </ul>
# </div></li>
# <li class="utility-navigation__item">
# <a accesskey="" class="utility-navigation__item-link" href="" id="" name="" rel="" style="" target="" title="">Info For</a>
# <div class="utility-navigation__child-container">
# <ul class="utility-navigation__children">
# <li class="utility-navigation__child-item">
# <a accesskey="" data-drupal-link-system-path="node/2881" href="/admissions" id="" name="" rel="" style="" target="" title="">Prospective Students</a>
# </li>
# <li class="utility-navigation__child-item">
# <a accesskey="" data-drupal-link-system-path="node/9871" href="/admitted-students" id="" name="" rel="" style="" target="" title="">Admitted Students (Full-Time)</a>
# </li>
# <li class="utility-navigation__child-item">
# <a accesskey="" data-drupal-link-system-path="node/13076" href="/eveningprogram/admitted-students" id="" name="" rel="" style="" target="" title="">New EMP Students</a>
# </li>
# <li class="utility-navigation__child-item">
# <a accesskey="" data-drupal-link-system-path="node/2966" href="/gateways/current-students" id="" name="" rel="" style="" target="" title="">Current Students</a>
# </li>
# <li class="utility-navigation__child-item">
# <a accesskey="" data-drupal-link-system-path="node/2976" href="/gateways/faculty-staff" id="" name="" rel="" style="" target="" title="">Faculty and Staff</a>
# </li>
# <li class="utility-navigation__child-item">
# <a accesskey="" data-drupal-link-system-path="node/2971" href="/alumni" id="" name="" rel="" style="" target="" title="">Alumni</a>
# </li>
# <li class="utility-navigation__child-item">
# <a accesskey="" data-drupal-link-system-path="node/6571" href="/media" id="" name="" rel="" style="" target="" title="Resources for Media">Media</a>
# </li>
# </ul>
# </div></li>
# <li class="support-link utility-navigation__item">
# <a accesskey="" class="utility-navigation__item-link" data-drupal-link-system-path="node/3106" href="/support-harris" id="" name="" rel="" style="" target="" title="">Support Harris</a>
# <div class="utility-navigation__child-container">
# <ul class="utility-navigation__children">
# <li class="utility-navigation__child-item">
# <a data-drupal-link-system-path="node/3091" href="/support-harris/ways-to-give">Ways to Give</a>
# </li>
# <li class="utility-navigation__child-item">
# <a data-drupal-link-system-path="node/29876" href="/support-harris/harris-society">Harris Society</a>
# </li>
# </ul>
# </div></li>
# </ul>
# </nav>
# </div>
# </div>
# <div class="search-block"> <div class="views-exposed-form bef-exposed-form block block-views block-views-exposed-filter-blocksearch-content-search-content-page-1" data-drupal-selector="views-exposed-form-search-content-search-content-page-1" id="block-exposedformsearch-contentsearch-content-page-1">
# <form accept-charset="UTF-8" action="/search" id="views-exposed-form-search-content-search-content-page-1" method="get">
# <div class="filters clearfix">
# <div class="js-form-item form-item js-form-type-textfield form-type-textfield js-form-item-keys2 form-item-keys2">
# <input class="form-text" data-drupal-selector="edit-keys2" id="edit-keys2" maxlength="128" name="keys2" placeholder="Search" size="30" type="text" value=""/>
# </div>
# <fieldset class="fieldgroup form-composite js-form-item js-form-wrapper form-wrapper" data-drupal-selector="edit-sort-bef-combine" id="edit-sort-bef-combine--2--wrapper">
# <legend>
# <span class="fieldset-legend">Sort</span>
# <span class="chevron bottom">
# <a href="#"></a>
# </span>
# </legend>
# <div class="fieldset-wrapper">
# <div class="form-radios" id="edit-sort-bef-combine--2"><div class="form-radios">
# <div class="js-form-item form-item js-form-type-radio form-type-radio js-form-item-sort-bef-combine form-item-sort-bef-combine">
# <input class="form-radio" data-drupal-selector="edit-sort-bef-combine-created-asc-2" id="edit-sort-bef-combine-created-asc--2" name="sort_bef_combine" type="radio" value="created_ASC"/>
# <label class="option" for="edit-sort-bef-combine-created-asc--2">Older first</label>
# </div>
# <div class="js-form-item form-item js-form-type-radio form-type-radio js-form-item-sort-bef-combine form-item-sort-bef-combine">
# <input class="form-radio" data-drupal-selector="edit-sort-bef-combine-created-desc-2" id="edit-sort-bef-combine-created-desc--2" name="sort_bef_combine" type="radio" value="created_DESC"/>
# <label class="option" for="edit-sort-bef-combine-created-desc--2">Most recent</label>
# </div>
# <div class="js-form-item form-item js-form-type-radio form-type-radio js-form-item-sort-bef-combine form-item-sort-bef-combine">
# <input class="form-radio" data-drupal-selector="edit-sort-bef-combine-search-api-relevance-asc-2" id="edit-sort-bef-combine-search-api-relevance-asc--2" name="sort_bef_combine" type="radio" value="search_api_relevance_ASC"/>
# <label class="option" for="edit-sort-bef-combine-search-api-relevance-asc--2">Less relevant</label>
# </div>
# <div class="js-form-item form-item js-form-type-radio form-type-radio js-form-item-sort-bef-combine form-item-sort-bef-combine">
# <input checked="checked" class="form-radio" data-drupal-selector="edit-sort-bef-combine-search-api-relevance-desc-2" id="edit-sort-bef-combine-search-api-relevance-desc--2" name="sort_bef_combine" type="radio" value="search_api_relevance_DESC"/>
# <label class="option" for="edit-sort-bef-combine-search-api-relevance-desc--2">Most relevant</label>
# </div>
# </div>
# </div>
# </div>
# </fieldset>
# <div class="form-actions js-form-wrapper form-wrapper" data-drupal-selector="edit-actions" id="edit-actions--2"><input class="button--primary button js-form-submit form-submit" data-drupal-selector="edit-submit-search-content-2" id="edit-submit-search-content--2" type="submit" value="Search"/>
# </div>
# </div>
# </form>
# </div>
# </div>
# </div>
# </div>
# </div>
# </header>
# <div class="wrapper-content">
# <div class="hidden" data-drupal-messages-fallback=""></div>
# <div class="block block-harris-blocks block-harris-current-node-block" id="block-currentnode">
# <section class="node--hero concentric-red-large">
# <div class="hero-banner--internal">
# <div class="color_reversed breadcrumbs">
# <div class="container hero_region_breadcrumbs">
# <div class="l-1up">
# <nav aria-labelledby="block-breadcrumbs-menu" class="block block-menu navigation menu--" id="block-breadcrumbs" role="navigation">
# <h2 class="visually-hidden" id="block-breadcrumbs-menu">Breadcrumbs</h2>
# <nav aria-labelledby="system-breadcrumb" class="breadcrumb" role="navigation">
# <h2 class="visually-hidden" id="system-breadcrumb">Breadcrumb</h2>
# <ol>
# <li>
# <a href="/">Home</a>
# </li>
# <li>
# <a href="/academics">Academics</a>
# </li>
# <li>
# <a href="/academics/degrees">Degrees</a>
# </li>
# <li>
#                   Master of Public Policy (MPP)
#               </li>
# </ol>
# </nav>
# </nav>
# </div>
# </div>
# </div>
# <div class="container">
# <div class="l-1up">
# <div class="hero-content">
# <div class="node--hero--title">
# <h1><span class="field field--name-title field--type-string field--label-hidden">Master of Public Policy (MPP)</span>
# </h1>
# </div>
# <div class="node--hero--subhead">
# <div class="field field--name-field-subhead field--type-string field--label-hidden field__item">A two-year program for students interested in developing the analytical skills needed to take on today's pressing policy challenges.</div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>
# </div>
# <div class="primary-page">
# <div class="container">
# <main class="l-main" role="main">
# <a id="main-content" tabindex="-1"></a> <div class="block block-system block-system-main-block" id="block-harris-theme-content">
# <article about="/academics/degrees/master-public-policy-mpp" class="node node--program" data-history-node-id="7501" role="article">
# <div class="node--content">
# <div class="node--content--subhead">
# <div class="field field--name-field-subhead field--type-string field--label-hidden field__item">A two-year program for students interested in developing the analytical skills needed to take on today's pressing policy challenges.</div>
# </div>
# <aside class="node--content--sidebar-first">
# <div class="block block-harris-blocks block-harris-secondary-menu-block" id="block-secondarymenu--3">
# <div class="back-to-container">
# <a class="btn-go-back" href="/academics/degrees">Back to Degrees</a>
# </div>
# </div>
# <div class="node--content--contact">
# <div class="field field--name-field-contact-information field--type-entity-reference field--label-hidden field__item">
# <article about="/node/5716" class="node node--type-contact node--view-mode-sidebar-teaser" data-history-node-id="5716" role="article">
# <h2>
# <a href="/node/5716" rel="bookmark"><span class="field field--name-title field--type-string field--label-hidden">Office of Admissions</span>
# </a>
# </h2>
# <div class="node__content">
# <div class="link__email">
# <a href="mailto:harrisadmissions@uchicago.edu">Email<span class="element-invisible"> harrisadmissions@uchicago.edu</span></a>
# </div>
# <div class="field field--name-field-telephone-number field--type-telephone field--label-hidden field__item"><a href="tel:773.702.8401">773.702.8401</a></div>
# </div>
# </article>
# </div>
# </div>
# </aside>
# <div class="node--content--main">
# <div class="node--content--main--body">
# <div class="clearfix text-formatted field field--name-body field--type-text-with-summary field--label-hidden field__item"><p>Across the public and private sectors, a new generation of data-minded leaders is needed to bring fresh thinking and different approaches to the world's most pressing policy challenges.</p>
# <p>The two-year MPP is a professional degree program designed to develop leaders who put evidence first. In course work, you'll build critical thinking and analytical skills in the core curriculum that teach you to make data-driven decisions now and throughout your career. Through applied experiences in Chicago and beyond, you’ll meet face-to-face with professionals in the field to analyze urgent policy problems and design solutions that work, using the latest science and technology.</p>
# <p>The core curriculum draws on a variety of disciplines and fields, including economics, sociology, political science, statistics, econometrics, political economy, organizational theory, and program evaluation, an ideal fit for students seeking a multidisciplinary approach to the study of public policy.</p>
# <div class="embedded-entity" data-embed-button="file_browser" data-entity-embed-display="file:file_default" data-entity-embed-display-settings="1 Read the Master of Public Policy Brochure (PDF, 2.5MB)" data-entity-type="file" data-entity-uuid="750f93de-2c79-4731-8b1c-c0686d559dc1" data-langcode="en">
# <span class="file file--mime-application-pdf file--application-pdf"> <a href="https://harris.uchicago.edu/files/master_of_public_policy_brochure_0.pdf" title="master_of_public_policy_brochure.pdf" type="application/pdf; length=2585603">Read the Master of Public Policy Brochure (PDF, 2.5MB)</a></span>
# </div>
# <h2>Program Details</h2></div>
# </div>
# <div class="node--content--main--accordion node--content--accordion">
# <div class="field field--name-field-accordion field--type-entity-reference-revisions field--label-hidden field__items">
# <div class="field__item"> <div class="paragraph paragraph--type--accordions paragraph--view-mode--default">
# <div class="field__label field field--name-field-title field--type-string field--label-hidden field__item">Curriculum</div>
# <div class="field__item clearfix text-formatted field field--name-field-body field--type-text-long field--label-hidden"><ul><li>
# <p>18 graduate-level courses (1800 units of credit) with at least 12 Public Policy (PPHA) courses</p>
# </li>
# <li>
# <p>6 core courses that provide a foundation in critical analysis, reflecting Harris's belief that mastering quantitative and analytical skills prepares students to be effective public policy leaders</p>
# <ul><li>
# <p>PPHA 30800 Analytical Politics I: Strategic Foundations or PPHA 41501 - PhD Game Theory (instructor approval required).</p>
# </li>
# <li>
# <p>PPHA 31610 Analytical Politics II: Political Institutions </p>
# </li>
# <li>
# <p>Statistics Sequence I. Choose one of the following:</p>
# <ul><li>
# <p>PPHA 31002 Statistics for Data Analysis I</p>
# </li>
# <li><span><span><span><span><span><span><span><span>PPHA 31202 <span>Advanced Statistics for Data Analysis I </span></span></span></span></span></span></span></span></span></li>
# <li>
# <p>Any course in the PhD econometrics sequence (instructor approval required): PPHA 42000 or PPHA 42100, or PPHA 42200</p>
# </li>
# </ul></li>
# <li>
# <p>Statistics Sequence II. Choose one of the following:</p>
# <ul><li>PPHA 31102 Statistics for Data Analysis II: Regressions</li>
# <li><span><span><span><span><span><span><span><span>PPHA 31302 <span>Advanced Statistics for Data Analysis II</span></span></span></span></span></span></span></span></span></li>
# <li>Any course in the PhD econometrics sequence (instructor approval required): PPHA 42000 or PPHA 42100, or PPHA 42200</li>
# </ul></li>
# <li>
# <p>Microeconomics Sequence I. Choose from the following:</p>
# </li>
# <li>
# <ul><li>
# <p>PPHA 32300 Principles of Microeconomics and Public Policy I</p>
# </li>
# <li>
# <p>PPHA 32310 Advanced Microeconomics for Public Policy I</p>
# </li>
# <li>
# <p>PPHA 44100 Principles of Microeconomics and Public Policy I (PhD sequence - instructor approval required)</p>
# </li>
# </ul></li>
# <li>
# <p>Microeconomics Sequence II. Choose from the following:</p>
# <ul><li>PPHA 32400 Principles of Microeconomics and Public Policy II</li>
# <li>PPHA 32410 Advanced Microeconomics for Public Policy II</li>
# <li>PPHA 44200 Principles of Microeconomics and Public Policy II (PhD sequence - instructor approval required)</li>
# </ul></li>
# </ul></li>
# <li>
# <p>Elective Options</p>
# <ul><li>
# <p>MPP students can explore special academic interests and fields as well as participate in internships and independent research complementing required course work.</p>
# </li>
# <li>
# <p>Students may choose to focus on an area of public policy, register for courses in departments and schools across the University, and take advantage of <a href="/academics/design-your-path/applied-experience">experiential opportunities</a> to apply what they learn in the classroom to real-world problems.</p>
# </li>
# </ul></li>
# </ul></div>
# </div>
# </div>
# <div class="field__item"> <div class="paragraph paragraph--type--accordions paragraph--view-mode--default">
# <div class="field__label field field--name-field-title field--type-string field--label-hidden field__item">Other Requirements</div>
# <div class="field__item clearfix text-formatted field field--name-field-body field--type-text-long field--label-hidden"><ul><li>
# <p>A cumulative GPA of 2.7 for all courses, based on a 4.0 scale</p>
# </li>
# <li>
# <p>A grade of C- or better for the 6 core courses</p>
# </li>
# <li>
# <p>Completion of the math requirement (<a href="/student-life/harris-experience/academic-support-programs">support available</a>)</p>
# <ul><li>
# <p>Pass algebra exam</p>
# </li>
# <li>
# <p>Pass calculus exam</p>
# </li>
# </ul></li>
# <li>Completion of an applied experience requirement (<a href="https://harris.uchicago.edu/academics/design-your-path/applied-experience">more information</a>)</li>
# <li>
# <p>No more than 2 reading/research, independent study, or internship courses</p>
# </li>
# <li>
# <p>No more than 2 courses taken Pass/Fail (core courses cannot be taken pass/fail)</p>
# </li>
# <li>
# <p>Courses with grades of F, I, W, or with no reported grade do not apply toward the 18-course requirement for the program.</p>
# </li>
# </ul></div>
# </div>
# </div>
# <div class="field__item"> <div class="paragraph paragraph--type--accordions paragraph--view-mode--default">
# <div class="field__label field field--name-field-title field--type-string field--label-hidden field__item">Sample Schedule</div>
# <div class="field__item clearfix text-formatted field field--name-field-body field--type-text-long field--label-hidden"><h2>Year 1</h2>
# <h3>Autumn</h3>
# <ul><li>Microeconomics I (PPHA 32300)
# 	<ul><li>Option to take advanced PPHA 32310 or PhD level PPHA 44100</li>
# </ul></li>
# <li>Statistics for Data Analysis I (PPHA 31002)
# 	<ul><li>Option to take advanced PPHA 31202 or PhD level STAT 24400</li>
# </ul></li>
# <li>Analytical Politics I: Strategic Foundations (PPHA 30800) pr PhD Game Theory (PPHA 41501)</li>
# </ul><h3>Winter</h3>
# <ul><li>Microeconomics II (PPHA 32400)
# 	<ul><li>Option to take advanced PPHA 32410 or PhD level PPHA 44200</li>
# </ul></li>
# <li>Statistics for Data Analysis II: Regressions (PPHA 31102)
# 	<ul><li>Option to take advanced PPHA 31302, PhD level STAT 24400, or PhD level PPHA 42000</li>
# </ul></li>
# <li>Analytical Politics II: Political Institutions (PPHA 31610)</li>
# </ul><h3>Spring</h3>
# <ul><li>Elective</li>
# <li>Elective</li>
# <li>Elective</li>
# </ul></div>
# </div>
# </div>
# <div class="field__item"> <div class="paragraph paragraph--type--accordions paragraph--view-mode--default">
# <div class="field__label field field--name-field-title field--type-string field--label-hidden field__item">Testimonials</div>
# ...
# </li>
# <li class="utility-navigation__child-item">
# <a accesskey="" href="http://www.uchicagoalumni.org/directory.html" id="" name="" rel="" style="" target="" title="">Alumni Directory</a>
# </li>
# <li class="utility-navigation__child-item">
# <a accesskey="" data-drupal-link-system-path="node/7241" href="/alumni/get-involved" id="" name="" rel="" style="" target="" title="">Get Involved</a>
# </li>
# <li class="utility-navigation__child-item">
# <a accesskey="" href="/harrisgives" id="" name="" rel="" style="" target="" title="">Donate Now</a>
# </li>
# </ul>
# </div></li>
# </ul>
# </div>
# </div>
# </div>
# <footer class="footer">
# <div class="container">
# <nav aria-label="Footer menu" class="block block-menu navigation menu--footer" role="navigation">
# <h2 class="visually-hidden">Footer menu</h2>
# <ul class="menu">
# <li class="footer-logo menu-item">
# <a accesskey="" href="http://www.uchicago.edu/" id="" name="" rel="" style="" target="" title="">The University of Chicago</a>
# </li>
# <li class="menu-item">
# <a accesskey="" href="https://apply-harris.uchicago.edu/apply/" id="" name="" rel="" style="" target="" title="">Apply</a>
# </li>
# <li class="menu-item">
# <a accesskey="" href="http://humanresources.uchicago.edu/jobs/" id="" name="" rel="" style="" target="" title="">Careers at Harris</a>
# </li>
# <li class="menu-item">
# <a accesskey="" data-drupal-link-system-path="academics/programs-degrees/courses" href="/academics/programs-degrees/courses" id="" name="" rel="" style="" target="" title="">Courses</a>
# </li>
# <li class="menu-item">
# <a accesskey="" data-drupal-link-system-path="node/6841" href="/directions" id="" name="" rel="" style="" target="" title="">Directions</a>
# </li>
# <li class="menu-item">
# <a accesskey="" href="http://grad.uchicago.edu/about-us/privacy-notice/" id="" name="" rel="" style="" target="" title="">Privacy Notice</a>
# </li>
# </ul>
# </nav>
# <nav aria-label="Connect with Us" class="block block-menu navigation menu--social-media-menu" role="navigation">
# <h2>Connect with Us</h2>
# <ul class="menu">
# <li class="footer-facebook menu-item">
# <a accesskey="" href="https://www.facebook.com/harrispolicy" id="" name="" rel="" style="" target="" title="">Facebook</a>
# </li>
# <li class="footer-twitter menu-item">
# <a accesskey="" href="https://twitter.com/HarrisPolicy" id="" name="" rel="" style="" target="" title="">Twitter</a>
# </li>
# <li class="footer-linkedin menu-item">
# <a accesskey="" href="https://www.linkedin.com/edu/harris-school-of-public-policy-at-the-university-of-chicago-152025" id="" name="" rel="" style="" target="" title="">LinkedIn</a>
# </li>
# <li class="footer-youtube menu-item">
# <a accesskey="" href="http://www.youtube.com/user/UChicagoHarris" id="" name="" rel="" style="" target="" title="">Youtube</a>
# </li>
# </ul>
# </nav>
# <div class="block block-block-content block-block-content3bec117c-2b91-4ce7-bab1-5a6d4c20816b" id="block-footerquestionsblock">
# <div class="clearfix text-formatted field field--name-body field--type-text-with-summary field--label-hidden field__item"><div class="block-contact-block">
# <h2 style=" width: 100%;">Questions?</h2>
# <div class="questions-button-wrapper"><a class="button questions primary-button" href="/contact-us" style="font-size: 12px; padding: 2px 40px; margin: 10px 0;">Contact Us</a></div>
# </div>
# <style type="text/css">
# <!--/*--><![CDATA[/* ><!--*/
# questions-button-wrapper{text-align: center; padding-top: 12px;}
# @media (min-width: 1100px){.questions-button-wrapper{padding: 0; float: left; padding-top: 24px; width: 100%; text-align: left;} }
# a.button.questions:hover:after{z-index:-1;}
# a.button.questions:hover{color: #ae132a;}
# a.button.questions{
#     border: 2px solid #ae132a;
#     background: #ae132a;
#     z-index: 2;
#     color: #fff;
# }
#
# /*--><!]]>*/
# </style></div>
# </div>
# <div class="block block-block-content block-block-content379f8bee-93e1-4b96-82ae-3745d7d58306" id="block-measuredmarketingpixel">
# <div class="clearfix text-formatted field field--name-body field--type-text-with-summary field--label-hidden field__item"><script async="" type="text/javascript">
# <!--//--><![CDATA[// ><!--
# var d=document,s="https://a.smtrk.net/trk?t=s&i=5bcdf95d65e3641d4cf0829e&p=t,i,x&s=72cb0155755cd58de7d7676aad9c3981&r="+escape(d.referrer)+"&u="+escape(d.URL),n=d.createElement("script"),e=d.getElementsByTagName("script")[0];n.async=!0,n.src=s,e.parentNode.insertBefore(n,e);
# //--><!]]>
# </script><style type="text/css">
# <!--/*--><![CDATA[/* ><!--*/
#
# #block-measuredmarketingpixel{display:none; z-index: -10;}
#
# /*--><!]]>*/
# </style></div>
# </div>
# <div class="block block-block-content block-block-content82bbd380-e310-4fdd-9243-13d5a30e79bd" id="block-linkedinsitewidepixeltracking">
# <div class="clearfix text-formatted field field--name-body field--type-text-with-summary field--label-hidden field__item"><script type="text/javascript">
# <!--//--><![CDATA[// ><!--
#
# _linkedin_partner_id = "947153";
# window._linkedin_data_partner_ids = window._linkedin_data_partner_ids || [];
# window._linkedin_data_partner_ids.push(_linkedin_partner_id);
#
# //--><!]]>
# </script><script type="text/javascript">
# <!--//--><![CDATA[// ><!--
#
# (function(){var s = document.getElementsByTagName("script")[0];
# var b = document.createElement("script");
# b.type = "text/javascript";b.async = true;
# b.src = "https://snap.licdn.com/li.lms-analytics/insight.min.js";
# s.parentNode.insertBefore(b, s);})();
#
# //--><!]]>
# </script><noscript>
# <img alt="" height="1" src="https://px.ads.linkedin.com/collect/?pid=947153&amp;fmt=gif" style="display:none;" width="1"/></noscript></div>
# </div>
# <div class="block block-block-content block-block-content67689b46-4603-426e-9ae9-98e6b3ca35c6" id="block-mobilemenufixcss">
# <div class="clearfix text-formatted field field--name-body field--type-text-with-summary field--label-hidden field__item"><style>
# <!--/*--><![CDATA[/* ><!--*/
# @media only screen and (max-width: 900px) { .main-navigation__wrap.sub-menu ul.sf-menu li.sf-depth-1.keep-visible .inner-menu-column > ul {z-index: 0;}}
# /*--><!]]>*/
# </style></div>
# </div>
# <div class="block block-block-content block-block-content5de1b834-dfdd-45b7-b36e-e4315a9a7db3" id="block-alertheader">
# <div class="clearfix text-formatted field field--name-body field--type-text-with-summary field--label-hidden field__item"><link href="https://use.fontawesome.com/14fb473629.css" media="all" rel="stylesheet"/><script>
# <!--//--><![CDATA[// ><!--
#
# /*document.getElementsByClassName('dialog-off-canvas-main-canvas')[0].insertAdjacentHTML('beforebegin','<a class="ss-standard ss-alert" href="https://harris.uchicago.edu/coronavirus-updates" id="alert_banner"><p>Updates on coronavirus for the Harris community');*/
# document.getElementsByClassName('dialog-off-canvas-main-canvas')[0].insertAdjacentHTML('beforebegin',
#     '<a class="ss-standard ss-alert" href="https://goforward.uchicago.edu/" id="alert_banner" title="University Covid-19 Updates"><p>University Covid-19 Updates');
#
# //--><!]]>
# </script><style type="text/css">
# <!--/*--><![CDATA[/* ><!--*/
# #alert_banner:focus:before, #alert_banner:hover:before {color: #f8a429;}
# #alert_banner:before {
#     clear: both;
#     display: block;
#     color: #282828;
#     vertical-align: middle;
#     margin-bottom: .25em;
# }
# /*
# .ss-alert:before, .ss-alert.right:after {
#     content: '⚠';
#     font-family: FontAwesome;
#     content: '\f071';
# }
# */
# #alert_banner {
#     display: block;
#     padding: 1em 2%;
#     text-align: center;
#     color: #000;
#     border-bottom: 1px solid #000;
#     font-family: 'Gotham A', 'Gotham B','HelveticaNeue','Helvetica Neue','HelveticaNeueRoman','HelveticaNeue-Roman','Helvetica Neue Roman','TeXGyreHerosRegular','Helvetica','Tahoma','Geneva','Arial',sans-serif;
#     font-weight: 500;
#     font-style: normal;
#     font-size: .9em;
#     line-height: 1.5em;
#     letter-spacing: normal;
#     line-height: 1em;
#     background-color: #f9b64e;
#     /*background-image: linear-gradient(45deg, rgba(255,255,255,0.15) 25%, transparent 25%, transparent 50%, rgba(255,255,255,0.15) 50%, rgba(255,255,255,0.15) 75%, transparent 75%, transparent);*/
#     -webkit-background-size: 40px 40px;
#     background-size: 40px 40px;
#     transition: background .25s;
# }
# #alert_banner:focus, #alert_banner:hover {
#     color: #f8a429;
#     background-color: #000;
#     text-decoration: none;
# }
# #alert_banner p{ margin: .5em .5em;}
# #alert_banner{
#     padding: 0.35em 2%;
#     font-size: 0.78em;
# }
#
# /*--><!]]>*/
# </style></div>
# </div>
# <div class="block block-block-content block-block-contentf48d9899-238b-4acb-b5d9-aa2c52ab3ed1" id="block-hubspottrackingcode">
# <div class="clearfix text-formatted field field--name-body field--type-text-with-summary field--label-hidden field__item"><!-- Start of HubSpot Embed Code -->
# <script async="" defer="defer" id="hs-script-loader" src="//js.hs-scripts.com/7087380.js" type="text/javascript"></script><!-- End of HubSpot Embed Code --></div>
# </div>
# <div class="block block-block-content block-block-content667c4369-32f5-4c70-8279-a70343a26fc5" id="block-harriscssoverrides">
# <div class="clearfix text-formatted field field--name-body field--type-text-with-summary field--label-hidden field__item"><style type="text/css">
# <!--/*--><![CDATA[/* ><!--*/
# .block-superfishmain .inner-menu-row a[href~="/academics/undergraduate-program"] ~ ul.sf-hidden,
# .block-superfishmain .inner-menu-row a[href~="/academics/undergraduate-program"] ~ ul li,
# .block-superfishmain .inner-menu-row a[href~="/academics/undergraduate"] ~ ul li,
# .block-superfishmain .inner-menu-row a[href~="/academics/undergraduate"] ~ ul.sf-hidden {
#     display: none !important;
# }
# .block-superfishmain .inner-menu-row a[href~="/news-events/not-another-politics-podcast"] ~ ul.sf-hidden,
# .block-superfishmain .inner-menu-row a[href~="/news-events/not-another-politics-podcast"] ~ ul li {   display: none !important;}
# ul#superfish-main ul.sf-hidden:empty{display: none !important;}
# ul.sf-hidden:empty{display: none;}
# ul.chosen-results:empty{display: none;}
# ul:empty{display: none;}
#
# .block-superfishmain .inner-menu-row a.centers + ul li,
# .block-superfishmain .inner-menu-row a.centers + ul.sf-hidden,
# ul#superfish-main.sfHoverActive li.sf-depth-1:hover .inner-menu-row a.centers + ul.sf-hidden {
#     display: none !important;
# }
#
# /*--><!]]>*/
# </style></div>
# </div>
# </div>
# </footer>
# </div>
# </div>
# <script data-drupal-selector="drupal-settings-json" type="application/json">{"path":{"baseUrl":"\/","scriptPath":null,"pathPrefix":"","currentPath":"node\/7501","currentPathIsAdmin":false,"isFront":false,"currentLanguage":"en"},"pluralDelimiter":"\u0003","suppressDeprecationErrors":true,"ajaxPageState":{"libraries":"addtoany\/addtoany,better_exposed_filters\/general,classy\/base,classy\/file,classy\/messages,classy\/node,core\/html5shiv,core\/normalize,google_analytics\/google_analytics,harris_theme\/fonts,harris_theme\/global-styling,paragraphs\/drupal.paragraphs.unpublished,superfish\/superfish,superfish\/superfish_hoverintent,superfish\/superfish_smallscreen,superfish\/superfish_supersubs,superfish\/superfish_supposition,system\/base,views\/views.module","theme":"harris_theme","theme_token":null},"ajaxTrustedUrl":{"\/search":true},"google_analytics":{"trackOutbound":true,"trackMailto":true,"trackDownload":true,"trackDownloadExtensions":"7z|aac|arc|arj|asf|asx|avi|bin|csv|doc(x|m)?|dot(x|m)?|exe|flv|gif|gz|gzip|hqx|jar|jpe?g|js|mp(2|3|4|e?g)|mov(ie)?|msi|msp|pdf|phps|png|ppt(x|m)?|pot(x|m)?|pps(x|m)?|ppam|sld(x|m)?|thmx|qtm?|ra(m|r)?|sea|sit|tar|tgz|torrent|txt|wav|wma|wmv|wpd|xls(x|m|b)?|xlt(x|m)|xlam|xml|z|zip","trackDomainMode":2,"trackCrossDomains":["harris.uchicago.edu, apply-harris.uchicago.edu"]},"superfish":{"superfish-main":{"id":"superfish-main","sf":{"animation":{"opacity":"show","height":"show"},"speed":"fast","autoArrows":false,"dropShadows":false},"plugins":{"smallscreen":{"mode":"window_width","breakpoint":900,"title":"Main navigation"},"supposition":true,"supersubs":true}}},"user":{"uid":0,"permissionsHash":"d6ee0468f2be400ea79a72aa6a398b93498d88dc871240bc02ab60d7a0145bb8"}}</script>
# <script src="/core/assets/vendor/jquery/jquery.min.js?v=3.5.1"></script>
# <script src="/core/assets/vendor/jquery-once/jquery.once.min.js?v=2.2.3"></script>
# <script src="/core/misc/drupalSettingsLoader.js?v=8.9.14"></script>
# <script src="/core/misc/drupal.js?v=8.9.14"></script>
# <script src="/core/misc/drupal.init.js?v=8.9.14"></script>
# <script src="/core/assets/vendor/jquery.ui/ui/data-min.js?v=1.12.1"></script>
# <script src="/core/assets/vendor/jquery.ui/ui/disable-selection-min.js?v=1.12.1"></script>
# <script src="/core/assets/vendor/jquery.ui/ui/form-min.js?v=1.12.1"></script>
# <script src="/core/assets/vendor/jquery.ui/ui/labels-min.js?v=1.12.1"></script>
# <script src="/core/assets/vendor/jquery.ui/ui/jquery-1-7-min.js?v=1.12.1"></script>
# <script src="/core/assets/vendor/jquery.ui/ui/scroll-parent-min.js?v=1.12.1"></script>
# <script src="/core/assets/vendor/jquery.ui/ui/tabbable-min.js?v=1.12.1"></script>
# <script src="/core/assets/vendor/jquery.ui/ui/unique-id-min.js?v=1.12.1"></script>
# <script src="/core/assets/vendor/jquery.ui/ui/version-min.js?v=1.12.1"></script>
# <script src="/core/assets/vendor/jquery.ui/ui/escape-selector-min.js?v=1.12.1"></script>
# <script src="/core/assets/vendor/jquery.ui/ui/focusable-min.js?v=1.12.1"></script>
# <script src="/core/assets/vendor/jquery.ui/ui/ie-min.js?v=1.12.1"></script>
# <script src="/core/assets/vendor/jquery.ui/ui/keycode-min.js?v=1.12.1"></script>
# <script src="/core/assets/vendor/jquery.ui/ui/plugin-min.js?v=1.12.1"></script>
# <script src="/core/assets/vendor/jquery.ui/ui/safe-active-element-min.js?v=1.12.1"></script>
# <script src="/core/assets/vendor/jquery.ui/ui/safe-blur-min.js?v=1.12.1"></script>
# <script src="/core/assets/vendor/jquery.ui/ui/widget-min.js?v=1.12.1"></script>
# <script async="" src="https://static.addtoany.com/menu/page.js"></script>
# <script src="/modules/contrib/addtoany/js/addtoany.js?v=8.9.14"></script>
# <script src="/modules/contrib/google_analytics/js/google_analytics.js?v=8.9.14"></script>
# <script src="/core/assets/vendor/jquery.ui/ui/widgets/tabs-min.js?v=1.12.1"></script>
# <script src="/core/misc/progress.js?v=8.9.14"></script>
# <script src="/core/misc/ajax.js?v=8.9.14"></script>
# <script src="/core/themes/stable/js/ajax.js?v=8.9.14"></script>
# <script src="/themes/custom/harris_theme/js/jquery.fitvids.js?v=1.21"></script>
# <script src="/themes/custom/harris_theme/js/chosen.jquery.js?v=1.21"></script>
# <script src="/themes/custom/harris_theme/js/jquery.matchHeight.js?v=1.21"></script>
# <script src="/themes/custom/harris_theme/js/classie.js?v=1.21"></script>
# <script src="/themes/custom/harris_theme/js/script.js?v=1.21"></script>
# <script src="/themes/custom/harris_theme/js/tabs_slideshow.js?v=1.21"></script>
# <script src="/themes/custom/harris_theme/js/slick.js?v=1.21"></script>
# <script src="/themes/custom/harris_theme/js/megamenu.js?v=1.21"></script>
# <script src="/themes/custom/harris_theme/js/ambientvideo.js?v=1.21"></script>
# <script src="/themes/custom/harris_theme/js/microsite.js?v=1.21"></script>
# <script src="/modules/contrib/better_exposed_filters/js/better_exposed_filters.js?v=4.x"></script>
# <script src="/libraries/superfish/superfish.js?qsquwr"></script>
# <script src="/libraries/superfish/jquery.hoverIntent.minified.js?qsquwr"></script>
# <script src="/libraries/superfish/sfsmallscreen.js?qsquwr"></script>
# <script src="/libraries/superfish/supposition.js?qsquwr"></script>
# <script src="/libraries/superfish/supersubs.js?qsquwr"></script>
# <script src="/modules/contrib/superfish/js/superfish.js?v=2.0"></script>
# <script type="text/javascript">window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","licenseKey":"e43e9c38fc","applicationID":"70697360","transactionName":"NgBRMRMEDEUHV0UNWw9KcgYVDA1YSXBDEUQACW8LDgEHaiVbXxBGDglfABM5LFkCUWcNURYmXAsVFw1aClFDSQoXDFYS","queueTime":0,"applicationTime":1796,"atts":"GkdSR1seH0s=","errorBeacon":"bam.nr-data.net","agent":""}</script></body>
# </html>

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en" prefix="content: http://purl.org/rss/1.0/modules/content/  dc: http://purl.org/dc/terms/  foaf: http://xmlns.com/foaf/0.1/  og: http://ogp.me/ns#  rdfs: http://www.w3.org/2000/01/rdf-schema#  schema: http://schema.org/  sioc: http://rdfs.org/sioc/ns#  sioct: http://rdfs.org/sioc/types#  skos: http://www.w3.org/2004/02/skos/core#  xsd: http://www.w3.org/2001/XMLSchema# ">
#  <head>
#   <!-- Google Tag Manager -->
#   <script>
#    (function (w, d, s, l, i) {
#             wl = wl || [];
#             wl.push({'gtm.start': new Date().getTime(), event: 'gtm.js'});
#             var f = d.getElementsByTagName(s)
#             0, j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : '';
#             j.async = true;
#             j.src = 'https://www.googletagmanager.com/gtm.js?id=' + i + dl;
#             f.parentNode.insertBefore(j, f);
#           })(window, document, 'script', 'dataLayer', 'GTM-W7TVBBS');
#   </script>
#   <!-- End Google Tag Manager -->
#   <meta charset="utf-8"/>
#   <script type="text/javascript">
#    (window.NREUM||(NREUM={})).loader_config={licenseKey:"e43e9c38fc",applicationID:"70697360"};window.NREUM||(NREUM={}),__nr_require=function(e,t,n){function r(n){if(!t[n]){var i=t[n]={exports:{}};e[n][0].call(i.exports,function(t){var i=e[n][1][t];return r(i||t)},i,i.exports)}return t[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var i=0;i<n.length;i++)r(n[i]);return r}({1:[function(e,t,n){function r(){}function i(e,t,n){return function(){return o(e,[u.now()].concat(c(arguments)),t?null:this,n),t?void 0:this}}var o=e("handle"),a=e(7),c=e(8),f=e("ee").get("tracer"),u=e("loader"),s=NREUM;"undefined"==typeof window.newrelic&&(newrelic=s);var d=["setPageViewName","setCustomAttribute","setErrorHandler","finished","addToTrace","inlineHit","addRelease"],p="api-",l=p+"ixn-";a(d,function(e,t){s[t]=i(p+t,!0,"api")}),s.addPageAction=i(p+"addPageAction",!0),s.setCurrentRouteName=i(p+"routeName",!0),t.exports=newrelic,s.interaction=function(){return(new r).get()};var m=r.prototype={createTracer:function(e,t){var n={},r=this,i="function"==typeof t;return o(l+"tracer",[u.now(),e,n],r),function(){if(f.emit((i?"":"no-")+"fn-start",[u.now(),r,i],n),i)try{return t.apply(this,arguments)}catch(e){throw f.emit("fn-err",[arguments,this,e],n),e}finally{f.emit("fn-end",[u.now()],n)}}}};a("actionText,setName,setAttribute,save,ignore,onEnd,getContext,end,get".split(","),function(e,t){m[t]=i(l+t)}),newrelic.noticeError=function(e,t){"string"==typeof e&&(e=new Error(e)),o("err",[e,u.now(),!1,t])}},{}],2:[function(e,t,n){function r(){return c.exists&&performance.now?Math.round(performance.now()):(o=Math.max((new Date).getTime(),o))-a}function i(){return o}var o=(new Date).getTime(),a=o,c=e(9);t.exports=r,t.exports.offset=a,t.exports.getLastTimestamp=i},{}],3:[function(e,t,n){function r(e){return!(!e||!e.protocol||"file:"===e.protocol)}t.exports=r},{}],4:[function(e,t,n){function r(e,t){var n=e.getEntries();n.forEach(function(e){"first-paint"===e.name?d("timing",["fp",Math.floor(e.startTime)]):"first-contentful-paint"===e.name&&d("timing",["fcp",Math.floor(e.startTime)])})}function i(e,t){var n=e.getEntries();n.length>0&&d("lcp",[n[n.length-1]])}function o(e){e.getEntries().forEach(function(e){e.hadRecentInput||d("cls",[e])})}function a(e){if(e instanceof m&&!g){var t=Math.round(e.timeStamp),n={type:e.type};t<=p.now()?n.fid=p.now()-t:t>p.offset&&t<=Date.now()?(t-=p.offset,n.fid=p.now()-t):t=p.now(),g=!0,d("timing",["fi",t,n])}}function c(e){d("pageHide",[p.now(),e])}if(!("init"in NREUM&&"page_view_timing"in NREUM.init&&"enabled"in NREUM.init.page_view_timing&&NREUM.init.page_view_timing.enabled===!1)){var f,u,s,d=e("handle"),p=e("loader"),l=e(6),m=NREUM.o.EV;if("PerformanceObserver"in window&&"function"==typeof window.PerformanceObserver){f=new PerformanceObserver(r);try{f.observe({entryTypes:["paint"]})}catch(v){}u=new PerformanceObserver(i);try{u.observe({entryTypes:["largest-contentful-paint"]})}catch(v){}s=new PerformanceObserver(o);try{s.observe({type:"layout-shift",buffered:!0})}catch(v){}}if("addEventListener"in document){var g=!1,w=["click","keydown","mousedown","pointerdown","touchstart"];w.forEach(function(e){document.addEventListener(e,a,!1)})}l(c)}},{}],5:[function(e,t,n){function r(e,t){if(!i)return!1;if(e!==i)return!1;if(!t)return!0;if(!o)return!1;for(var n=o.split("."),r=t.split("."),a=0;a<r.length;a++)if(r[a]!==n[a])return!1;return!0}var i=null,o=null,a=/Version\/(\S+)\s+Safari/;if(navigator.userAgent){var c=navigator.userAgent,f=c.match(a);f&&c.indexOf("Chrome")===-1&&c.indexOf("Chromium")===-1&&(i="Safari",o=f[1])}t.exports={agent:i,version:o,match:r}},{}],6:[function(e,t,n){function r(e){function t(){e(a&&document[a]?document[a]:document[i]?"hidden":"visible")}"addEventListener"in document&&o&&document.addEventListener(o,t,!1)}t.exports=r;var i,o,a;"undefined"!=typeof document.hidden?(i="hidden",o="visibilitychange",a="visibilityState"):"undefined"!=typeof document.msHidden?(i="msHidden",o="msvisibilitychange"):"u ...
#   </script>
#   <script>
#    window.google_analytics_domain_name = "none";window.google_analytics_uacct = "UA-32628807-2";(function(i,s,o,g,r,a,m){i["GoogleAnalyticsObject"]=r;i[r]=i[r]||function(){(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)})(window,document,"script","https://www.google-analytics.com/analytics.js","ga");ga("create", "UA-32628807-2", {"cookieDomain":"auto","allowLinker":true});ga("require", "linker");ga("linker:autoLink", ["harris.uchicago.edu, apply-harris.uchicago.edu"]);ga("set", "anonymizeIp", true);ga("send", "pageview");
#   </script>
#   <meta content="Across the public and private sectors, a new generation of data-minded leaders is needed to bring fresh thinking and different approaches to the world's most pressing policy challenges." name="description"/>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=3.0, user-scalable=yes" name="viewport"/>
#   <meta content="Drupal 8 (https://www.drupal.org)" name="Generator"/>
#   <meta content="width" name="MobileOptimized"/>
#   <meta content="true" name="HandheldFriendly"/>
#   <link href="/themes/custom/harris_theme/favicon.ico" rel="shortcut icon" type="image/vnd.microsoft.icon"/>
#   <link href="https://harris.uchicago.edu/academics/degrees/master-public-policy-mpp" rel="canonical"/>
#   <link href="https://harris.uchicago.edu/node/7501" rel="shortlink"/>
#   <link href="https://harris.uchicago.edu/academics/degrees/master-public-policy-mpp" rel="revision"/>
#   <script defer="" src="/files/google_tag/primary/google_tag.script.js?qsquwr">
#   </script>
#   <script>
#    window.a2a_config=window.a2a_config||{};a2a_config.callbacks=[];a2a_config.overlays=[];a2a_config.templates={};
#   </script>
#   <title>
#    Master of Public Policy (MPP) | The University of Chicago Harris School of Public Policy
#   </title>
#   <link href="/core/assets/vendor/normalize-css/normalize.css?qsquwr" media="all" rel="stylesheet"/>
#   <link href="/core/misc/normalize-fixes.css?qsquwr" media="all" rel="stylesheet"/>
#   <link href="/libraries/superfish/css/superfish.css?qsquwr" media="all" rel="stylesheet"/>
#   <link href="/core/themes/stable/css/system/components/ajax-progress.module.css?qsquwr" media="all" rel="stylesheet"/>
#   <link href="/core/themes/stable/css/system/components/align.module.css?qsquwr" media="all" rel="stylesheet"/>
#   <link href="/core/themes/stable/css/system/components/autocomplete-loading.module.css?qsquwr" media="all" rel="stylesheet"/>
#   <link href="/core/themes/stable/css/system/components/fieldgroup.module.css?qsquwr" media="all" rel="stylesheet"/>
#   <link href="/core/themes/stable/css/system/components/container-inline.module.css?qsquwr" media="all" rel="stylesheet"/>
#   <link href="/core/themes/stable/css/system/components/clearfix.module.css?qsquwr" media="all" rel="stylesheet"/>
#   <link href="/core/themes/stable/css/system/components/details.module.css?qsquwr" media="all" rel="stylesheet"/>
#   <link href="/core/themes/stable/css/system/components/hidden.module.css?qsquwr" media="all" rel="stylesheet"/>
#   <link href="/core/themes/stable/css/system/components/item-list.module.css?qsquwr" media="all" rel="stylesheet"/>
#   <link href="/core/themes/stable/css/system/components/js.module.css?qsquwr" media="all" rel="stylesheet"/>
#   <link href="/core/themes/stable/css/system/components/nowrap.module.css?qsquwr" media="all" rel="stylesheet"/>
#   <link href="/core/themes/stable/css/system/components/position-container.module.css?qsquwr" media="all" rel="stylesheet"/>
#   <link href="/core/themes/stable/css/system/components/progress.module.css?qsquwr" media="all" rel="stylesheet"/>
#   <link href="/core/themes/stable/css/system/components/reset-appearance.module.css?qsquwr" media="all" rel="stylesheet"/>
#   <link href="/core/themes/stable/css/system/components/resize.module.css?qsquwr" media="all" rel="stylesheet"/>
#   <link href="/core/themes/stable/css/system/components/sticky-header.module.css?qsquwr" media="all" rel="stylesheet"/>
#   <link href="/core/themes/stable/css/system/components/system-status-counter.css?qsquwr" media="all" rel="stylesheet"/>
#   <link href="/core/themes/stable/css/system/components/system-status-report-counters.css?qsquwr" media="all" rel="stylesheet"/>
#   <link href="/core/themes/stable/css/system/components/system-status-report-general-info.css?qsquwr" media="all" rel="stylesheet"/>
#   <link href="/core/themes/stable/css/system/components/tabledrag.module.css?qsquwr" media="all" rel="stylesheet"/>
#   <link href="/core/themes/stable/css/system/components/tablesort.module.css?qsquwr" media="all" rel="stylesheet"/>
#   <link href="/core/themes/stable/css/system/components/tree-child.module.css?qsquwr" media="all" rel="stylesheet"/>
#   <link href="/core/assets/vendor/jquery.ui/themes/base/core.css?qsquwr" media="all" rel="stylesheet"/>
#   <link href="/core/assets/vendor/jquery.ui/themes/base/tabs.css?qsquwr" media="all" rel="stylesheet"/>
#   <link href="/core/themes/stable/css/views/views.module.css?qsquwr" media="all" rel="stylesheet"/>
#   <link href="/modules/contrib/addtoany/css/addtoany.css?qsquwr" media="all" rel="stylesheet"/>
#   <link href="/core/assets/vendor/jquery.ui/themes/base/theme.css?qsquwr" media="all" rel="stylesheet"/>
#   <link href="/modules/contrib/paragraphs/css/paragraphs.unpublished.css?qsquwr" media="all" rel="stylesheet"/>
#   <link href="/modules/contrib/better_exposed_filters/css/better_exposed_filters.css?qsquwr" media="all" rel="stylesheet"/>
#   <link href="/core/themes/classy/css/components/action-links.css?qsquwr" media="all" rel="stylesheet"/>
#   <link href="/core/themes/classy/css/components/breadcrumb.css?qsquwr" media="all" rel="stylesheet"/>
#   <link href="/core/themes/classy/css/components/button.css?qsquwr" media="all" rel="stylesheet"/>
#   <link href="/core/themes/classy/css/components/collapse-processed.css?qsquwr" media="all" rel="stylesheet"/>
#   <link href="/core/themes/classy/css/components/container-inline.css?qsquwr" media="all" rel="stylesheet"/>
#   <link href="/core/themes/classy/css/components/details.css?qsquwr" media="all" rel="stylesheet"/>
#   <link href="/core/themes/classy/css/components/exposed-filters.css?qsquwr" media="all" rel="stylesheet"/>
#   <link href="/core/themes/classy/css/components/field.css?qsquwr" media="all" rel="stylesheet"/>
#   <link href="/core/themes/classy/css/components/form.css?qsquwr" media="all" rel="stylesheet"/>
#   <link href="/core/themes/classy/css/components/icons.css?qsquwr" media="all" rel="stylesheet"/>
#   <link href="/core/themes/classy/css/components/inline-form.css?qsquwr" media="all" rel="stylesheet"/>
#   <link href="/core/themes/classy/css/components/item-list.css?qsquwr" media="all" rel="stylesheet"/>
#   <link href="/core/themes/classy/css/components/link.css?qsquwr" media="all" rel="stylesheet"/>
#   <link href="/core/themes/classy/css/components/links.css?qsquwr" media="all" rel="stylesheet"/>
#   <link href="/core/themes/classy/css/components/menu.css?qsquwr" media="all" rel="stylesheet"/>
#   <link href="/core/themes/classy/css/components/more-link.css?qsquwr" media="all" rel="stylesheet"/>
#   <link href="/core/themes/classy/css/components/pager.css?qsquwr" media="all" rel="stylesheet"/>
#   <link href="/core/themes/classy/css/components/tabledrag.css?qsquwr" media="all" rel="stylesheet"/>
#   <link href="/core/themes/classy/css/components/tableselect.css?qsquwr" media="all" rel="stylesheet"/>
#   <link href="/core/themes/classy/css/components/tablesort.css?qsquwr" media="all" rel="stylesheet"/>
#   <link href="/core/themes/classy/css/components/tabs.css?qsquwr" media="all" rel="stylesheet"/>
#   <link href="/core/themes/classy/css/components/textarea.css?qsquwr" media="all" rel="stylesheet"/>
#   <link href="/core/themes/classy/css/components/ui-dialog.css?qsquwr" media="all" rel="stylesheet"/>
#   <link href="/core/themes/classy/css/components/messages.css?qsquwr" media="all" rel="stylesheet"/>
#   <link href="/core/themes/classy/css/components/progress.css?qsquwr" media="all" rel="stylesheet"/>
#   <link href="/core/themes/classy/css/components/node.css?qsquwr" media="all" rel="stylesheet"/>
#   <link href="/core/themes/classy/css/components/file.css?qsquwr" media="all" rel="stylesheet"/>
#   <link href="/themes/custom/harris_theme/css/styles.css?qsquwr" media="all" rel="stylesheet"/>
#   <link href="https://cloud.typography.com/6178934/6584352/css/fonts.css" media="all" rel="stylesheet"/>
#   <!--[if lte IE 8]>
# <script src="/core/assets/vendor/html5shiv/html5shiv.min.js?v=3.7.3"></script>
# <![endif]-->
#  </head>
#  <body class="path-node page-node-type-program node--landing-page--secondary">
#   <!-- Google Tag Manager (noscript) -->
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-W7TVBBS" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <!-- End Google Tag Manager (noscript) -->
#   <a class="visually-hidden focusable skip-link" href="#main-content">
#    Skip to main content
#   </a>
#   <noscript aria-hidden="true">
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-W7TVBBS" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <div class="dialog-off-canvas-main-canvas" data-off-canvas-main-canvas="">
#    <header class="header" xmlns="http://www.w3.org/1999/html">
#     <div class="utility-navigation__wrap desktop-only">
#      <div class="utility-menu">
#       <div class="container">
#        <nav aria-label="Utility" class="block block-menu navigation menu--utility" role="navigation">
#         <h2 class="visually-hidden">
#          Utility
#         </h2>
#         <ul class="utility-navigation">
#          <li class="search-link utility-navigation__item">
#           <a class="utility-navigation__item-link" data-drupal-link-system-path="search" href="/search">
#            Search
#           </a>
#          </li>
#          <li class="utility-navigation__item">
#           <a class="utility-navigation__item-link" data-drupal-link-system-path="user/login" href="/user/login">
#            Log in
#           </a>
#          </li>
#          <li class="utility-navigation__item">
#           <a class="utility-navigation__item-link" data-drupal-link-system-path="directory" href="/directory">
#            Directory
#           </a>
#          </li>
#          <li class="utility-navigation__item">
#           <a accesskey="" class="utility-navigation__item-link" data-drupal-link-system-path="node/3101" href="/hireharris" id="" name="" rel="" style="" target="" title="">
#            Hire Harris
#           </a>
#           <div class="utility-navigation__child-container">
#            <ul class="utility-navigation__children">
#             <li class="utility-navigation__child-item">
#              <a accesskey="" data-drupal-link-system-path="node/3081" href="/findtalent" id="" name="" rel="" style="" target="" title="">
#               Find Talent
#              </a>
#             </li>
#             <li class="utility-navigation__child-item">
#              <a accesskey="" data-drupal-link-system-path="node/3051" href="/student-life/career-development" id="" name="" rel="" style="" target="" title="">
#               Find Work
#              </a>
#             </li>
#            </ul>
#           </div>
#          </li>
#          <li class="utility-navigation__item">
#           <a accesskey="" class="utility-navigation__item-link" href="" id="" name="" rel="" style="" target="" title="">
#            Info For
#           </a>
#           <div class="utility-navigation__child-container">
#            <ul class="utility-navigation__children">
#             <li class="utility-navigation__child-item">
#              <a accesskey="" data-drupal-link-system-path="node/2881" href="/admissions" id="" name="" rel="" style="" target="" title="">
#               Prospective Students
#              </a>
#             </li>
#             <li class="utility-navigation__child-item">
#              <a accesskey="" data-drupal-link-system-path="node/9871" href="/admitted-students" id="" name="" rel="" style="" target="" title="">
#               Admitted Students (Full-Time)
#              </a>
#             </li>
#             <li class="utility-navigation__child-item">
#              <a accesskey="" data-drupal-link-system-path="node/13076" href="/eveningprogram/admitted-students" id="" name="" rel="" style="" target="" title="">
#               New EMP Students
#              </a>
#             </li>
#             <li class="utility-navigation__child-item">
#              <a accesskey="" data-drupal-link-system-path="node/2966" href="/gateways/current-students" id="" name="" rel="" style="" target="" title="">
#               Current Students
#              </a>
#             </li>
#             <li class="utility-navigation__child-item">
#              <a accesskey="" data-drupal-link-system-path="node/2976" href="/gateways/faculty-staff" id="" name="" rel="" style="" target="" title="">
#               Faculty and Staff
#              </a>
#             </li>
#             <li class="utility-navigation__child-item">
#              <a accesskey="" data-drupal-link-system-path="node/2971" href="/alumni" id="" name="" rel="" style="" target="" title="">
#               Alumni
#              </a>
#             </li>
#             <li class="utility-navigation__child-item">
#              <a accesskey="" data-drupal-link-system-path="node/6571" href="/media" id="" name="" rel="" style="" target="" title="Resources for Media">
#               Media
#              </a>
#             </li>
#            </ul>
#           </div>
#          </li>
#          <li class="support-link utility-navigation__item">
#           <a accesskey="" class="utility-navigation__item-link" data-drupal-link-system-path="node/3106" href="/support-harris" id="" name="" rel="" style="" target="" title="">
#            Support Harris
#           </a>
#           <div class="utility-navigation__child-container">
#            <ul class="utility-navigation__children">
#             <li class="utility-navigation__child-item">
#              <a data-drupal-link-system-path="node/3091" href="/support-harris/ways-to-give">
#               Ways to Give
#              </a>
#             </li>
#             <li class="utility-navigation__child-item">
#              <a data-drupal-link-system-path="node/29876" href="/support-harris/harris-society">
#               Harris Society
#              </a>
#             </li>
#            </ul>
#           </div>
#          </li>
#         </ul>
#        </nav>
#       </div>
#      </div>
#      <div class="search-block">
#       <div class="views-exposed-form bef-exposed-form block block-views block-views-exposed-filter-blocksearch-content-search-content-page" data-drupal-selector="views-exposed-form-search-content-search-content-page" id="block-exposedformsearch-contentsearch-content-page-2">
#        <form accept-charset="UTF-8" action="/search" id="views-exposed-form-search-content-search-content-page" method="get">
#         <div class="filters clearfix">
#          <div class="js-form-item form-item js-form-type-textfield form-type-textfield js-form-item-keys form-item-keys">
#           <input class="form-text" data-drupal-selector="edit-keys" id="edit-keys" maxlength="128" name="keys" placeholder="Search" size="30" type="text" value=""/>
#          </div>
#          <fieldset class="fieldgroup form-composite js-form-item js-form-wrapper form-wrapper" data-drupal-selector="edit-sort-bef-combine" id="edit-sort-bef-combine--wrapper">
#           <legend>
#            <span class="fieldset-legend">
#             Sort
#            </span>
#            <span class="chevron bottom">
#             <a href="#">
#             </a>
#            </span>
#           </legend>
#           <div class="fieldset-wrapper">
#            <div class="form-radios" id="edit-sort-bef-combine">
#             <div class="form-radios">
#              <div class="js-form-item form-item js-form-type-radio form-type-radio js-form-item-sort-bef-combine form-item-sort-bef-combine">
#               <input class="form-radio" data-drupal-selector="edit-sort-bef-combine-created-asc" id="edit-sort-bef-combine-created-asc" name="sort_bef_combine" type="radio" value="created_ASC"/>
#               <label class="option" for="edit-sort-bef-combine-created-asc">
#                Older first
#               </label>
#              </div>
#              <div class="js-form-item form-item js-form-type-radio form-type-radio js-form-item-sort-bef-combine form-item-sort-bef-combine">
#               <input class="form-radio" data-drupal-selector="edit-sort-bef-combine-created-desc" id="edit-sort-bef-combine-created-desc" name="sort_bef_combine" type="radio" value="created_DESC"/>
#               <label class="option" for="edit-sort-bef-combine-created-desc">
#                Most recent
#               </label>
#              </div>
#              <div class="js-form-item form-item js-form-type-radio form-type-radio js-form-item-sort-bef-combine form-item-sort-bef-combine">
#               <input class="form-radio" data-drupal-selector="edit-sort-bef-combine-search-api-relevance-asc" id="edit-sort-bef-combine-search-api-relevance-asc" name="sort_bef_combine" type="radio" value="search_api_relevance_ASC"/>
#               <label class="option" for="edit-sort-bef-combine-search-api-relevance-asc">
#                Less relevant
#               </label>
#              </div>
#              <div class="js-form-item form-item js-form-type-radio form-type-radio js-form-item-sort-bef-combine form-item-sort-bef-combine">
#               <input checked="checked" class="form-radio" data-drupal-selector="edit-sort-bef-combine-search-api-relevance-desc" id="edit-sort-bef-combine-search-api-relevance-desc" name="sort_bef_combine" type="radio" value="search_api_relevance_DESC"/>
#               <label class="option" for="edit-sort-bef-combine-search-api-relevance-desc">
#                Most relevant
#               </label>
#              </div>
#             </div>
#            </div>
#           </div>
#          </fieldset>
#          <div class="form-actions js-form-wrapper form-wrapper" data-drupal-selector="edit-actions" id="edit-actions">
#           <input class="button--primary button js-form-submit form-submit" data-drupal-selector="edit-submit-search-content" id="edit-submit-search-content" type="submit" value="Search"/>
#          </div>
#         </div>
#        </form>
#       </div>
#      </div>
#     </div>
#     <div class="container">
#      <a class="brand" href="/">
#       <div class="brand__logo">
#        <svg height="87" viewbox="0 0 180 87" width="180" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#         <title>
#          Page 1
#         </title>
#         <defs>
#          <path d="M0 86.912h179.528V.847H0z" id="a">
#          </path>
#         </defs>
#         <g fill="none" fill-rule="evenodd">
#          <path d="M17.963 41.241h2.874v5.213h5.3V41.24h2.873v13.172h-2.874v-5.287h-5.3v5.287h-2.873z" fill="#000">
#          </path>
#          <g transform="translate(0 .005)">
#           <path d="M37.24 50.851v-.508a4.367 4.367 0 0 0-1.811-.376c-1.214 0-1.96.489-1.96 1.392v.037c0 .772.635 1.224 1.55 1.224 1.324 0 2.22-.734 2.22-1.769zm-6.514.659v-.038c0-2.201 1.66-3.218 4.031-3.218a7.04 7.04 0 0 1 2.445.415v-.17c0-1.185-.728-1.843-2.147-1.843-1.082 0-1.847.207-2.761.545l-.71-2.182c1.102-.49 2.184-.81 3.882-.81 1.55 0 2.669.414 3.378 1.13.746.752 1.082 1.862 1.082 3.217v5.852h-2.743v-1.092c-.69.771-1.642 1.28-3.023 1.28-1.885 0-3.434-1.092-3.434-3.086zm11.122-7.188h2.836v2.032c.58-1.392 1.512-2.295 3.192-2.22v2.991h-.15c-1.885 0-3.042 1.148-3.042 3.557v3.725h-2.836V44.322zm7.278 0h2.836v2.032c.579-1.392 1.512-2.295 3.192-2.22v2.991h-.15c-1.884 0-3.042 1.148-3.042 3.557v3.725h-2.836V44.322z" fill="#000">
#           </path>
#           <mask fill="#fff" id="b">
#            <use xlink:href="#a">
#            </use>
#           </mask>
#           <path d="M56.534 54.407h2.837V44.322h-2.837v10.085zM56.46 43.21h2.986v-2.54H56.46v2.54zm4.273 9.861l1.212-1.881c1.083.79 2.221 1.204 3.154 1.204.821 0 1.194-.3 1.194-.752v-.038c0-.621-.97-.828-2.07-1.166-1.4-.415-2.987-1.073-2.987-3.03v-.038c0-2.05 1.642-3.199 3.658-3.199 1.269 0 2.65.433 3.732 1.167l-1.082 1.976c-.989-.584-1.978-.94-2.706-.94-.691 0-1.045.3-1.045.695v.038c0 .564.951.828 2.034 1.204 1.4.47 3.023 1.148 3.023 2.991v.039c0 2.238-1.66 3.255-3.825 3.255a6.97 6.97 0 0 1-4.292-1.525m17.813-4.666c2.165 0 3.583-1.166 3.583-2.898v-.037c0-1.882-1.4-2.86-3.509-2.86h-3.303v5.795h3.229zm-4.702-7.168h4.888c2.949 0 4.89 1.58 4.89 4.177v.037c0 2.84-2.352 4.309-5.132 4.309h-3.173v4.647h-1.473v-13.17zm11.513 9.483v-6.04h1.437v5.682c0 1.807.97 2.935 2.668 2.935 1.642 0 2.893-1.223 2.893-3.048v-5.57h1.419v9.728h-1.419v-1.693c-.653 1.054-1.642 1.9-3.303 1.9-2.333 0-3.695-1.58-3.695-3.895m19.258-1.147v-.038c0-2.295-1.568-3.764-3.397-3.764-1.791 0-3.489 1.525-3.489 3.745v.038c0 2.258 1.698 3.763 3.49 3.763 1.865 0 3.396-1.393 3.396-3.744m-6.83 2.972v1.863h-1.438V40.672h1.438v5.964c.783-1.166 1.922-2.163 3.695-2.163 2.314 0 4.61 1.844 4.61 5.042v.038c0 3.18-2.278 5.061-4.61 5.061-1.792 0-2.949-.978-3.695-2.07m10.43 1.863h1.438V40.67h-1.438zm4.255.001h1.437v-9.729h-1.437v9.729zm-.093-11.855h1.642v-1.599h-1.642v1.6zm3.62 7.037v-.037c0-2.747 2.127-5.08 4.945-5.08 1.829 0 2.967.771 3.863 1.73l-.953 1.016c-.764-.808-1.622-1.467-2.93-1.467-1.958 0-3.45 1.675-3.45 3.764v.037c0 2.107 1.529 3.782 3.544 3.782 1.232 0 2.183-.62 2.949-1.449l.914.866c-.97 1.091-2.127 1.881-3.937 1.881-2.818 0-4.945-2.314-4.945-5.042m17.195-1.186c2.165 0 3.583-1.166 3.583-2.898v-.037c0-1.882-1.4-2.86-3.508-2.86h-3.304v5.795h3.23zm-4.703-7.168h4.89c2.948 0 4.889 1.58 4.889 4.177v.037c0 2.84-2.351 4.309-5.132 4.309h-3.173v4.647h-1.474v-13.17zm19.464 8.353v-.037c0-2.088-1.549-3.801-3.583-3.801-2.09 0-3.527 1.713-3.527 3.764v.037c0 2.088 1.53 3.782 3.564 3.782 2.09 0 3.546-1.694 3.546-3.744m-8.584 0v-.038c0-2.747 2.127-5.08 5.038-5.08 2.893 0 5.02 2.295 5.02 5.043v.037c0 2.747-2.146 5.08-5.057 5.08-2.893 0-5.001-2.295-5.001-5.042m12.129 4.816h1.438V40.67h-1.438zm4.254.001h1.437v-9.729h-1.437v9.729zm-.093-11.855h1.643v-1.599h-1.643v1.6zm3.621 7.037v-.037c0-2.747 2.126-5.08 4.944-5.08 1.83 0 2.968.771 3.863 1.73l-.952 1.016c-.765-.808-1.623-1.467-2.93-1.467-1.959 0-3.451 1.675-3.451 3.764v.037c0 2.107 1.53 3.782 3.545 3.782 1.231 0 2.183-.62 2.948-1.449l.915.866c-.97 1.091-2.128 1.881-3.938 1.881-2.818 0-4.945-2.314-4.945-5.042m10.443 7.394l.485-1.148c.468.245.897.357 1.512.357.859 0 1.4-.45 1.978-1.824l-4.385-9.69h1.587l3.507 8.11 3.099-8.11h1.53l-4.05 10.047c-.821 2.014-1.754 2.747-3.21 2.747-.802 0-1.4-.17-2.053-.489" fill="#000" mask="url(#b)">
#           </path>
#           <path d="M58.011 74.59l3.26 7.984a42.732 42.732 0 0 0 10.182-7.005l-6.171-5.978a34.214 34.214 0 0 1-7.271 4.999m-15.424 3.715c-3.661 0-7.185-.587-10.492-1.663l-3.256 7.974a42.271 42.271 0 0 0 13.748 2.296c4.812 0 9.433-.815 13.749-2.296l-3.256-7.974a33.839 33.839 0 0 1-10.493 1.663M8.558 46.569H0c.971 15.858 10.453 29.39 23.903 36.006l3.261-7.986A34.43 34.43 0 0 1 8.558 46.57M42.587 9.453c8.715 0 16.662 3.297 22.695 8.715l6.171-5.979C63.854 5.15 53.72.847 42.587.847 19.913.847 1.378 18.678 0 41.19h8.558C9.92 23.435 24.63 9.453 42.588 9.453" fill="#D2D2CA" mask="url(#b)">
#           </path>
#           <path d="M58.011 74.59l3.26 7.984a42.732 42.732 0 0 0 10.182-7.005l-6.171-5.978a34.214 34.214 0 0 1-7.271 4.999" fill="#4E131F" mask="url(#b)">
#           </path>
#           <path d="M42.587 78.305c-3.661 0-7.185-.587-10.492-1.663l-3.256 7.974a42.271 42.271 0 0 0 13.748 2.296c4.812 0 9.433-.815 13.749-2.296l-3.256-7.974a33.839 33.839 0 0 1-10.493 1.663" fill="#6D001F" mask="url(#b)">
#           </path>
#           <path d="M8.558 46.569H0c.971 15.858 10.453 29.39 23.903 36.006l3.261-7.986A34.43 34.43 0 0 1 8.558 46.57" fill="#8B0021" mask="url(#b)">
#           </path>
#           <path d="M42.587 9.453c8.715 0 16.662 3.297 22.695 8.715l6.171-5.979C63.854 5.15 53.72.847 42.587.847 19.913.847 1.378 18.678 0 41.19h8.558C9.92 23.435 24.63 9.453 42.588 9.453" fill="#AE132A" mask="url(#b)">
#           </path>
#           <path d="M19.83 32.06h-1.768v-1.19h4.814v1.189H21.11v4.67h-1.28zm5.32-1.188h1.278v2.318h2.357v-2.318h1.278v5.858h-1.278v-2.35h-2.357v2.351h-1.279zm7.6 0h4.383v1.146h-3.112v1.19h2.739v1.145h-2.74v1.23h3.154v1.147h-4.423zm10.548 3.348v-3.348h1.278v3.314c0 .954.473 1.448 1.253 1.448.78 0 1.254-.477 1.254-1.406v-3.356h1.278v3.306c0 1.774-.988 2.644-2.548 2.644s-2.515-.879-2.515-2.603m7.66-3.347h1.179l2.722 3.606v-3.606h1.261v5.858h-1.087l-2.814-3.724v3.724h-1.261zm7.908 5.858h1.278v-5.858h-1.278zm3.527-5.858h1.411l1.519 4.125 1.52-4.125h1.377l-2.35 5.9h-1.128zm8.017 0h4.382v1.146H71.68v1.19h2.739v1.145h-2.74v1.23h3.154v1.147H70.41zm9.427 2.845c.623 0 .98-.335.98-.829v-.016c0-.552-.382-.838-1.005-.838h-1.27v1.683h1.295zm-2.573-2.846h2.657c.738 0 1.31.21 1.692.595.324.326.498.786.498 1.339v.017c0 .945-.506 1.54-1.245 1.815l1.42 2.093h-1.494l-1.246-1.874h-1.004v1.874h-1.278v-5.859zm6.896 5.005l.755-.912c.523.435 1.071.711 1.735.711.523 0 .839-.208.839-.552v-.017c0-.326-.2-.493-1.17-.745-1.171-.3-1.927-.628-1.927-1.79v-.018c0-1.062.847-1.765 2.034-1.765.847 0 1.569.267 2.158.745l-.664.97c-.514-.36-1.02-.577-1.51-.577s-.748.226-.748.51v.018c0 .384.25.51 1.254.77 1.179.31 1.843.735 1.843 1.757v.017c0 1.163-.88 1.816-2.133 1.816a3.68 3.68 0 0 1-2.466-.938m7.062.854h1.279v-5.858h-1.279zm5.378-4.67h-1.768v-1.19h4.814v1.189h-1.767v4.67H96.6zm6.955 2.36l-2.234-3.549h1.495l1.386 2.352 1.41-2.352h1.454l-2.233 3.524v2.335h-1.278zm13.966-.602V33.8c0-1.004-.73-1.842-1.76-1.842s-1.742.82-1.742 1.825v.017c0 1.004.73 1.84 1.759 1.84 1.03 0 1.743-.819 1.743-1.823m-4.84 0V33.8c0-1.665 1.304-3.03 3.097-3.03s3.08 1.348 3.08 3.013v.017c0 1.665-1.304 3.03-3.097 3.03s-3.08-1.348-3.08-3.013m8.607-2.945h4.424v1.171h-3.146v1.247h2.773v1.172h-2.773v2.268h-1.278zm10.265 2.946V33.8c0-1.665 1.244-3.03 3.03-3.03 1.095 0 1.75.369 2.29.904l-.813.945c-.449-.41-.905-.66-1.485-.66-.98 0-1.686.82-1.686 1.824v.017c0 1.004.69 1.84 1.686 1.84.664 0 1.07-.267 1.527-.685l.813.828c-.597.645-1.261 1.047-2.383 1.047-1.71 0-2.98-1.331-2.98-3.013m7.677-2.945h1.279v2.318h2.356v-2.318h1.28v5.858h-1.28v-2.35h-2.356v2.351h-1.279zm7.659 5.858h1.279v-5.858h-1.279zm3.768-2.912V33.8c0-1.665 1.245-3.03 3.03-3.03 1.095 0 1.751.369 2.291.904l-.814.945c-.448-.41-.905-.66-1.485-.66-.98 0-1.685.82-1.685 1.824v.017c0 1.004.688 1.84 1.685 1.84.664 0 1.07-.267 1.527-.685l.813.828c-.597.645-1.261 1.047-2.382 1.047-1.71 0-2.98-1.331-2.98-3.013m11.013.461l-.772-1.9-.772 1.9h1.544zm-1.345-3.448h1.18l2.489 5.9h-1.336l-.53-1.314h-2.458l-.532 1.314h-1.303l2.49-5.9zm5.228 2.988V33.8c0-1.665 1.286-3.03 3.046-3.03 1.046 0 1.677.285 2.283.804l-.805.979c-.449-.377-.847-.595-1.52-.595-.929 0-1.667.83-1.667 1.825v.017c0 1.07.73 1.858 1.759 1.858.465 0 .88-.118 1.203-.352v-.837h-1.286v-1.113h2.524v2.545c-.598.51-1.42.929-2.482.929-1.81 0-3.055-1.281-3.055-3.013m12.64.001V33.8c0-1.004-.73-1.842-1.76-1.842s-1.743.82-1.743 1.825v.017c0 1.004.73 1.84 1.76 1.84 1.029 0 1.743-.819 1.743-1.823m-4.84 0V33.8c0-1.665 1.303-3.03 3.097-3.03 1.793 0 3.08 1.348 3.08 3.013v.017c0 1.665-1.304 3.03-3.097 3.03s-3.08-1.348-3.08-3.013" fill="#8B0021" mask="url(#b)">
#           </path>
#          </g>
#         </g>
#        </svg>
#        <img alt="The University of Chicago Harris School of Public Policy" class="affixed-logo-img" src=""/>
#        <h1 class="element-invisible">
#         The University of Chicago Harris School of Public Policy
#        </h1>
#       </div>
#      </a>
#      <span class="menu-button">
#      </span>
#      <div class="main-navigation__wrap">
#       <div class="block block-superfish block-superfishmain" id="block-mainnavigation">
#        <ul class="menu sf-menu sf-main sf-horizontal sf-style-none" id="superfish-main">
#         <li class="sf-depth-1 menuparent" id="main-menu-link-contentd54c2690-c3cf-4a5b-8f38-81a8e84dcc94">
#          <a accesskey="" class="sf-depth-1 menuparent" href="/about" id="" name="" rel="" style="" target="" title="">
#           About
#          </a>
#          <div class="main-navigation__cta">
#           <div class="main-navigation__cta-container">
#            <h3 class="main-navigation__cta-title">
#             Considering Applying?
#            </h3>
#            <p class="main-navigation__cta-statement">
#             Get a jump start now by creating an account with our simple online tool.
#            </p>
#            <div class="cta-wrapper">
#             <div class="button">
#              <a href="https://apply-harris.uchicago.edu/apply/">
#               Get Started
#              </a>
#             </div>
#            </div>
#            <p class="main-navigation__cta-note">
#             Still have questions? Check out
#             <a class="main-navigation__cta-note-link" href="/admissions">
#              Admissions
#             </a>
#             for details on requirements, deadlines, and financial aid.
#            </p>
#           </div>
#          </div>
#          <ul>
#           <li class="sf-depth-2 menuparent" id="main-menu-link-content020983d0-3324-423d-a28b-d16ee42b2240">
#            <a accesskey="" class="sf-depth-2 menuparent" href="/about/who-we-are" id="" name="" rel="" style="" target="" title="">
#             Who We Are
#            </a>
#            <div class="main-navigation__cta">
#             <div class="main-navigation__cta-container">
#              <h3 class="main-navigation__cta-title">
#               Considering Applying?
#              </h3>
#              <p class="main-navigation__cta-statement">
#               Get a jump start now by creating an account with our simple online tool.
#              </p>
#              <div class="cta-wrapper">
#               <div class="button">
#                <a href="https://apply-harris.uchicago.edu/apply/">
#                 Get Started
#                </a>
#               </div>
#              </div>
#              <p class="main-navigation__cta-note">
#               Still have questions? Check out
#               <a class="main-navigation__cta-note-link" href="/admissions">
#                Admissions
#               </a>
#               for details on requirements, deadlines, and financial aid.
#              </p>
#             </div>
#            </div>
#            <ul>
#             <li class="sf-depth-3 sf-no-children" id="main-menu-link-contentd7fcffa7-cc90-4e63-a5e9-7c8ad175c323">
#              <a class="sf-depth-3" href="/about/who-we-are/our-principles">
#               Our Principles
#              </a>
#             </li>
#             <li class="sf-depth-3 sf-no-children" id="main-menu-link-content6fe2ae85-c72b-476b-9ef3-63de056fdf8e">
#              <a accesskey="" class="sf-depth-3" href="/about/who-we-are/harris-by-the-numbers" id="" name="" rel="" style="" target="" title="">
#               Harris By The Numbers
#              </a>
#             </li>
#             <li class="sf-depth-3 sf-no-children" id="main-menu-link-content7526ceb4-191d-47b5-95b1-ae7c36a3364b">
#              <a accesskey="" class="sf-depth-3" href="/about/who-we-are/career-outcomes-report" id="" name="" rel="" style="" target="" title="">
#               Career Outcomes Report
#              </a>
#             </li>
#            </ul>
#           </li>
#           <li class="sf-depth-2 menuparent" id="main-menu-link-content0b811255-7ed0-49a9-8339-e0d8ea36ae4f">
#            <a accesskey="" class="sf-depth-2 menuparent" href="/about/keller-center" id="" name="" rel="" style="" target="" title="">
#             The Keller Center
#            </a>
#            <div class="main-navigation__cta">
#             <div class="main-navigation__cta-container">
#              <h3 class="main-navigation__cta-title">
#               Considering Applying?
#              </h3>
#              <p class="main-navigation__cta-statement">
#               Get a jump start now by creating an account with our simple online tool.
#              </p>
#              <div class="cta-wrapper">
#               <div class="button">
#                <a href="https://apply-harris.uchicago.edu/apply/">
#                 Get Started
#                </a>
#               </div>
#              </div>
#              <p class="main-navigation__cta-note">
#               Still have questions? Check out
#               <a class="main-navigation__cta-note-link" href="/admissions">
#                Admissions
#               </a>
#               for details on requirements, deadlines, and financial aid.
#              </p>
#             </div>
#            </div>
#            <ul>
#             <li class="sf-depth-3 sf-no-children" id="main-menu-link-content97f43b74-9db2-4b2d-8a09-3d12d2019919">
#              <a class="sf-depth-3" href="/about/keller-center/the-future-of-policy">
#               The Future of Policy
#              </a>
#             </li>
#             <li class="sf-depth-3 sf-no-children" id="main-menu-link-content1b53dafc-5868-4154-8979-97e6def36033">
#              <a class="sf-depth-3" href="/about/keller-center/your-impact">
#               Your Impact
#              </a>
#             </li>
#             <li class="sf-depth-3 sf-no-children" id="main-menu-link-contentfa8c1d08-edd5-4785-8df7-ce9702563d4c">
#              <a class="sf-depth-3" href="/about/keller-center/design-sustainability">
#               Design &amp; Sustainability
#              </a>
#             </li>
#             <li class="sf-depth-3 sf-no-children" id="main-menu-link-content3802b80b-703b-4762-b02d-4f33ac8e7884">
#              <a accesskey="" class="sf-depth-3" href="/about/keller-center/press-room" id="" name="" rel="" style="" target="" title="">
#               Press Room
#              </a>
#             </li>
#            </ul>
#           </li>
#           <li class="sf-depth-2 menuparent" id="main-menu-link-content269112f3-da00-4884-ad66-b0f1169cd34c">
#            <a accesskey="" class="sf-depth-2 menuparent" href="/about/leadership" id="" name="" rel="" style="" target="" title="">
#             Leadership
#            </a>
#            <div class="main-navigation__cta">
#             <div class="main-navigation__cta-container">
#              <h3 class="main-navigation__cta-title">
#               Considering Applying?
#              </h3>
#              <p class="main-navigation__cta-statement">
#               Get a jump start now by creating an account with our simple online tool.
#              </p>
#              <div class="cta-wrapper">
#               <div class="button">
#                <a href="https://apply-harris.uchicago.edu/apply/">
#                 Get Started
#                </a>
#               </div>
#              </div>
#              <p class="main-navigation__cta-note">
#               Still have questions? Check out
#               <a class="main-navigation__cta-note-link" href="/admissions">
#                Admissions
#               </a>
#               for details on requirements, deadlines, and financial aid.
#              </p>
#             </div>
#            </div>
#            <ul>
#             <li class="sf-depth-3 sf-no-children" id="main-menu-link-content27a51cfe-f20a-45a6-acb1-f640d23b3bdb">
#              <a accesskey="" class="sf-depth-3" href="/about/leadership/meet-our-new-dean" id="" name="" rel="" style="" target="" title="">
#               Meet Our Dean
#              </a>
#             </li>
#             <li class="sf-depth-3 sf-no-children" id="main-menu-link-contentbe92591e-e9c5-4474-b8b6-09eb05316b23">
#              <a class="sf-depth-3" href="/about/leadership/deans-office">
#               Dean's Office
#              </a>
#             </li>
#             <li class="sf-depth-3 sf-no-children" id="main-menu-link-content8e384ed3-c604-41ea-a793-b9599a17d87d">
#              <a class="sf-depth-3" href="/about/leadership/harris-council">
#               Harris Council
#              </a>
#             </li>
#             <li class="sf-depth-3 sf-no-children" id="main-menu-link-content2a5592d1-3ee0-46ee-bea0-7ee53a9b263f">
#              <a accesskey="" class="sf-depth-3" href="/about/leadership/alumni-council" id="" name="" rel="" style="" target="" title="">
#               Alumni Council
#              </a>
#             </li>
#             <li class="sf-depth-3 sf-no-children" id="main-menu-link-content75f12bd9-6d74-48ed-b46a-81ec94e6285b">
#              <a class="sf-depth-3" href="/about/leadership/diversity-council">
#               Diversity &amp; Inclusion Advisory Board
#              </a>
#             </li>
#            </ul>
#           </li>
#           <li class="sf-depth-2 menuparent" id="main-menu-link-content42cc1c22-2f87-4e91-881b-2b19414f889e">
#            <a accesskey="" class="sf-depth-2 menuparent" href="/about/history" id="" name="" rel="" style="" target="" title="">
#             History
#            </a>
#            <div class="main-navigation__cta">
#             <div class="main-navigation__cta-container">
#              <h3 class="main-navigation__cta-title">
#               Considering Applying?
#              </h3>
#              <p class="main-navigation__cta-statement">
#               Get a jump start now by creating an account with our simple online tool.
#              </p>
#              <div class="cta-wrapper">
#               <div class="button">
#                <a href="https://apply-harris.uchicago.edu/apply/">
#                 Get Started
#                </a>
#               </div>
#              </div>
#              <p class="main-navigation__cta-note">
#               Still have questions? Check out
#               <a class="main-navigation__cta-note-link" href="/admissions">
#                Admissions
#               </a>
#               for details on requirements, deadlines, and financial aid.
#              </p>
#             </div>
#            </div>
#            <ul>
#             <li class="sf-depth-3 sf-no-children" id="main-menu-link-content6ae9b4e7-a9a9-4fa0-8d31-9fd7cdf88792">
#              <a class="sf-depth-3" href="/about/history/history-of-harris">
#               History of Harris
#              </a>
#             </li>
#             <li class="sf-depth-3 sf-no-children" id="main-menu-link-contentb35ffb08-cf92-4d82-a4a7-5191ea4befe6">
#              <a class="sf-depth-3" href="/about/history/legacy-of-irving-b-harris">
#               Legacy of Irving B. Harris
#              </a>
#             </li>
#            </ul>
#           </li>
#           <li class="sf-depth-2 menuparent" id="main-menu-link-contentcd42cda4-54de-465b-8aa0-91d77b122b50">
#            <a class="sf-depth-2 menuparent" href="/about/diversity-inclusion">
#             Diversity &amp; Inclusion
#            </a>
#            <div class="main-navigation__cta">
#             <div class="main-navigation__cta-container">
#              <h3 class="main-navigation__cta-title">
#               Considering Applying?
#              </h3>
#              <p class="main-navigation__cta-statement">
#               Get a jump start now by creating an account with our simple online tool.
#              </p>
#              <div class="cta-wrapper">
#               <div class="button">
#                <a href="https://apply-harris.uchicago.edu/apply/">
#                 Get Started
#                </a>
#               </div>
#              </div>
#              <p class="main-navigation__cta-note">
#               Still have questions? Check out
#               <a class="main-navigation__cta-note-link" href="/admissions">
#                Admissions
#               </a>
#               for details on requirements, deadlines, and financial aid.
#              </p>
#             </div>
#            </div>
#            <ul>
#             <li class="sf-depth-3 sf-no-children" id="main-menu-link-content0c51fd6a-e763-4b52-a952-1a1f6900fc67">
#              <a class="sf-depth-3" href="/about/diversity-inclusion/our-commitment">
#               Our Commitment
#              </a>
#             </li>
#             <li class="sf-depth-3 sf-no-children" id="main-menu-link-contenta39a4e20-0d4e-40e6-823a-ac8eeab5b27b">
#              <a class="sf-depth-3" href="/about/diversity-inclusion/roadmap-progress">
#               Roadmap &amp; Progress
#              </a>
#             </li>
#             <li class="sf-depth-3 sf-no-children" id="main-menu-link-content5cc0f49d-3b7d-4a2e-81b3-d33f446ec2b5">
#              <a class="sf-depth-3" href="/about/diversity-inclusion/community">
#               D&amp;I Community
#              </a>
#             </li>
#             <li class="sf-depth-3 sf-no-children" id="main-menu-link-content550f489d-c8bc-4299-a3fd-cf97951fe194">
#              <a class="sf-depth-3" href="/about/diversity-inclusion/resources">
#               Resources
#              </a>
#             </li>
#             <li class="sf-depth-3 sf-no-children" id="main-menu-link-content9095ae10-e8e0-4f25-9d70-9d61aefa661e">
#              <a class="sf-depth-3" href="/about/diversity-inclusion/news-events">
#               News &amp; Events
#              </a>
#             </li>
#            </ul>
#           </li>
#          </ul>
#         </li>
#         <li class="active-trail sf-depth-1 menuparent" id="main-menu-link-content9da6182e-cd2d-428f-9710-3b903002082a">
#          <a accesskey="" class="sf-depth-1 menuparent" href="/academics" id="" name="" rel="" style="" target="" title="">
#           Academics
#          </a>
#          <div class="main-navigation__cta">
#           <div class="main-navigation__cta-container">
#            <h3 class="main-navigation__cta-title">
#             Considering Applying?
#            </h3>
#            <p class="main-navigation__cta-statement">
#             Get a jump start now by creating an account with our simple online tool.
#            </p>
#            <div class="cta-wrapper">
#             <div class="button">
#              <a href="https://apply-harris.uchicago.edu/apply/">
#               Get Started
#              </a>
#             </div>
#            </div>
#            <p class="main-navigation__cta-note">
#             Still have questions? Check out
#             <a class="main-navigation__cta-note-link" href="/admissions">
#              Admissions
#             </a>
#             for details on requirements, deadlines, and financial aid.
#            </p>
#           </div>
#          </div>
#          <ul>
#           <li class="active-trail sf-depth-2 menuparent" id="main-menu-link-content3a71c320-c465-4d06-90a9-4b5a59f8de7e">
#            <a accesskey="" class="sf-depth-2 menuparent" href="/academics/degrees" id="" name="" rel="" style="" target="" title="">
#             Degrees
#            </a>
#            <div class="main-navigation__cta">
#             <div class="main-navigation__cta-container">
#              <h3 class="main-navigation__cta-title">
#               Considering Applying?
#              </h3>
#              <p class="main-navigation__cta-statement">
#               Get a jump start now by creating an account with our simple online tool.
#              </p>
#              <div class="cta-wrapper">
#               <div class="button">
#                <a href="https://apply-harris.uchicago.edu/apply/">
#                 Get Started
#                </a>
#               </div>
#              </div>
#              <p class="main-navigation__cta-note">
#               Still have questions? Check out
#               <a class="main-navigation__cta-note-link" href="/admissions">
#                Admissions
#               </a>
#               for details on requirements, deadlines, and financial aid.
#              </p>
# ...
#           Careers at Harris
#          </a>
#         </li>
#         <li class="menu-item">
#          <a accesskey="" data-drupal-link-system-path="academics/programs-degrees/courses" href="/academics/programs-degrees/courses" id="" name="" rel="" style="" target="" title="">
#           Courses
#          </a>
#         </li>
#         <li class="menu-item">
#          <a accesskey="" data-drupal-link-system-path="node/6841" href="/directions" id="" name="" rel="" style="" target="" title="">
#           Directions
#          </a>
#         </li>
#         <li class="menu-item">
#          <a accesskey="" href="http://grad.uchicago.edu/about-us/privacy-notice/" id="" name="" rel="" style="" target="" title="">
#           Privacy Notice
#          </a>
#         </li>
#        </ul>
#       </nav>
#       <nav aria-label="Connect with Us" class="block block-menu navigation menu--social-media-menu" role="navigation">
#        <h2>
#         Connect with Us
#        </h2>
#        <ul class="menu">
#         <li class="footer-facebook menu-item">
#          <a accesskey="" href="https://www.facebook.com/harrispolicy" id="" name="" rel="" style="" target="" title="">
#           Facebook
#          </a>
#         </li>
#         <li class="footer-twitter menu-item">
#          <a accesskey="" href="https://twitter.com/HarrisPolicy" id="" name="" rel="" style="" target="" title="">
#           Twitter
#          </a>
#         </li>
#         <li class="footer-linkedin menu-item">
#          <a accesskey="" href="https://www.linkedin.com/edu/harris-school-of-public-policy-at-the-university-of-chicago-152025" id="" name="" rel="" style="" target="" title="">
#           LinkedIn
#          </a>
#         </li>
#         <li class="footer-youtube menu-item">
#          <a accesskey="" href="http://www.youtube.com/user/UChicagoHarris" id="" name="" rel="" style="" target="" title="">
#           Youtube
#          </a>
#         </li>
#        </ul>
#       </nav>
#       <div class="block block-block-content block-block-content3bec117c-2b91-4ce7-bab1-5a6d4c20816b" id="block-footerquestionsblock">
#        <div class="clearfix text-formatted field field--name-body field--type-text-with-summary field--label-hidden field__item">
#         <div class="block-contact-block">
#          <h2 style=" width: 100%;">
#           Questions?
#          </h2>
#          <div class="questions-button-wrapper">
#           <a class="button questions primary-button" href="/contact-us" style="font-size: 12px; padding: 2px 40px; margin: 10px 0;">
#            Contact Us
#           </a>
#          </div>
#         </div>
#         <style type="text/css">
#          <!--/*--><![CDATA[/* ><!--*/
# questions-button-wrapper{text-align: center; padding-top: 12px;}
# @media (min-width: 1100px){.questions-button-wrapper{padding: 0; float: left; padding-top: 24px; width: 100%; text-align: left;} }
# a.button.questions:hover:after{z-index:-1;}
# a.button.questions:hover{color: #ae132a;}
# a.button.questions{
#     border: 2px solid #ae132a;
#     background: #ae132a;
#     z-index: 2;
#     color: #fff;
# }
#
# /*--><!]]>*/
#         </style>
#        </div>
#       </div>
#       <div class="block block-block-content block-block-content379f8bee-93e1-4b96-82ae-3745d7d58306" id="block-measuredmarketingpixel">
#        <div class="clearfix text-formatted field field--name-body field--type-text-with-summary field--label-hidden field__item">
#         <script async="" type="text/javascript">
#          <!--//--><![CDATA[// ><!--
# var d=document,s="https://a.smtrk.net/trk?t=s&i=5bcdf95d65e3641d4cf0829e&p=t,i,x&s=72cb0155755cd58de7d7676aad9c3981&r="+escape(d.referrer)+"&u="+escape(d.URL),n=d.createElement("script"),e=d.getElementsByTagName("script")[0];n.async=!0,n.src=s,e.parentNode.insertBefore(n,e);
# //--><!]]>
#         </script>
#         <style type="text/css">
#          <!--/*--><![CDATA[/* ><!--*/
#
# #block-measuredmarketingpixel{display:none; z-index: -10;}
#
# /*--><!]]>*/
#         </style>
#        </div>
#       </div>
#       <div class="block block-block-content block-block-content82bbd380-e310-4fdd-9243-13d5a30e79bd" id="block-linkedinsitewidepixeltracking">
#        <div class="clearfix text-formatted field field--name-body field--type-text-with-summary field--label-hidden field__item">
#         <script type="text/javascript">
#          <!--//--><![CDATA[// ><!--
#
# _linkedin_partner_id = "947153";
# window._linkedin_data_partner_ids = window._linkedin_data_partner_ids || [];
# window._linkedin_data_partner_ids.push(_linkedin_partner_id);
#
# //--><!]]>
#         </script>
#         <script type="text/javascript">
#          <!--//--><![CDATA[// ><!--
#
# (function(){var s = document.getElementsByTagName("script")[0];
# var b = document.createElement("script");
# b.type = "text/javascript";b.async = true;
# b.src = "https://snap.licdn.com/li.lms-analytics/insight.min.js";
# s.parentNode.insertBefore(b, s);})();
#
# //--><!]]>
#         </script>
#         <noscript>
#          <img alt="" height="1" src="https://px.ads.linkedin.com/collect/?pid=947153&amp;fmt=gif" style="display:none;" width="1"/>
#         </noscript>
#        </div>
#       </div>
#       <div class="block block-block-content block-block-content67689b46-4603-426e-9ae9-98e6b3ca35c6" id="block-mobilemenufixcss">
#        <div class="clearfix text-formatted field field--name-body field--type-text-with-summary field--label-hidden field__item">
#         <style>
#          <!--/*--><![CDATA[/* ><!--*/
# @media only screen and (max-width: 900px) { .main-navigation__wrap.sub-menu ul.sf-menu li.sf-depth-1.keep-visible .inner-menu-column > ul {z-index: 0;}}
# /*--><!]]>*/
#         </style>
#        </div>
#       </div>
#       <div class="block block-block-content block-block-content5de1b834-dfdd-45b7-b36e-e4315a9a7db3" id="block-alertheader">
#        <div class="clearfix text-formatted field field--name-body field--type-text-with-summary field--label-hidden field__item">
#         <link href="https://use.fontawesome.com/14fb473629.css" media="all" rel="stylesheet"/>
#         <script>
#          <!--//--><![CDATA[// ><!--
#
# /*document.getElementsByClassName('dialog-off-canvas-main-canvas')[0].insertAdjacentHTML('beforebegin','<a class="ss-standard ss-alert" href="https://harris.uchicago.edu/coronavirus-updates" id="alert_banner"><p>Updates on coronavirus for the Harris community');*/
# document.getElementsByClassName('dialog-off-canvas-main-canvas')[0].insertAdjacentHTML('beforebegin',
#     '<a class="ss-standard ss-alert" href="https://goforward.uchicago.edu/" id="alert_banner" title="University Covid-19 Updates"><p>University Covid-19 Updates');
#
# //--><!]]>
#         </script>
#         <style type="text/css">
#          <!--/*--><![CDATA[/* ><!--*/
# #alert_banner:focus:before, #alert_banner:hover:before {color: #f8a429;}
# #alert_banner:before {
#     clear: both;
#     display: block;
#     color: #282828;
#     vertical-align: middle;
#     margin-bottom: .25em;
# }
# /*
# .ss-alert:before, .ss-alert.right:after {
#     content: '⚠';
#     font-family: FontAwesome;
#     content: '\f071';
# }
# */
# #alert_banner {
#     display: block;
#     padding: 1em 2%;
#     text-align: center;
#     color: #000;
#     border-bottom: 1px solid #000;
#     font-family: 'Gotham A', 'Gotham B','HelveticaNeue','Helvetica Neue','HelveticaNeueRoman','HelveticaNeue-Roman','Helvetica Neue Roman','TeXGyreHerosRegular','Helvetica','Tahoma','Geneva','Arial',sans-serif;
#     font-weight: 500;
#     font-style: normal;
#     font-size: .9em;
#     line-height: 1.5em;
#     letter-spacing: normal;
#     line-height: 1em;
#     background-color: #f9b64e;
#     /*background-image: linear-gradient(45deg, rgba(255,255,255,0.15) 25%, transparent 25%, transparent 50%, rgba(255,255,255,0.15) 50%, rgba(255,255,255,0.15) 75%, transparent 75%, transparent);*/
#     -webkit-background-size: 40px 40px;
#     background-size: 40px 40px;
#     transition: background .25s;
# }
# #alert_banner:focus, #alert_banner:hover {
#     color: #f8a429;
#     background-color: #000;
#     text-decoration: none;
# }
# #alert_banner p{ margin: .5em .5em;}
# #alert_banner{
#     padding: 0.35em 2%;
#     font-size: 0.78em;
# }
#
# /*--><!]]>*/
#         </style>
#        </div>
#       </div>
#       <div class="block block-block-content block-block-contentf48d9899-238b-4acb-b5d9-aa2c52ab3ed1" id="block-hubspottrackingcode">
#        <div class="clearfix text-formatted field field--name-body field--type-text-with-summary field--label-hidden field__item">
#         <!-- Start of HubSpot Embed Code -->
#         <script async="" defer="defer" id="hs-script-loader" src="//js.hs-scripts.com/7087380.js" type="text/javascript">
#         </script>
#         <!-- End of HubSpot Embed Code -->
#        </div>
#       </div>
#       <div class="block block-block-content block-block-content667c4369-32f5-4c70-8279-a70343a26fc5" id="block-harriscssoverrides">
#        <div class="clearfix text-formatted field field--name-body field--type-text-with-summary field--label-hidden field__item">
#         <style type="text/css">
#          <!--/*--><![CDATA[/* ><!--*/
# .block-superfishmain .inner-menu-row a[href~="/academics/undergraduate-program"] ~ ul.sf-hidden,
# .block-superfishmain .inner-menu-row a[href~="/academics/undergraduate-program"] ~ ul li,
# .block-superfishmain .inner-menu-row a[href~="/academics/undergraduate"] ~ ul li,
# .block-superfishmain .inner-menu-row a[href~="/academics/undergraduate"] ~ ul.sf-hidden {
#     display: none !important;
# }
# .block-superfishmain .inner-menu-row a[href~="/news-events/not-another-politics-podcast"] ~ ul.sf-hidden,
# .block-superfishmain .inner-menu-row a[href~="/news-events/not-another-politics-podcast"] ~ ul li {   display: none !important;}
# ul#superfish-main ul.sf-hidden:empty{display: none !important;}
# ul.sf-hidden:empty{display: none;}
# ul.chosen-results:empty{display: none;}
# ul:empty{display: none;}
#
# .block-superfishmain .inner-menu-row a.centers + ul li,
# .block-superfishmain .inner-menu-row a.centers + ul.sf-hidden,
# ul#superfish-main.sfHoverActive li.sf-depth-1:hover .inner-menu-row a.centers + ul.sf-hidden {
#     display: none !important;
# }
#
# /*--><!]]>*/
#         </style>
#        </div>
#       </div>
#      </div>
#     </footer>
#    </div>
#   </div>
#   <script data-drupal-selector="drupal-settings-json" type="application/json">
#    {"path":{"baseUrl":"\/","scriptPath":null,"pathPrefix":"","currentPath":"node\/7501","currentPathIsAdmin":false,"isFront":false,"currentLanguage":"en"},"pluralDelimiter":"\u0003","suppressDeprecationErrors":true,"ajaxPageState":{"libraries":"addtoany\/addtoany,better_exposed_filters\/general,classy\/base,classy\/file,classy\/messages,classy\/node,core\/html5shiv,core\/normalize,google_analytics\/google_analytics,harris_theme\/fonts,harris_theme\/global-styling,paragraphs\/drupal.paragraphs.unpublished,superfish\/superfish,superfish\/superfish_hoverintent,superfish\/superfish_smallscreen,superfish\/superfish_supersubs,superfish\/superfish_supposition,system\/base,views\/views.module","theme":"harris_theme","theme_token":null},"ajaxTrustedUrl":{"\/search":true},"google_analytics":{"trackOutbound":true,"trackMailto":true,"trackDownload":true,"trackDownloadExtensions":"7z|aac|arc|arj|asf|asx|avi|bin|csv|doc(x|m)?|dot(x|m)?|exe|flv|gif|gz|gzip|hqx|jar|jpe?g|js|mp(2|3|4|e?g)|mov(ie)?|msi|msp|pdf|phps|png|ppt(x|m)?|pot(x|m)?|pps(x|m)?|ppam|sld(x|m)?|thmx|qtm?|ra(m|r)?|sea|sit|tar|tgz|torrent|txt|wav|wma|wmv|wpd|xls(x|m|b)?|xlt(x|m)|xlam|xml|z|zip","trackDomainMode":2,"trackCrossDomains":["harris.uchicago.edu, apply-harris.uchicago.edu"]},"superfish":{"superfish-main":{"id":"superfish-main","sf":{"animation":{"opacity":"show","height":"show"},"speed":"fast","autoArrows":false,"dropShadows":false},"plugins":{"smallscreen":{"mode":"window_width","breakpoint":900,"title":"Main navigation"},"supposition":true,"supersubs":true}}},"user":{"uid":0,"permissionsHash":"d6ee0468f2be400ea79a72aa6a398b93498d88dc871240bc02ab60d7a0145bb8"}}
#   </script>
#   <script src="/core/assets/vendor/jquery/jquery.min.js?v=3.5.1">
#   </script>
#   <script src="/core/assets/vendor/jquery-once/jquery.once.min.js?v=2.2.3">
#   </script>
#   <script src="/core/misc/drupalSettingsLoader.js?v=8.9.14">
#   </script>
#   <script src="/core/misc/drupal.js?v=8.9.14">
#   </script>
#   <script src="/core/misc/drupal.init.js?v=8.9.14">
#   </script>
#   <script src="/core/assets/vendor/jquery.ui/ui/data-min.js?v=1.12.1">
#   </script>
#   <script src="/core/assets/vendor/jquery.ui/ui/disable-selection-min.js?v=1.12.1">
#   </script>
#   <script src="/core/assets/vendor/jquery.ui/ui/form-min.js?v=1.12.1">
#   </script>
#   <script src="/core/assets/vendor/jquery.ui/ui/labels-min.js?v=1.12.1">
#   </script>
#   <script src="/core/assets/vendor/jquery.ui/ui/jquery-1-7-min.js?v=1.12.1">
#   </script>
#   <script src="/core/assets/vendor/jquery.ui/ui/scroll-parent-min.js?v=1.12.1">
#   </script>
#   <script src="/core/assets/vendor/jquery.ui/ui/tabbable-min.js?v=1.12.1">
#   </script>
#   <script src="/core/assets/vendor/jquery.ui/ui/unique-id-min.js?v=1.12.1">
#   </script>
#   <script src="/core/assets/vendor/jquery.ui/ui/version-min.js?v=1.12.1">
#   </script>
#   <script src="/core/assets/vendor/jquery.ui/ui/escape-selector-min.js?v=1.12.1">
#   </script>
#   <script src="/core/assets/vendor/jquery.ui/ui/focusable-min.js?v=1.12.1">
#   </script>
#   <script src="/core/assets/vendor/jquery.ui/ui/ie-min.js?v=1.12.1">
#   </script>
#   <script src="/core/assets/vendor/jquery.ui/ui/keycode-min.js?v=1.12.1">
#   </script>
#   <script src="/core/assets/vendor/jquery.ui/ui/plugin-min.js?v=1.12.1">
#   </script>
#   <script src="/core/assets/vendor/jquery.ui/ui/safe-active-element-min.js?v=1.12.1">
#   </script>
#   <script src="/core/assets/vendor/jquery.ui/ui/safe-blur-min.js?v=1.12.1">
#   </script>
#   <script src="/core/assets/vendor/jquery.ui/ui/widget-min.js?v=1.12.1">
#   </script>
#   <script async="" src="https://static.addtoany.com/menu/page.js">
#   </script>
#   <script src="/modules/contrib/addtoany/js/addtoany.js?v=8.9.14">
#   </script>
#   <script src="/modules/contrib/google_analytics/js/google_analytics.js?v=8.9.14">
#   </script>
#   <script src="/core/assets/vendor/jquery.ui/ui/widgets/tabs-min.js?v=1.12.1">
#   </script>
#   <script src="/core/misc/progress.js?v=8.9.14">
#   </script>
#   <script src="/core/misc/ajax.js?v=8.9.14">
#   </script>
#   <script src="/core/themes/stable/js/ajax.js?v=8.9.14">
#   </script>
#   <script src="/themes/custom/harris_theme/js/jquery.fitvids.js?v=1.21">
#   </script>
#   <script src="/themes/custom/harris_theme/js/chosen.jquery.js?v=1.21">
#   </script>
#   <script src="/themes/custom/harris_theme/js/jquery.matchHeight.js?v=1.21">
#   </script>
#   <script src="/themes/custom/harris_theme/js/classie.js?v=1.21">
#   </script>
#   <script src="/themes/custom/harris_theme/js/script.js?v=1.21">
#   </script>
#   <script src="/themes/custom/harris_theme/js/tabs_slideshow.js?v=1.21">
#   </script>
#   <script src="/themes/custom/harris_theme/js/slick.js?v=1.21">
#   </script>
#   <script src="/themes/custom/harris_theme/js/megamenu.js?v=1.21">
#   </script>
#   <script src="/themes/custom/harris_theme/js/ambientvideo.js?v=1.21">
#   </script>
#   <script src="/themes/custom/harris_theme/js/microsite.js?v=1.21">
#   </script>
#   <script src="/modules/contrib/better_exposed_filters/js/better_exposed_filters.js?v=4.x">
#   </script>
#   <script src="/libraries/superfish/superfish.js?qsquwr">
#   </script>
#   <script src="/libraries/superfish/jquery.hoverIntent.minified.js?qsquwr">
#   </script>
#   <script src="/libraries/superfish/sfsmallscreen.js?qsquwr">
#   </script>
#   <script src="/libraries/superfish/supposition.js?qsquwr">
#   </script>
#   <script src="/libraries/superfish/supersubs.js?qsquwr">
#   </script>
#   <script src="/modules/contrib/superfish/js/superfish.js?v=2.0">
#   </script>
#   <script type="text/javascript">
#    window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","licenseKey":"e43e9c38fc","applicationID":"70697360","transactionName":"NgBRMRMEDEUHV0UNWw9KcgYVDA1YSXBDEUQACW8LDgEHaiVbXxBGDglfABM5LFkCUWcNURYmXAsVFw1aClFDSQoXDFYS","queueTime":0,"applicationTime":1796,"atts":"GkdSR1seH0s=","errorBeacon":"bam.nr-data.net","agent":""}
#   </script>
#  </body>
# </html>

# %%
#find all text
print(soup.get_text())
# Out:
# Master of Public Policy (MPP) | The University of Chicago Harris School of Public Policy
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   Skip to main content
#
#
#
#
#
#
#
#
# Utility
#
#
# Search
#
#
# Log in
#
#
# Directory
#
#
# Hire Harris
#
#
#
# Find Talent
#
#
# Find Work
#
#
#
#
# Info For
#
#
#
# Prospective Students
#
#
# Admitted Students (Full-Time)
#
#
# New EMP Students
#
#
# Current Students
#
#
# Faculty and Staff
#
#
# Alumni
#
#
# Media
#
#
#
#
# Support Harris
#
#
#
# Ways to Give
#
#
# Harris Society
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sort
#
#
#
#
#
#
#
#
# Older first
#
#
#
# Most recent
#
#
#
# Less relevant
#
#
#
# Most relevant
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Page 1
#
# The University of Chicago Harris School of Public Policy
#
#
#
#
#
#
# AboutConsidering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.Who We AreConsidering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.Our PrinciplesHarris By The NumbersCareer Outcomes ReportThe Keller CenterConsidering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.The Future of PolicyYour ImpactDesign & SustainabilityPress RoomLeadershipConsidering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.Meet Our DeanDean's OfficeHarris CouncilAlumni CouncilDiversity & Inclusion Advisory BoardHistoryConsidering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.History of HarrisLegacy of Irving B. HarrisDiversity & InclusionConsidering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.Our CommitmentRoadmap & ProgressD&I CommunityResourcesNews & EventsAcademicsConsidering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.DegreesConsidering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.Master of Public Policy (MPP)Evening Master’s ProgramMS in Computational Analysis and Public PolicyMA in Public Policy with Certificate in Research MethodsMA in Public PolicyMA in International Development and PolicyPhDNon-Degree ProgramsConsidering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.Credential ProgramsExecutive EducationCivic Leadership AcademyDesign Your PathConsidering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.CoursesCore CurriculumPractical ExperienceCertificatesPolicy AreasExpert GuideDegree ComparisonWorkshopsAcademic CalendarFaculty DirectoryUndergraduate ProgramConsidering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.OverviewThesisStudentsJoint DegreesTeamStudy Abroad in BarcelonaAdmissionsConsidering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.Why Public Policy?Applying to HarrisConsidering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.UChicago College Graduating ClassInternational StudentsFAQAdmissions ResourcesHarris Scholars ProgramRequirements & DeadlinesMeet with HarrisConsidering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial a ...
#
#
#
#
#
#
# Utility
#
#
# Search
#
#
# Log in
#
#
# Directory
#
#
# Hire Harris
#
#
#
# Find Talent
#
#
# Find Work
#
#
#
#
# Info For
#
#
#
# Prospective Students
#
#
# Admitted Students (Full-Time)
#
#
# New EMP Students
#
#
# Current Students
#
#
# Faculty and Staff
#
#
# Alumni
#
#
# Media
#
#
#
#
# Support Harris
#
#
#
# Ways to Give
#
#
# Harris Society
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sort
#
#
#
#
#
#
#
#
# Older first
#
#
#
# Most recent
#
#
#
# Less relevant
#
#
#
# Most relevant
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Breadcrumbs
#
# Breadcrumb
#
#
# Home
#
#
# Academics
#
#
# Degrees
#
#
#                   Master of Public Policy (MPP)
#
#
#
#
#
#
#
#
#
#
#
# Master of Public Policy (MPP)
#
#
#
# A two-year program for students interested in developing the analytical skills needed to take on today's pressing policy challenges.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# A two-year program for students interested in developing the analytical skills needed to take on today's pressing policy challenges.
#
#
#
#
# Back to Degrees
#
#
#
#
#
#
# Office of Admissions
#
#
#
#
# Email harrisadmissions@uchicago.edu
#
# 773.702.8401
#
#
#
#
#
#
#
# Across the public and private sectors, a new generation of data-minded leaders is needed to bring fresh thinking and different approaches to the world's most pressing policy challenges.
# The two-year MPP is a professional degree program designed to develop leaders who put evidence first. In course work, you'll build critical thinking and analytical skills in the core curriculum that teach you to make data-driven decisions now and throughout your career. Through applied experiences in Chicago and beyond, you’ll meet face-to-face with professionals in the field to analyze urgent policy problems and design solutions that work, using the latest science and technology.
# The core curriculum draws on a variety of disciplines and fields, including economics, sociology, political science, statistics, econometrics, political economy, organizational theory, and program evaluation, an ideal fit for students seeking a multidisciplinary approach to the study of public policy.
#
#  Read the Master of Public Policy Brochure (PDF, 2.5MB)
#
# Program Details
#
#
#
#
# Curriculum
#
# 18 graduate-level courses (1800 units of credit) with at least 12 Public Policy (PPHA) courses
#
#
# 6 core courses that provide a foundation in critical analysis, reflecting Harris's belief that mastering quantitative and analytical skills prepares students to be effective public policy leaders
#
# PPHA 30800 Analytical Politics I: Strategic Foundations or PPHA 41501 - PhD Game Theory (instructor approval required).
#
#
# PPHA 31610 Analytical Politics II: Political Institutions
#
#
# Statistics Sequence I. Choose one of the following:
#
# PPHA 31002 Statistics for Data Analysis I
#
# PPHA 31202 Advanced Statistics for Data Analysis I
#
# Any course in the PhD econometrics sequence (instructor approval required): PPHA 42000 or PPHA 42100, or PPHA 42200
#
#
#
# Statistics Sequence II. Choose one of the following:
# PPHA 31102 Statistics for Data Analysis II: Regressions
# PPHA 31302 Advanced Statistics for Data Analysis II
# Any course in the PhD econometrics sequence (instructor approval required): PPHA 42000 or PPHA 42100, or PPHA 42200
#
#
# Microeconomics Sequence I. Choose from the following:
#
#
#
# PPHA 32300 Principles of Microeconomics and Public Policy I
#
#
# PPHA 32310 Advanced Microeconomics for Public Policy I
#
#
# PPHA 44100 Principles of Microeconomics and Public Policy I (PhD sequence - instructor approval required)
#
#
#
# Microeconomics Sequence II. Choose from the following:
# PPHA 32400 Principles of Microeconomics and Public Policy II
# PPHA 32410 Advanced Microeconomics for Public Policy II
# PPHA 44200 Principles of Microeconomics and Public Policy II (PhD sequence - instructor approval required)
#
#
#
# Elective Options
#
# MPP students can explore special academic interests and fields as well as participate in internships and independent research complementing required course work.
#
#
# Students may choose to focus on an area of public policy, register for courses in departments and schools across the University, and take advantage of experiential opportunities to apply what they learn in the classroom to real-world problems.
#
#
#
#
#
#
# Other Requirements
#
# A cumulative GPA of 2.7 for all courses, based on a 4.0 scale
#
#
# A grade of C- or better for the 6 core courses
#
#
# Completion of the math requirement (support available)
#
# Pass algebra exam
#
#
# Pass calculus exam
#
#
# Completion of an applied experience requirement (more information)
#
# No more than 2 reading/research, independent study, or internship courses
#
#
# No more than 2 courses taken Pass/Fail (core courses cannot be taken pass/fail)
#
#
# Courses with grades of F, I, W, or with no reported grade do not apply toward the 18-course requirement for the program.
#
#
#
#
#
# Sample Schedule
# Year 1
# Autumn
# Microeconomics I (PPHA 32300)
# 	Option to take advanced PPHA 32310 or PhD level PPHA 44100
#
# Statistics for Data Analysis I (PPHA 31002)
# 	Option to take advanced PPHA 31202 or PhD level STAT 24400
#
# Analytical Politics I: Strategic Foundations (PPHA 30800) pr PhD Game Theory (PPHA 41501)
# Winter
# Microeconomics II (PPHA 32400)
# 	Option to take advanced PPHA 32410 or PhD level PPHA 44200
#
# Statistics for Data Analysis II: Regressions (PPHA 31102)
# 	Option to take advanced PPHA 31302, PhD level STAT 24400, or PhD level PPHA 42000
#
# Analytical Politics II: Political Institutions (PPHA 31610)
# Spring
# Elective
# Elective
# Elective
#
#
#
#
# Testimonials
# “Having attained a master’s of public policy, I have frameworks and tools that I use to formulate responses to complex issues in a deeper and more thoughtful way. The graduate degree in public policy offers an opportunity to step outside of narrow disciplines and learn from and amongst a diverse group of incredibly bright and talented people. I grew significantly as an individual through the friendships I developed and perspectives I gained from my peers. I now have a network across geographies of colleagues in a variety of professional disciplines that I utilize to stay connected to global issues and apply to my personal and professional pursuits.”
# —Eric Tawney (MPP'14), Investment Analyst at BlackRock
# “My Harris education helps me connect the dots and construct a more comprehensive view of how the Central Bank should produce its policy, including how to maintain low inflation and a stable exchange rate on a national scale. I am, ultimately, impacting my country’s economic policy by bridging the gap between academic research and policy practice.”
# —Andi Widianto (MPP'11), Economic Analyst at the Central Bank of Indonesia
# “I think the biggest difference between an economics degree and one in public policy is that those of us with public policy backgrounds better understand the political aspect, the incentives of various stakeholders, and how that impacts policy design and implementation. A lot of policies fail because of competing interests. The advantage that Harris graduates have is that we understand those incentives and interests. We know that it’s about more than just the economic and financial pieces. That informs our work and ultimately matters a lot.”
# —Oliver Azuara Herrera (MPP'02, PhD'11), Economics Officer at the Inter-American Development Bank
# “One thing Harris does is give you a really flexible toolkit that can be used in a lot of different ways in the policy arena.”
# —Elizabeth Kneebone (MPP'03 and recipient of the 2016 Harris Alumni Rising Star Award), Brookings Institution's Metropolitan Policy Program Fellow
# “On a day-to-day basis—in Chicago, in my district, in committee, on the floor, analyzing policy—the skill set I got at Harris is what I use the most.”
# —Mike Quigley (AM'85), US Representative for the 5th District of Illinois
#
#
#
#
#
#
#
#
#
#
#       Alumni profile
#
#
# Questions for Hilarie Koplow-McAdams, AM'87
#
#
#
#       The New Relic executive reflects on disruptive innovation and the need for more women leaders in Silicon Valley.
#
#
# Read more
#
#
#
#
# FAQs
#
#
#
#
#
# What can I do with a policy degree?
#
#
#
# What can I do with a policy degree?
# Since a public policy degree provides a set of research, analytical, communication, and management skills that are transferable across sectors and issue areas, graduates have flexibility in choosing their career paths.
# Public policy graduates often move back and forth between the public, private, and nonprofit sectors, or between international and US-based work. Harris graduates are highly sought-after specifically for their strategic skills, and many have gone on to be social entrepreneurs. Employers look for graduates to help understand and communicate complex data and information in a way that clearly and concisely supports effective decision-making. In the nonprofit sector, the analytical and program evaluation techniques learned can be useful in demonstrating the impact of an organization's programs, which can be useful for funding, governmental relations, and lobbying efforts.
# A public policy degree can also be beneficial in industries such as energy, health care, finance, transportation, telecommunications, education, or other heavily regulated industries that are impacted by laws or policy outcomes or have a dependency on lobbying and political influence. An understanding of policy can help professionals in those industries as they advance in their careers.
#
#
#
#
#
#
# I do not have a quantitative background. Can I handle the demanding coursework at Harris?
#
#
#
# I do not have a quantitative background. Can I handle the demanding coursework at Harris?
# Roughly one-third of our full-time students consider themselves as not having a strong quantitative background prior to applying to and enrolling at Harris. Many demonstrated their capability by scoring well on the GRE or taking supplemental quantitative courses prior to coming to Harris. We have all the resources necessary to ensure that enrolling students will excel in our core curriculum.
#
#
#
#
#
#
# Do you accept GMAT or LSAT in lieu of the GRE?
#
#
#
# Do you accept GMAT or LSAT in lieu of the GRE?
# For admissions to full-time programs, we will accept the GRE or the GMAT score. For those applicants who are currently enrolled in a joint-degree program with the Law School, we will consider your LSAT scores. (Note: Test scores are not required for the Evening Master's Program.)
#
#
#
#
#
#
#
# International Development
#
#
#
# I am interested in international development. Can I take classes in this area in this program?
# If you are interested in international development, we recommend exploring the Pearson Institute International Policy and Development (IPD) Certificate.
# The IPD is designed to prepare students for careers in government, non-governmental organizations, international organizations, or multinational corporations. The certificate’s curated list of electives is designed to allow students to explore multiple academic approaches to understanding development, including from economics, political science, statistics, and psychology.Learn more here.
#
#
#
#
#
#
#
#
#
# Apply Now - Make a Difference Today
#
#
#
# Start making a difference today.
#
# Request Info
# Apply Now
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Faculty Spotlight
#
#
# Ethan Bueno de Mesquita
#
# Sydney Stein Professor and Deputy Dean
#
#
#         Ethan Bueno de Mesquita, AB'96, is an applied game theorist whose research focuses on political violence—especially terrorism, insurgency, and rebellion—and on democratic accountability.
#
#
# Read more
#
#
#
#
#
#
# Recent News
#
#
#
#
# Study Shows Signs Pointing to a Peaceful Afghanistan Transition as US Withdraws May Be Misleading
#
#
#
#
# Mon., May 17, 2021
#
#
#
#
#
#
# Informing Presidential Decision-Making: A View from the Council of Economic Advisers
#
#
#
#
# Fri., May 14, 2021
#
#
#
#
#
# More news
#
#
#
#
# Upcoming Events
#
#
#
#
#
# Mentor Send-Off
#
#
#
#
#
# Mon., May 17, 2021 | 6:00 PM
#
#
#
#
# Virtual Program
# via Zoom, IL 60637
# United States
#
#
#
#
#
#
# Harris Insights: Q&A with Alumni
#
#
#
#
#
# Tue., May 18, 2021 | 5:30 PM
#
#
#
#
# A link will be sent to registered guests
# Chicago, IL 60637
# United States
#
#
#
#
# More events
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# You might also be interested in...
#
#
#
#
#
#
#
#
#
#
#
#
#
# May 20, 2021
#
#
#
#
# Bay Area Networking Event
#
#
#
# Read more
#
#
#
#
#
#
#
#
#
#
#
# May 11, 2021
#
#
#
# Student Profile: Josephine Lando, MPP Class of 2023
#
#
#
# Read more
#
#
#
#
#
#
#
#
#
#
#
# May 07, 2021
#
#
#
# Student Profile: Victor Hinardi, MPP Class of 2023 and 2020 Data and Policy Summer Scholar
#
#
#
# Read more
#
#
#
#
#
#
#
#
#
#
#
# May 04, 2021
#
#
#
# Student Profile: Jeremy Xu, MPP Class of 2023
#
#
#
# Read more
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Prospective Students
#
#
#
# How to Apply
#
#
# Why Public Policy
#
#
# Financial Aid
#
#
# Events
#
#
#
#
# Current Students
#
#
#
# Academic Advising & Support
#
#
# Financial Aid for Students
#
#
# Courses
#
#
# Course Evaluations
#
#
# Find a Job or Internship
#
#
# Disability Resources
#
#
#
#
# Faculty & Staff
#
#
#
# Room Reservations
#
#
# Academic Calendar
#
#
# Faculty Resources
#
#
# Faculty Access
#
#
# Human Resources
#
#
#
#
# Alumni
#
#
#
# News and Events
#
#
# Alumni Directory
#
#
# Get Involved
#
#
# Donate Now
#
#
#
#
#
#
#
#
#
#
# Footer menu
#
#
# The University of Chicago
#
#
# Apply
#
#
# Careers at Harris
#
#
# Courses
#
#
# Directions
#
#
# Privacy Notice
#
#
#
#
# Connect with Us
#
#
# Facebook
#
#
# Twitter
#
#
# LinkedIn
#
#
# Youtube
#
#
#
#
#
# Questions?
# Contact Us

# %%
all_links = soup.find_all("a")
for link in all_links:
    print(link.get("href"))
# Out:
# #main-content
# /search
# /user/login
# /directory
# /hireharris
# /findtalent
# /student-life/career-development
#
# /admissions
# /admitted-students
# /eveningprogram/admitted-students
# /gateways/current-students
# /gateways/faculty-staff
# /alumni
# /media
# /support-harris
# /support-harris/ways-to-give
# /support-harris/harris-society
# #
# /
# /about
# https://apply-harris.uchicago.edu/apply/
# /admissions
# /about/who-we-are
# https://apply-harris.uchicago.edu/apply/
# /admissions
# /about/who-we-are/our-principles
# /about/who-we-are/harris-by-the-numbers
# /about/who-we-are/career-outcomes-report
# /about/keller-center
# https://apply-harris.uchicago.edu/apply/
# /admissions
# /about/keller-center/the-future-of-policy
# /about/keller-center/your-impact
# /about/keller-center/design-sustainability
# /about/keller-center/press-room
# /about/leadership
# https://apply-harris.uchicago.edu/apply/
# /admissions
# /about/leadership/meet-our-new-dean
# /about/leadership/deans-office
# /about/leadership/harris-council
# /about/leadership/alumni-council
# /about/leadership/diversity-council
# /about/history
# https://apply-harris.uchicago.edu/apply/
# /admissions
# /about/history/history-of-harris
# /about/history/legacy-of-irving-b-harris
# /about/diversity-inclusion
# https://apply-harris.uchicago.edu/apply/
# /admissions
# /about/diversity-inclusion/our-commitment
# /about/diversity-inclusion/roadmap-progress
# /about/diversity-inclusion/community
# /about/diversity-inclusion/resources
# /about/diversity-inclusion/news-events
# /academics
# https://apply-harris.uchicago.edu/apply/
# /admissions
# /academics/degrees
# https://apply-harris.uchicago.edu/apply/
# /admissions
# /academics/degrees/master-public-policy-mpp
# /academics/degrees/evening-masters-program-part-time-ma
# /academics/degrees/ms-computational-analysis-public-policy-mscapp
# /academics/degrees/ma-public-policy-certificate-research-methods-macrm
# /academics/degrees/ma-public-policy
# /academics/degrees/ma-international-development-policy-maidp
# /academics/degrees/phd
# /academics/non-degree-programs
# https://apply-harris.uchicago.edu/apply/
# /admissions
# /academics/non-degree-programs/credential-programs
# /academics/non-degree-programs/executive-education
# /academics/non-degree-programs/civic-leadership-academy
# /academics/design-your-path
# https://apply-harris.uchicago.edu/apply/
# /admissions
# /academics/programs-degrees/courses
# /academics/design-your-path/core-curriculum
# /academics/design-your-path/practical-experience
# /academics/design-your-path/certificates
# /academics/design-your-path/policy-areas
# /academics/design-your-path/expert-guide
# /academics/design-your-path/degree-comparison
# /academics/design-your-path/workshops
# /academics/design-your-path/academic-calendar
# /directory?field_profile_type_target_id%5B0%5D=32&field_profile_type_target_id%5B1%5D=32&title=
# /academics/undergraduate
# https://apply-harris.uchicago.edu/apply/
# /admissions
# /academics/undergraduate/overview
# /academics/undergraduate/overview/thesis
# /academics/undergraduate/students
# /academics/undergraduate/joint-degrees
# /academics/undergraduate/team
# https://study-abroad.uchicago.edu/programs/barcelona-public-policy
# /admissions
# https://apply-harris.uchicago.edu/apply/
# /admissions
# /admissions/why-public-policy
# /admissions/applying-to-harris
# https://apply-harris.uchicago.edu/apply/
# /admissions
# /admissions/applying-to-harris/uchicago-college-graduating-class
# /admissions/applying-to-harris/international-students
# /admissions/applying-to-harris/FAQ
# /admissions/applying-to-harris/admissions-resources
# /admissions/applying-to-harris/harris-scholars-program
# /admissions/requirements-and-deadlines
# /admissions/meet-with-harris
# https://apply-harris.uchicago.edu/apply/
# /admissions
# /admissions/meet-with-harris/connect-with-our-students
# /admissions/meet-with-harris/schedule-visit
# /admissions/meet-with-harris/recruitment-team
# /admissions/meet-with-harris/diversity-day
# /admissions/financing-your-degree
# https://apply-harris.uchicago.edu/apply/
# /admissions
# /admissions/financing-your-degree/scholarships-fellowships
# /admissions/financing-your-degree/loans-work-study
# /admissions/financing-your-degree/third-party-funding
# /admissions/financing-your-degree/tuition-and-expenses
# /blog
# /admissions/request-information
# /student-life
# https://apply-harris.uchicago.edu/apply/
# /admissions
# /student-life/what-to-expect
# https://apply-harris.uchicago.edu/apply/
# /admissions
# /student-life/what-to-expect/orientation-to-graduation
# /student-life/what-to-expect/connect-with-your-community
# /student-life/harris-experience
# https://apply-harris.uchicago.edu/apply/
# /admissions
# /student-life/harris-experience/our-campus
# /student-life/harris-experience/city-chicago
# /student-life/harris-experience/mentor-program
# /student-life/harris-experience/student-organizations
# /student-life/harris-experience/leadership-credential
# /student-life/career-development
# https://apply-harris.uchicago.edu/apply/
# /admissions
# /student-life/career-development/consideringharris
# /student-life/career-development/applying-and-interviewing
# /student-life/career-development/alumnicareersupport
# /student-life/career-development/internshipsandfunding
# /student-life/career-development/international-students
# /student-life/career-development/FAQ
# /student-life/career-development/meet-cdo-team
# /student-life/dean-of-students-office
# https://apply-harris.uchicago.edu/apply/
# /admissions
# /student-life/dean-of-students-office/academic-advising
# /student-life/dean-of-students-office/writing-program
# /student-life/dean-of-students-office/academic-support-programs
# /student-life/dean-of-students-office/student-emergency-resources
# /student-life/dean-of-students-office/policies
# /research-impact
# https://apply-harris.uchicago.edu/apply/
# /admissions
# /research-impact/centers-institutes
# https://apply-harris.uchicago.edu/apply/
# /admissions
# /research-impact/centers-institutes/center-economic-policy
# /research-impact/centers-institutes/center-health-policy
# /research-impact/centers-institutes/center-human-potential-public-policy-chppp
# /research-impact/centers-institutes/center-impact-sciences
# /research-impact/centers-institutes/center-municipal-finance
# /research-impact/centers-institutes/center-survey-methodology
# /research-impact/centers-institutes/cyber-policy-initiative
# /research-impact/centers-institutes/family-self-sufficiency-data-center
# /research-impact/centers-institutes/affiliated-centers
# /research-impact/urban-labs
# /research-impact/initiatives-partnerships
# https://apply-harris.uchicago.edu/apply/
# /admissions
# /research-impact/initiatives-partnerships/national-partnerships
# /research-impact/initiatives-partnerships/international-partnerships
# /research-impact/faculty
# https://apply-harris.uchicago.edu/apply/
# /admissions
# /research-impact/alumni-impact
# /news-events
# https://apply-harris.uchicago.edu/apply/
# /admissions
# /news-events/news
# https://apply-harris.uchicago.edu/apply/
# /admissions
# /news-events/news/news
# /news-events/news/profile
# /news-events/news/research
# /news-events/news/in-the-news
# /news-events/events
# https://apply-harris.uchicago.edu/apply/
# /admissions
# /news-events/events/academic-conferences
# /news-events/events/admissions
# /news-events/events/alumni
# /news-events/events/students
# /news-events/events/special-events
# /news-events/events/visiting-speakers
# /news-events/events/past-events
# /news-events/events/international-policy-development-faculty-insight-series
# /news-events/not-another-politics-podcast
# https://apply-harris.uchicago.edu/apply/
# /admissions
# /news-events/podcasts-archive-radio-harris-day-one
# /news-events/20ish-questions
# /blog
# /search
# /user/login
# /directory
# /hireharris
# /findtalent
# /student-life/career-development
#
# /admissions
# /admitted-students
# /eveningprogram/admitted-students
# /gateways/current-students
# /gateways/faculty-staff
# /alumni
# /media
# /support-harris
# /support-harris/ways-to-give
# /support-harris/harris-society
# #
# /
# /academics
# /academics/degrees
# None
# /academics/degrees
# /node/5716
# mailto:harrisadmissions@uchicago.edu
# tel:773.702.8401
# https://harris.uchicago.edu/files/master_of_public_policy_brochure_0.pdf
# /academics/design-your-path/applied-experience
# /student-life/harris-experience/academic-support-programs
# https://harris.uchicago.edu/academics/design-your-path/applied-experience
# /news-events/news/questions-hilarie-koplow-mcadams-am87
# /news-events/news/questions-hilarie-koplow-mcadams-am87
# /node/6016
# /research-impact/alumni-impact
# /node/2801
# /student-life/harris-experience/academic-support-programs
# /node/2751
# /node/35526
# https://harris.uchicago.edu/academics/design-your-path/certificates/certificate-international-policy-development
# /node/2521
# https://harris.uchicago.edu/admissions/request-information
# https://apply-harris.uchicago.edu/apply/
# /directory/ethan-bueno-de-mesquita
# /directory/ethan-bueno-de-mesquita
# /directory/ethan-bueno-de-mesquita
# /news-events/news/study-shows-signs-pointing-peaceful-afghanistan-transition-us-withdraws-may-be
# /news-events/news/informing-presidential-decision-making-view-council-economic-advisers
# /news-events/news
# /news-events/events/mentor-send
# /news-events/events/harris-insights-qa-alumni
# /news-events/events
# /news-events/events/bay-area-networking-event
# /news-events/events/bay-area-networking-event
# /news-events/events/bay-area-networking-event
# /news-events/news/student-profile-josephine-lando-mpp-class-2023
# /news-events/news/student-profile-josephine-lando-mpp-class-2023
# /news-events/news/student-profile-josephine-lando-mpp-class-2023
# /news-events/news/student-profile-victor-hinardi-mpp-class-2023-and-2020-data-and-policy-summer
# /news-events/news/student-profile-victor-hinardi-mpp-class-2023-and-2020-data-and-policy-summer
# /news-events/news/student-profile-victor-hinardi-mpp-class-2023-and-2020-data-and-policy-summer
# /news-events/news/student-profile-jeremy-xu-mpp-class-2023
# /news-events/news/student-profile-jeremy-xu-mpp-class-2023
# /news-events/news/student-profile-jeremy-xu-mpp-class-2023
#
# /admissions/applying-to-harris
# /admissions/why-public-policy
# /admissions/financing-your-degree
# /news-events/events
#
# /gateways/current-students/academic-support
# /gateways/current-students/financial-aid
# /academics/programs-degrees/courses
# https://harris.uchicago.edu/course-evaluation-results
# /student-life/career-development
# /about/diversity-inclusion/resources/resources-for-students-with-disabilities
#
# https://25live.collegenet.com/pro/harrisuchicago
# /academics/design-your-path/academic-calendar
# /gateways/faculty-staff/instructor-resources
# https://facultyaccess.uchicago.edu
# /gateways/faculty-staff/human-resources
#
# /news-events
# http://www.uchicagoalumni.org/directory.html
# /alumni/get-involved
# /harrisgives
# http://www.uchicago.edu/
# https://apply-harris.uchicago.edu/apply/
# http://humanresources.uchicago.edu/jobs/
# /academics/programs-degrees/courses
# /directions
# http://grad.uchicago.edu/about-us/privacy-notice/
# https://www.facebook.com/harrispolicy
# https://twitter.com/HarrisPolicy
# https://www.linkedin.com/edu/harris-school-of-public-policy-at-the-university-of-chicago-152025
# http://www.youtube.com/user/UChicagoHarris
# /contact-us

# %%
type(all_links)
# Out:
# bs4.element.ResultSet

# %%
all_divs = soup.find_all("div")
for link in all_divs:
    print(link.get_text())
# Out:
# Utility
#
#
# Search
#
#
# Log in
#
#
# Directory
#
#
# Hire Harris
#
#
#
# Find Talent
#
#
# Find Work
#
#
#
#
# Info For
#
#
#
# Prospective Students
#
#
# Admitted Students (Full-Time)
#
#
# New EMP Students
#
#
# Current Students
#
#
# Faculty and Staff
#
#
# Alumni
#
#
# Media
#
#
#
#
# Support Harris
#
#
#
# Ways to Give
#
#
# Harris Society
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sort
#
#
#
#
#
#
#
#
# Older first
#
#
#
# Most recent
#
#
#
# Less relevant
#
#
#
# Most relevant
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Page 1
#
# The University of Chicago Harris School of Public Policy
#
#
#
#
#
#
# AboutConsidering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.Who We AreConsidering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.Our PrinciplesHarris By The NumbersCareer Outcomes ReportThe Keller CenterConsidering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.The Future of PolicyYour ImpactDesign & SustainabilityPress RoomLeadershipConsidering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.Meet Our DeanDean's OfficeHarris CouncilAlumni CouncilDiversity & Inclusion Advisory BoardHistoryConsidering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.History of HarrisLegacy of Irving B. HarrisDiversity & InclusionConsidering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.Our CommitmentRoadmap & ProgressD&I CommunityResourcesNews & EventsAcademicsConsidering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.DegreesConsidering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.Master of Public Policy (MPP)Evening Master’s ProgramMS in Computational Analysis and Public PolicyMA in Public Policy with Certificate in Research MethodsMA in Public PolicyMA in International Development and PolicyPhDNon-Degree ProgramsConsidering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.Credential ProgramsExecutive EducationCivic Leadership AcademyDesign Your PathConsidering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.CoursesCore CurriculumPractical ExperienceCertificatesPolicy AreasExpert GuideDegree ComparisonWorkshopsAcademic CalendarFaculty DirectoryUndergraduate ProgramConsidering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.OverviewThesisStudentsJoint DegreesTeamStudy Abroad in BarcelonaAdmissionsConsidering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.Why Public Policy?Applying to HarrisConsidering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.UChicago College Graduating ClassInternational StudentsFAQAdmissions ResourcesHarris Scholars ProgramRequirements & DeadlinesMeet with HarrisConsidering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial a ...
#
#
#
#
#
#
# Utility
#
#
# Search
#
#
# Log in
#
#
# Directory
#
#
# Hire Harris
#
#
#
# Find Talent
#
#
# Find Work
#
#
#
#
# Info For
#
#
#
# Prospective Students
#
#
# Admitted Students (Full-Time)
#
#
# New EMP Students
#
#
# Current Students
#
#
# Faculty and Staff
#
#
# Alumni
#
#
# Media
#
#
#
#
# Support Harris
#
#
#
# Ways to Give
#
#
# Harris Society
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sort
#
#
#
#
#
#
#
#
# Older first
#
#
#
# Most recent
#
#
#
# Less relevant
#
#
#
# Most relevant
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Breadcrumbs
#
# Breadcrumb
#
#
# Home
#
#
# Academics
#
#
# Degrees
#
#
#                   Master of Public Policy (MPP)
#
#
#
#
#
#
#
#
#
#
#
# Master of Public Policy (MPP)
#
#
#
# A two-year program for students interested in developing the analytical skills needed to take on today's pressing policy challenges.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# A two-year program for students interested in developing the analytical skills needed to take on today's pressing policy challenges.
#
#
#
#
# Back to Degrees
#
#
#
#
#
#
# Office of Admissions
#
#
#
#
# Email harrisadmissions@uchicago.edu
#
# 773.702.8401
#
#
#
#
#
#
#
# Across the public and private sectors, a new generation of data-minded leaders is needed to bring fresh thinking and different approaches to the world's most pressing policy challenges.
# The two-year MPP is a professional degree program designed to develop leaders who put evidence first. In course work, you'll build critical thinking and analytical skills in the core curriculum that teach you to make data-driven decisions now and throughout your career. Through applied experiences in Chicago and beyond, you’ll meet face-to-face with professionals in the field to analyze urgent policy problems and design solutions that work, using the latest science and technology.
# The core curriculum draws on a variety of disciplines and fields, including economics, sociology, political science, statistics, econometrics, political economy, organizational theory, and program evaluation, an ideal fit for students seeking a multidisciplinary approach to the study of public policy.
#
#  Read the Master of Public Policy Brochure (PDF, 2.5MB)
#
# Program Details
#
#
#
#
# Curriculum
#
# 18 graduate-level courses (1800 units of credit) with at least 12 Public Policy (PPHA) courses
#
#
# 6 core courses that provide a foundation in critical analysis, reflecting Harris's belief that mastering quantitative and analytical skills prepares students to be effective public policy leaders
#
# PPHA 30800 Analytical Politics I: Strategic Foundations or PPHA 41501 - PhD Game Theory (instructor approval required).
#
#
# PPHA 31610 Analytical Politics II: Political Institutions
#
#
# Statistics Sequence I. Choose one of the following:
#
# PPHA 31002 Statistics for Data Analysis I
#
# PPHA 31202 Advanced Statistics for Data Analysis I
#
# Any course in the PhD econometrics sequence (instructor approval required): PPHA 42000 or PPHA 42100, or PPHA 42200
#
#
#
# Statistics Sequence II. Choose one of the following:
# PPHA 31102 Statistics for Data Analysis II: Regressions
# PPHA 31302 Advanced Statistics for Data Analysis II
# Any course in the PhD econometrics sequence (instructor approval required): PPHA 42000 or PPHA 42100, or PPHA 42200
#
#
# Microeconomics Sequence I. Choose from the following:
#
#
#
# PPHA 32300 Principles of Microeconomics and Public Policy I
#
#
# PPHA 32310 Advanced Microeconomics for Public Policy I
#
#
# PPHA 44100 Principles of Microeconomics and Public Policy I (PhD sequence - instructor approval required)
#
#
#
# Microeconomics Sequence II. Choose from the following:
# PPHA 32400 Principles of Microeconomics and Public Policy II
# PPHA 32410 Advanced Microeconomics for Public Policy II
# PPHA 44200 Principles of Microeconomics and Public Policy II (PhD sequence - instructor approval required)
#
#
#
# Elective Options
#
# MPP students can explore special academic interests and fields as well as participate in internships and independent research complementing required course work.
#
#
# Students may choose to focus on an area of public policy, register for courses in departments and schools across the University, and take advantage of experiential opportunities to apply what they learn in the classroom to real-world problems.
#
#
#
#
#
#
# Other Requirements
#
# A cumulative GPA of 2.7 for all courses, based on a 4.0 scale
#
#
# A grade of C- or better for the 6 core courses
#
#
# Completion of the math requirement (support available)
#
# Pass algebra exam
#
#
# Pass calculus exam
#
#
# Completion of an applied experience requirement (more information)
#
# No more than 2 reading/research, independent study, or internship courses
#
#
# No more than 2 courses taken Pass/Fail (core courses cannot be taken pass/fail)
#
#
# Courses with grades of F, I, W, or with no reported grade do not apply toward the 18-course requirement for the program.
#
#
#
#
#
# Sample Schedule
# Year 1
# Autumn
# Microeconomics I (PPHA 32300)
# 	Option to take advanced PPHA 32310 or PhD level PPHA 44100
#
# Statistics for Data Analysis I (PPHA 31002)
# 	Option to take advanced PPHA 31202 or PhD level STAT 24400
#
# Analytical Politics I: Strategic Foundations (PPHA 30800) pr PhD Game Theory (PPHA 41501)
# Winter
# Microeconomics II (PPHA 32400)
# 	Option to take advanced PPHA 32410 or PhD level PPHA 44200
#
# Statistics for Data Analysis II: Regressions (PPHA 31102)
# 	Option to take advanced PPHA 31302, PhD level STAT 24400, or PhD level PPHA 42000
#
# Analytical Politics II: Political Institutions (PPHA 31610)
# Spring
# Elective
# Elective
# Elective
#
#
#
#
# Testimonials
# “Having attained a master’s of public policy, I have frameworks and tools that I use to formulate responses to complex issues in a deeper and more thoughtful way. The graduate degree in public policy offers an opportunity to step outside of narrow disciplines and learn from and amongst a diverse group of incredibly bright and talented people. I grew significantly as an individual through the friendships I developed and perspectives I gained from my peers. I now have a network across geographies of colleagues in a variety of professional disciplines that I utilize to stay connected to global issues and apply to my personal and professional pursuits.”
# —Eric Tawney (MPP'14), Investment Analyst at BlackRock
# “My Harris education helps me connect the dots and construct a more comprehensive view of how the Central Bank should produce its policy, including how to maintain low inflation and a stable exchange rate on a national scale. I am, ultimately, impacting my country’s economic policy by bridging the gap between academic research and policy practice.”
# —Andi Widianto (MPP'11), Economic Analyst at the Central Bank of Indonesia
# “I think the biggest difference between an economics degree and one in public policy is that those of us with public policy backgrounds better understand the political aspect, the incentives of various stakeholders, and how that impacts policy design and implementation. A lot of policies fail because of competing interests. The advantage that Harris graduates have is that we understand those incentives and interests. We know that it’s about more than just the economic and financial pieces. That informs our work and ultimately matters a lot.”
# —Oliver Azuara Herrera (MPP'02, PhD'11), Economics Officer at the Inter-American Development Bank
# “One thing Harris does is give you a really flexible toolkit that can be used in a lot of different ways in the policy arena.”
# —Elizabeth Kneebone (MPP'03 and recipient of the 2016 Harris Alumni Rising Star Award), Brookings Institution's Metropolitan Policy Program Fellow
# “On a day-to-day basis—in Chicago, in my district, in committee, on the floor, analyzing policy—the skill set I got at Harris is what I use the most.”
# —Mike Quigley (AM'85), US Representative for the 5th District of Illinois
#
#
#
#
#
#
#
#
#
#
#       Alumni profile
#
#
# Questions for Hilarie Koplow-McAdams, AM'87
#
#
#
#       The New Relic executive reflects on disruptive innovation and the need for more women leaders in Silicon Valley.
#
#
# Read more
#
#
#
#
# FAQs
#
#
#
#
#
# What can I do with a policy degree?
#
#
#
# What can I do with a policy degree?
# Since a public policy degree provides a set of research, analytical, communication, and management skills that are transferable across sectors and issue areas, graduates have flexibility in choosing their career paths.
# Public policy graduates often move back and forth between the public, private, and nonprofit sectors, or between international and US-based work. Harris graduates are highly sought-after specifically for their strategic skills, and many have gone on to be social entrepreneurs. Employers look for graduates to help understand and communicate complex data and information in a way that clearly and concisely supports effective decision-making. In the nonprofit sector, the analytical and program evaluation techniques learned can be useful in demonstrating the impact of an organization's programs, which can be useful for funding, governmental relations, and lobbying efforts.
# A public policy degree can also be beneficial in industries such as energy, health care, finance, transportation, telecommunications, education, or other heavily regulated industries that are impacted by laws or policy outcomes or have a dependency on lobbying and political influence. An understanding of policy can help professionals in those industries as they advance in their careers.
#
#
#
#
#
#
# I do not have a quantitative background. Can I handle the demanding coursework at Harris?
#
#
#
# I do not have a quantitative background. Can I handle the demanding coursework at Harris?
# Roughly one-third of our full-time students consider themselves as not having a strong quantitative background prior to applying to and enrolling at Harris. Many demonstrated their capability by scoring well on the GRE or taking supplemental quantitative courses prior to coming to Harris. We have all the resources necessary to ensure that enrolling students will excel in our core curriculum.
#
#
#
#
#
#
# Do you accept GMAT or LSAT in lieu of the GRE?
#
#
#
# Do you accept GMAT or LSAT in lieu of the GRE?
# For admissions to full-time programs, we will accept the GRE or the GMAT score. For those applicants who are currently enrolled in a joint-degree program with the Law School, we will consider your LSAT scores. (Note: Test scores are not required for the Evening Master's Program.)
#
#
#
#
#
#
#
# International Development
#
#
#
# I am interested in international development. Can I take classes in this area in this program?
# If you are interested in international development, we recommend exploring the Pearson Institute International Policy and Development (IPD) Certificate.
# The IPD is designed to prepare students for careers in government, non-governmental organizations, international organizations, or multinational corporations. The certificate’s curated list of electives is designed to allow students to explore multiple academic approaches to understanding development, including from economics, political science, statistics, and psychology.Learn more here.
#
#
#
#
#
#
#
#
#
# Apply Now - Make a Difference Today
#
#
#
# Start making a difference today.
#
# Request Info
# Apply Now
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Faculty Spotlight
#
#
# Ethan Bueno de Mesquita
#
# Sydney Stein Professor and Deputy Dean
#
#
#         Ethan Bueno de Mesquita, AB'96, is an applied game theorist whose research focuses on political violence—especially terrorism, insurgency, and rebellion—and on democratic accountability.
#
#
# Read more
#
#
#
#
#
#
# Recent News
#
#
#
#
# Study Shows Signs Pointing to a Peaceful Afghanistan Transition as US Withdraws May Be Misleading
#
#
#
#
# Mon., May 17, 2021
#
#
#
#
#
#
# Informing Presidential Decision-Making: A View from the Council of Economic Advisers
#
#
#
#
# Fri., May 14, 2021
#
#
#
#
#
# More news
#
#
#
#
# Upcoming Events
#
#
#
#
#
# Mentor Send-Off
#
#
#
#
#
# Mon., May 17, 2021 | 6:00 PM
#
#
#
#
# Virtual Program
# via Zoom, IL 60637
# United States
#
#
#
#
#
#
# Harris Insights: Q&A with Alumni
#
#
#
#
#
# Tue., May 18, 2021 | 5:30 PM
#
#
#
#
# A link will be sent to registered guests
# Chicago, IL 60637
# United States
#
#
#
#
# More events
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# You might also be interested in...
#
#
#
#
#
#
#
#
#
#
#
#
#
# May 20, 2021
#
#
#
#
# Bay Area Networking Event
#
#
#
# Read more
#
#
#
#
#
#
#
#
#
#
#
# May 11, 2021
#
#
#
# Student Profile: Josephine Lando, MPP Class of 2023
#
#
#
# Read more
#
#
#
#
#
#
#
#
#
#
#
# May 07, 2021
#
#
#
# Student Profile: Victor Hinardi, MPP Class of 2023 and 2020 Data and Policy Summer Scholar
#
#
#
# Read more
#
#
#
#
#
#
#
#
#
#
#
# May 04, 2021
#
#
#
# Student Profile: Jeremy Xu, MPP Class of 2023
#
#
#
# Read more
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Prospective Students
#
#
#
# How to Apply
#
#
# Why Public Policy
#
#
# Financial Aid
#
#
# Events
#
#
#
#
# Current Students
#
#
#
# Academic Advising & Support
#
#
# Financial Aid for Students
#
#
# Courses
#
#
# Course Evaluations
#
#
# Find a Job or Internship
#
#
# Disability Resources
#
#
#
#
# Faculty & Staff
#
#
#
# Room Reservations
#
#
# Academic Calendar
#
#
# Faculty Resources
#
#
# Faculty Access
#
#
# Human Resources
#
#
#
#
# Alumni
#
#
#
# News and Events
#
#
# Alumni Directory
#
#
# Get Involved
#
#
# Donate Now
#
#
#
#
#
#
#
#
#
#
# Footer menu
#
#
# The University of Chicago
#
#
# Apply
#
#
# Careers at Harris
#
#
# Courses
#
#
# Directions
#
#
# Privacy Notice
#
#
#
#
# Connect with Us
#
#
# Facebook
#
#
# Twitter
#
#
# LinkedIn
#
#
# Youtube
#
#
#
#
#
# Questions?
# Contact Us
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Utility
#
#
# Search
#
#
# Log in
#
#
# Directory
#
#
# Hire Harris
#
#
#
# Find Talent
#
#
# Find Work
#
#
#
#
# Info For
#
#
#
# Prospective Students
#
#
# Admitted Students (Full-Time)
#
#
# New EMP Students
#
#
# Current Students
#
#
# Faculty and Staff
#
#
# Alumni
#
#
# Media
#
#
#
#
# Support Harris
#
#
#
# Ways to Give
#
#
# Harris Society
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sort
#
#
#
#
#
#
#
#
# Older first
#
#
#
# Most recent
#
#
#
# Less relevant
#
#
#
# Most relevant
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Utility
#
#
# Search
#
#
# Log in
#
#
# Directory
#
#
# Hire Harris
#
#
#
# Find Talent
#
#
# Find Work
#
#
#
#
# Info For
#
#
#
# Prospective Students
#
#
# Admitted Students (Full-Time)
#
#
# New EMP Students
#
#
# Current Students
#
#
# Faculty and Staff
#
#
# Alumni
#
#
# Media
#
#
#
#
# Support Harris
#
#
#
# Ways to Give
#
#
# Harris Society
#
#
#
#
#
#
#
#
#
# Utility
#
#
# Search
#
#
# Log in
#
#
# Directory
#
#
# Hire Harris
#
#
#
# Find Talent
#
#
# Find Work
#
#
#
#
# Info For
#
#
#
# Prospective Students
#
#
# Admitted Students (Full-Time)
#
#
# New EMP Students
#
#
# Current Students
#
#
# Faculty and Staff
#
#
# Alumni
#
#
# Media
#
#
#
#
# Support Harris
#
#
#
# Ways to Give
#
#
# Harris Society
#
#
#
#
#
#
#
#
#
# Find Talent
#
#
# Find Work
#
#
#
#
#
#
# Prospective Students
#
#
# Admitted Students (Full-Time)
#
#
# New EMP Students
#
#
# Current Students
#
#
# Faculty and Staff
#
#
# Alumni
#
#
# Media
#
#
#
#
#
#
# Ways to Give
#
#
# Harris Society
#
#
#
#
#
#
#
#
#
#
#
# Sort
#
#
#
#
#
#
#
#
# Older first
#
#
#
# Most recent
#
#
#
# Less relevant
#
#
#
# Most relevant
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sort
#
#
#
#
#
#
#
#
# Older first
#
#
#
# Most recent
#
#
#
# Less relevant
#
#
#
# Most relevant
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sort
#
#
#
#
#
#
#
#
# Older first
#
#
#
# Most recent
#
#
#
# Less relevant
#
#
#
# Most relevant
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Older first
#
#
#
# Most recent
#
#
#
# Less relevant
#
#
#
# Most relevant
#
#
#
#
#
#
#
# Older first
#
#
#
# Most recent
#
#
#
# Less relevant
#
#
#
# Most relevant
#
#
#
#
#
#
# Older first
#
#
#
# Most recent
#
#
#
# Less relevant
#
#
#
# Most relevant
#
#
#
#
# Older first
#
#
#
# Most recent
#
#
#
# Less relevant
#
#
#
# Most relevant
#
#
#
#
#
#
# Page 1
#
# The University of Chicago Harris School of Public Policy
#
#
#
#
#
#
# AboutConsidering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.Who We AreConsidering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.Our PrinciplesHarris By The NumbersCareer Outcomes ReportThe Keller CenterConsidering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.The Future of PolicyYour ImpactDesign & SustainabilityPress RoomLeadershipConsidering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.Meet Our DeanDean's OfficeHarris CouncilAlumni CouncilDiversity & Inclusion Advisory BoardHistoryConsidering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.History of HarrisLegacy of Irving B. HarrisDiversity & InclusionConsidering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.Our CommitmentRoadmap & ProgressD&I CommunityResourcesNews & EventsAcademicsConsidering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.DegreesConsidering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.Master of Public Policy (MPP)Evening Master’s ProgramMS in Computational Analysis and Public PolicyMA in Public Policy with Certificate in Research MethodsMA in Public PolicyMA in International Development and PolicyPhDNon-Degree ProgramsConsidering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.Credential ProgramsExecutive EducationCivic Leadership AcademyDesign Your PathConsidering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.CoursesCore CurriculumPractical ExperienceCertificatesPolicy AreasExpert GuideDegree ComparisonWorkshopsAcademic CalendarFaculty DirectoryUndergraduate ProgramConsidering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.OverviewThesisStudentsJoint DegreesTeamStudy Abroad in BarcelonaAdmissionsConsidering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.Why Public Policy?Applying to HarrisConsidering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.UChicago College Graduating ClassInternational StudentsFAQAdmissions ResourcesHarris Scholars ProgramRequirements & DeadlinesMeet with HarrisConsidering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial a ...
#
#
#
#
#
#
# Utility
#
#
# Search
#
#
# Log in
#
#
# Directory
#
#
# Hire Harris
#
#
#
# Find Talent
#
#
# Find Work
#
#
#
#
# Info For
#
#
#
# Prospective Students
#
#
# Admitted Students (Full-Time)
#
#
# New EMP Students
#
#
# Current Students
#
#
# Faculty and Staff
#
#
# Alumni
#
#
# Media
#
#
#
#
# Support Harris
#
#
#
# Ways to Give
#
#
# Harris Society
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sort
#
#
#
#
#
#
#
#
# Older first
#
#
#
# Most recent
#
#
#
# Less relevant
#
#
#
# Most relevant
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Page 1
#
# The University of Chicago Harris School of Public Policy
#
#
#
#
# AboutConsidering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.Who We AreConsidering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.Our PrinciplesHarris By The NumbersCareer Outcomes ReportThe Keller CenterConsidering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.The Future of PolicyYour ImpactDesign & SustainabilityPress RoomLeadershipConsidering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.Meet Our DeanDean's OfficeHarris CouncilAlumni CouncilDiversity & Inclusion Advisory BoardHistoryConsidering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.History of HarrisLegacy of Irving B. HarrisDiversity & InclusionConsidering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.Our CommitmentRoadmap & ProgressD&I CommunityResourcesNews & EventsAcademicsConsidering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.DegreesConsidering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.Master of Public Policy (MPP)Evening Master’s ProgramMS in Computational Analysis and Public PolicyMA in Public Policy with Certificate in Research MethodsMA in Public PolicyMA in International Development and PolicyPhDNon-Degree ProgramsConsidering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.Credential ProgramsExecutive EducationCivic Leadership AcademyDesign Your PathConsidering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.CoursesCore CurriculumPractical ExperienceCertificatesPolicy AreasExpert GuideDegree ComparisonWorkshopsAcademic CalendarFaculty DirectoryUndergraduate ProgramConsidering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.OverviewThesisStudentsJoint DegreesTeamStudy Abroad in BarcelonaAdmissionsConsidering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.Why Public Policy?Applying to HarrisConsidering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.UChicago College Graduating ClassInternational StudentsFAQAdmissions ResourcesHarris Scholars ProgramRequirements & DeadlinesMeet with HarrisConsidering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial a ...
#
#
#
#
#
#
# Utility
#
#
# Search
#
#
# Log in
#
#
# Directory
#
#
# Hire Harris
#
#
#
# Find Talent
#
#
# Find Work
#
#
#
#
# Info For
#
#
#
# Prospective Students
#
#
# Admitted Students (Full-Time)
#
#
# New EMP Students
#
#
# Current Students
#
#
# Faculty and Staff
#
#
# Alumni
#
#
# Media
#
#
#
#
# Support Harris
#
#
#
# Ways to Give
#
#
# Harris Society
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sort
#
#
#
#
#
#
#
#
# Older first
#
#
#
# Most recent
#
#
#
# Less relevant
#
#
#
# Most relevant
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# AboutConsidering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.Who We AreConsidering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.Our PrinciplesHarris By The NumbersCareer Outcomes ReportThe Keller CenterConsidering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.The Future of PolicyYour ImpactDesign & SustainabilityPress RoomLeadershipConsidering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.Meet Our DeanDean's OfficeHarris CouncilAlumni CouncilDiversity & Inclusion Advisory BoardHistoryConsidering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.History of HarrisLegacy of Irving B. HarrisDiversity & InclusionConsidering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.Our CommitmentRoadmap & ProgressD&I CommunityResourcesNews & EventsAcademicsConsidering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.DegreesConsidering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.Master of Public Policy (MPP)Evening Master’s ProgramMS in Computational Analysis and Public PolicyMA in Public Policy with Certificate in Research MethodsMA in Public PolicyMA in International Development and PolicyPhDNon-Degree ProgramsConsidering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.Credential ProgramsExecutive EducationCivic Leadership AcademyDesign Your PathConsidering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.CoursesCore CurriculumPractical ExperienceCertificatesPolicy AreasExpert GuideDegree ComparisonWorkshopsAcademic CalendarFaculty DirectoryUndergraduate ProgramConsidering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.OverviewThesisStudentsJoint DegreesTeamStudy Abroad in BarcelonaAdmissionsConsidering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.Why Public Policy?Applying to HarrisConsidering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.UChicago College Graduating ClassInternational StudentsFAQAdmissions ResourcesHarris Scholars ProgramRequirements & DeadlinesMeet with HarrisConsidering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial a ...
#
#
# Considering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.
# Considering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.
# Get Started
# Get Started
# Considering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.
# Considering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.
# Get Started
# Get Started
# Considering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.
# Considering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.
# Get Started
# Get Started
# Considering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.
# Considering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.
# Get Started
# Get Started
# Considering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.
# Considering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.
# Get Started
# Get Started
# Considering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.
# Considering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.
# Get Started
# Get Started
# Considering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.
# Considering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.
# Get Started
# Get Started
# Considering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.
# Considering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.
# Get Started
# Get Started
# Considering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.
# Considering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.
# Get Started
# Get Started
# Considering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.
# Considering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.
# Get Started
# Get Started
# Considering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.
# Considering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.
# Get Started
# Get Started
# Considering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.
# Considering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.
# Get Started
# Get Started
# Considering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.
# Considering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.
# Get Started
# Get Started
# Considering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.
# Considering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.
# Get Started
# Get Started
# Considering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.
# Considering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.
# Get Started
# Get Started
# Considering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.
# Considering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.
# Get Started
# Get Started
# Considering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.
# Considering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.
# Get Started
# Get Started
# Considering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.
# Considering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.
# Get Started
# Get Started
# Considering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.
# Considering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.
# Get Started
# Get Started
# Considering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.
# Considering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.
# Get Started
# Get Started
# Considering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.
# Considering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.
# Get Started
# Get Started
# Considering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.
# Considering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.
# Get Started
# Get Started
# Considering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.
# Considering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.
# Get Started
# Get Started
# Considering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.
# Considering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.
# Get Started
# Get Started
# Considering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.
# Considering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.
# Get Started
# Get Started
# Considering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.
# Considering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.
# Get Started
# Get Started
# Considering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.
# Considering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.
# Get Started
# Get Started
# Considering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.
# Considering Applying?Get a jump start now by creating an account with our simple online tool.Get StartedStill have questions? Check out Admissions for details on requirements, deadlines, and financial aid.
# Get Started
# Get Started
#
#
#
#
# Utility
#
#
# Search
#
#
# Log in
#
#
# Directory
#
#
# Hire Harris
#
#
#
# Find Talent
#
#
# Find Work
#
#
#
#
# Info For
#
#
#
# Prospective Students
#
#
# Admitted Students (Full-Time)
#
#
# New EMP Students
#
#
# Current Students
#
#
# Faculty and Staff
#
#
# Alumni
#
#
# Media
#
#
#
#
# Support Harris
#
#
#
# Ways to Give
#
#
# Harris Society
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sort
#
#
#
#
#
#
#
#
# Older first
#
#
#
# Most recent
#
#
#
# Less relevant
#
#
#
# Most relevant
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Utility
#
#
# Search
#
#
# Log in
#
#
# Directory
#
#
# Hire Harris
#
#
#
# Find Talent
#
#
# Find Work
#
#
#
#
# Info For
#
#
#
# Prospective Students
#
#
# Admitted Students (Full-Time)
#
#
# New EMP Students
#
#
# Current Students
#
#
# Faculty and Staff
#
#
# Alumni
#
#
# Media
#
#
#
#
# Support Harris
#
#
#
# Ways to Give
#
#
# Harris Society
#
#
#
#
#
#
#
#
#
# Utility
#
#
# Search
#
#
# Log in
#
#
# Directory
#
#
# Hire Harris
#
#
#
# Find Talent
#
#
# Find Work
#
#
#
#
# Info For
#
#
#
# Prospective Students
#
#
# Admitted Students (Full-Time)
#
#
# New EMP Students
#
#
# Current Students
#
#
# Faculty and Staff
#
#
# Alumni
#
#
# Media
#
#
#
#
# Support Harris
#
#
#
# Ways to Give
#
#
# Harris Society
#
#
#
#
#
#
#
#
#
# Find Talent
#
#
# Find Work
#
#
#
#
#
#
# Prospective Students
#
#
# Admitted Students (Full-Time)
#
#
# New EMP Students
#
#
# Current Students
#
#
# Faculty and Staff
#
#
# Alumni
#
#
# Media
#
#
#
#
#
#
# Ways to Give
#
#
# Harris Society
#
#
#
#
#
#
#
#
#
#
#
# Sort
#
#
#
#
#
#
#
#
# Older first
#
#
#
# Most recent
#
#
#
# Less relevant
#
#
#
# Most relevant
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sort
#
#
#
#
#
#
#
#
# Older first
#
#
#
# Most recent
#
#
#
# Less relevant
#
#
#
# Most relevant
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sort
#
#
#
#
#
#
#
#
# Older first
#
#
#
# Most recent
#
#
#
# Less relevant
#
#
#
# Most relevant
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Older first
#
#
#
# Most recent
#
#
#
# Less relevant
#
#
#
# Most relevant
#
#
#
#
#
#
#
# Older first
#
#
#
# Most recent
#
#
#
# Less relevant
#
#
#
# Most relevant
#
#
#
#
#
#
# Older first
#
#
#
# Most recent
#
#
#
# Less relevant
#
#
#
# Most relevant
#
#
#
#
# Older first
#
#
#
# Most recent
#
#
#
# Less relevant
#
#
#
# Most relevant
#
#
#
#
#
#
#
#
#
#
#
#
# Breadcrumbs
#
# Breadcrumb
#
#
# Home
#
#
# Academics
#
#
# Degrees
#
#
#                   Master of Public Policy (MPP)
#
#
#
#
#
#
#
#
#
#
#
# Master of Public Policy (MPP)
#
#
#
# A two-year program for students interested in developing the analytical skills needed to take on today's pressing policy challenges.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# A two-year program for students interested in developing the analytical skills needed to take on today's pressing policy challenges.
#
#
#
#
# Back to Degrees
#
#
#
#
#
#
# Office of Admissions
#
#
#
#
# Email harrisadmissions@uchicago.edu
#
# 773.702.8401
#
#
#
#
#
#
#
# Across the public and private sectors, a new generation of data-minded leaders is needed to bring fresh thinking and different approaches to the world's most pressing policy challenges.
# The two-year MPP is a professional degree program designed to develop leaders who put evidence first. In course work, you'll build critical thinking and analytical skills in the core curriculum that teach you to make data-driven decisions now and throughout your career. Through applied experiences in Chicago and beyond, you’ll meet face-to-face with professionals in the field to analyze urgent policy problems and design solutions that work, using the latest science and technology.
# The core curriculum draws on a variety of disciplines and fields, including economics, sociology, political science, statistics, econometrics, political economy, organizational theory, and program evaluation, an ideal fit for students seeking a multidisciplinary approach to the study of public policy.
#
#  Read the Master of Public Policy Brochure (PDF, 2.5MB)
#
# Program Details
#
#
#
#
# Curriculum
#
# 18 graduate-level courses (1800 units of credit) with at least 12 Public Policy (PPHA) courses
#
#
# 6 core courses that provide a foundation in critical analysis, reflecting Harris's belief that mastering quantitative and analytical skills prepares students to be effective public policy leaders
#
# PPHA 30800 Analytical Politics I: Strategic Foundations or PPHA 41501 - PhD Game Theory (instructor approval required).
#
#
# PPHA 31610 Analytical Politics II: Political Institutions
# ...
# A public policy degree can also be beneficial in industries such as energy, health care, finance, transportation, telecommunications, education, or other heavily regulated industries that are impacted by laws or policy outcomes or have a dependency on lobbying and political influence. An understanding of policy can help professionals in those industries as they advance in their careers.
#
#
#
# I do not have a quantitative background. Can I handle the demanding coursework at Harris?
#
#
#
# I do not have a quantitative background. Can I handle the demanding coursework at Harris?
# Roughly one-third of our full-time students consider themselves as not having a strong quantitative background prior to applying to and enrolling at Harris. Many demonstrated their capability by scoring well on the GRE or taking supplemental quantitative courses prior to coming to Harris. We have all the resources necessary to ensure that enrolling students will excel in our core curriculum.
#
#
#
#
# I do not have a quantitative background. Can I handle the demanding coursework at Harris?
# Roughly one-third of our full-time students consider themselves as not having a strong quantitative background prior to applying to and enrolling at Harris. Many demonstrated their capability by scoring well on the GRE or taking supplemental quantitative courses prior to coming to Harris. We have all the resources necessary to ensure that enrolling students will excel in our core curriculum.
#
# I do not have a quantitative background. Can I handle the demanding coursework at Harris?
# Roughly one-third of our full-time students consider themselves as not having a strong quantitative background prior to applying to and enrolling at Harris. Many demonstrated their capability by scoring well on the GRE or taking supplemental quantitative courses prior to coming to Harris. We have all the resources necessary to ensure that enrolling students will excel in our core curriculum.
#
#
#
# Do you accept GMAT or LSAT in lieu of the GRE?
#
#
#
# Do you accept GMAT or LSAT in lieu of the GRE?
# For admissions to full-time programs, we will accept the GRE or the GMAT score. For those applicants who are currently enrolled in a joint-degree program with the Law School, we will consider your LSAT scores. (Note: Test scores are not required for the Evening Master's Program.)
#
#
#
#
#
# Do you accept GMAT or LSAT in lieu of the GRE?
# For admissions to full-time programs, we will accept the GRE or the GMAT score. For those applicants who are currently enrolled in a joint-degree program with the Law School, we will consider your LSAT scores. (Note: Test scores are not required for the Evening Master's Program.)
#
#
# Do you accept GMAT or LSAT in lieu of the GRE?
# For admissions to full-time programs, we will accept the GRE or the GMAT score. For those applicants who are currently enrolled in a joint-degree program with the Law School, we will consider your LSAT scores. (Note: Test scores are not required for the Evening Master's Program.)
#
#
#
#
# International Development
#
#
#
# I am interested in international development. Can I take classes in this area in this program?
# If you are interested in international development, we recommend exploring the Pearson Institute International Policy and Development (IPD) Certificate.
# The IPD is designed to prepare students for careers in government, non-governmental organizations, international organizations, or multinational corporations. The certificate’s curated list of electives is designed to allow students to explore multiple academic approaches to understanding development, including from economics, political science, statistics, and psychology.Learn more here.
#
#
#
#
# I am interested in international development. Can I take classes in this area in this program?
# If you are interested in international development, we recommend exploring the Pearson Institute International Policy and Development (IPD) Certificate.
# The IPD is designed to prepare students for careers in government, non-governmental organizations, international organizations, or multinational corporations. The certificate’s curated list of electives is designed to allow students to explore multiple academic approaches to understanding development, including from economics, political science, statistics, and psychology.Learn more here.
#
# I am interested in international development. Can I take classes in this area in this program?
# If you are interested in international development, we recommend exploring the Pearson Institute International Policy and Development (IPD) Certificate.
# The IPD is designed to prepare students for careers in government, non-governmental organizations, international organizations, or multinational corporations. The certificate’s curated list of electives is designed to allow students to explore multiple academic approaches to understanding development, including from economics, political science, statistics, and psychology.Learn more here.
#
#
#
#
# Apply Now - Make a Difference Today
#
#
#
# Start making a difference today.
#
# Request Info
# Apply Now
#
#
#
#
#
#
#
#
# Apply Now - Make a Difference Today
#
#
#
# Start making a difference today.
#
# Request Info
# Apply Now
#
#
#
#
#
# Start making a difference today.
#
# Request Info
# Apply Now
#
#
# Start making a difference today.
#
# Request Info
# Apply Now
#
# Request Info
# Apply Now
#
#
#
#
#
#
#
#
#
#
# Faculty Spotlight
#
#
# Ethan Bueno de Mesquita
#
# Sydney Stein Professor and Deputy Dean
#
#
#         Ethan Bueno de Mesquita, AB'96, is an applied game theorist whose research focuses on political violence—especially terrorism, insurgency, and rebellion—and on democratic accountability.
#
#
# Read more
#
#
#
#
#
#
# Recent News
#
#
#
#
# Study Shows Signs Pointing to a Peaceful Afghanistan Transition as US Withdraws May Be Misleading
#
#
#
#
# Mon., May 17, 2021
#
#
#
#
#
#
# Informing Presidential Decision-Making: A View from the Council of Economic Advisers
#
#
#
#
# Fri., May 14, 2021
#
#
#
#
#
# More news
#
#
#
#
# Upcoming Events
#
#
#
#
#
# Mentor Send-Off
#
#
#
#
#
# Mon., May 17, 2021 | 6:00 PM
#
#
#
#
# Virtual Program
# via Zoom, IL 60637
# United States
#
#
#
#
#
#
# Harris Insights: Q&A with Alumni
#
#
#
#
#
# Tue., May 18, 2021 | 5:30 PM
#
#
#
#
# A link will be sent to registered guests
# Chicago, IL 60637
# United States
#
#
#
#
# More events
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Faculty Spotlight
#
#
# Ethan Bueno de Mesquita
#
# Sydney Stein Professor and Deputy Dean
#
#
#         Ethan Bueno de Mesquita, AB'96, is an applied game theorist whose research focuses on political violence—especially terrorism, insurgency, and rebellion—and on democratic accountability.
#
#
# Read more
#
#
#
#
#
#
#
#
#
#
#
#
#
# Faculty Spotlight
#
#
# Ethan Bueno de Mesquita
#
# Sydney Stein Professor and Deputy Dean
#
#
#         Ethan Bueno de Mesquita, AB'96, is an applied game theorist whose research focuses on political violence—especially terrorism, insurgency, and rebellion—and on democratic accountability.
#
#
# Read more
#
#
#
#
#
#
#
#
#
#
#
# Faculty Spotlight
#
#
# Ethan Bueno de Mesquita
#
# Sydney Stein Professor and Deputy Dean
#
#
#         Ethan Bueno de Mesquita, AB'96, is an applied game theorist whose research focuses on political violence—especially terrorism, insurgency, and rebellion—and on democratic accountability.
#
#
# Read more
#
#
#
#
#
#
#
#
#
# Faculty Spotlight
#
#
#
#
#
#
#
#
#
#
# Ethan Bueno de Mesquita
#
# Sydney Stein Professor and Deputy Dean
#
#
#         Ethan Bueno de Mesquita, AB'96, is an applied game theorist whose research focuses on political violence—especially terrorism, insurgency, and rebellion—and on democratic accountability.
#
#
# Read more
#
#
# Sydney Stein Professor and Deputy Dean
#
#         Ethan Bueno de Mesquita, AB'96, is an applied game theorist whose research focuses on political violence—especially terrorism, insurgency, and rebellion—and on democratic accountability.
#
#
# Read more
#
#
# Recent News
#
#
#
#
# Study Shows Signs Pointing to a Peaceful Afghanistan Transition as US Withdraws May Be Misleading
#
#
#
#
# Mon., May 17, 2021
#
#
#
#
#
#
# Informing Presidential Decision-Making: A View from the Council of Economic Advisers
#
#
#
#
# Fri., May 14, 2021
#
#
#
#
#
# More news
#
#
#
#
#
#
#
# Study Shows Signs Pointing to a Peaceful Afghanistan Transition as US Withdraws May Be Misleading
#
#
#
#
# Mon., May 17, 2021
#
#
#
#
#
#
# Informing Presidential Decision-Making: A View from the Council of Economic Advisers
#
#
#
#
# Fri., May 14, 2021
#
#
#
#
#
# More news
#
#
#
#
#
#
# Study Shows Signs Pointing to a Peaceful Afghanistan Transition as US Withdraws May Be Misleading
#
#
#
#
# Mon., May 17, 2021
#
#
#
#
#
#
# Informing Presidential Decision-Making: A View from the Council of Economic Advisers
#
#
#
#
# Fri., May 14, 2021
#
#
#
#
#
# More news
#
#
#
#
# Study Shows Signs Pointing to a Peaceful Afghanistan Transition as US Withdraws May Be Misleading
#
#
#
#
# Mon., May 17, 2021
#
#
#
#
#
#
# Informing Presidential Decision-Making: A View from the Council of Economic Advisers
#
#
#
#
# Fri., May 14, 2021
#
#
#
#
#
#
# Study Shows Signs Pointing to a Peaceful Afghanistan Transition as US Withdraws May Be Misleading
#
#
#
#
# Mon., May 17, 2021
#
#
#
# Mon., May 17, 2021
#
#
# Informing Presidential Decision-Making: A View from the Council of Economic Advisers
#
#
#
#
# Fri., May 14, 2021
#
#
#
# Fri., May 14, 2021
#
# More news
#
# Upcoming Events
#
#
#
#
#
# Mentor Send-Off
#
#
#
#
#
# Mon., May 17, 2021 | 6:00 PM
#
#
#
#
# Virtual Program
# via Zoom, IL 60637
# United States
#
#
#
#
#
#
# Harris Insights: Q&A with Alumni
#
#
#
#
#
# Tue., May 18, 2021 | 5:30 PM
#
#
#
#
# A link will be sent to registered guests
# Chicago, IL 60637
# United States
#
#
#
#
# More events
#
#
#
#
#
#
#
#
#
#
# Mentor Send-Off
#
#
#
#
#
# Mon., May 17, 2021 | 6:00 PM
#
#
#
#
# Virtual Program
# via Zoom, IL 60637
# United States
#
#
#
#
#
#
# Harris Insights: Q&A with Alumni
#
#
#
#
#
# Tue., May 18, 2021 | 5:30 PM
#
#
#
#
# A link will be sent to registered guests
# Chicago, IL 60637
# United States
#
#
#
#
# More events
#
#
#
#
#
#
#
#
#
# Mentor Send-Off
#
#
#
#
#
# Mon., May 17, 2021 | 6:00 PM
#
#
#
#
# Virtual Program
# via Zoom, IL 60637
# United States
#
#
#
#
#
#
# Harris Insights: Q&A with Alumni
#
#
#
#
#
# Tue., May 18, 2021 | 5:30 PM
#
#
#
#
# A link will be sent to registered guests
# Chicago, IL 60637
# United States
#
#
#
#
# More events
#
#
#
#
#
#
#
# Mentor Send-Off
#
#
#
#
#
# Mon., May 17, 2021 | 6:00 PM
#
#
#
#
# Virtual Program
# via Zoom, IL 60637
# United States
#
#
#
#
#
#
# Harris Insights: Q&A with Alumni
#
#
#
#
#
# Tue., May 18, 2021 | 5:30 PM
#
#
#
#
# A link will be sent to registered guests
# Chicago, IL 60637
# United States
#
#
#
#
#
#
# Mentor Send-Off
#
#
#
#
#
# Mon., May 17, 2021 | 6:00 PM
#
#
#
#
# Virtual Program
# via Zoom, IL 60637
# United States
#
#
#
#
# Mon., May 17, 2021 | 6:00 PM
#
#
#
# Mon., May 17, 2021 | 6:00 PM
#
#
# Virtual Program
# via Zoom, IL 60637
# United States
#
# Virtual Program
# via Zoom, IL 60637
# United States
#
#
# Harris Insights: Q&A with Alumni
#
#
#
#
#
# Tue., May 18, 2021 | 5:30 PM
#
#
#
#
# A link will be sent to registered guests
# Chicago, IL 60637
# United States
#
#
#
#
# Tue., May 18, 2021 | 5:30 PM
#
#
#
# Tue., May 18, 2021 | 5:30 PM
#
#
# A link will be sent to registered guests
# Chicago, IL 60637
# United States
#
# A link will be sent to registered guests
# Chicago, IL 60637
# United States
# More events
#
#
#
#
#
# You might also be interested in...
#
#
#
#
#
#
#
#
#
#
#
#
#
# May 20, 2021
#
#
#
#
# Bay Area Networking Event
#
#
#
# Read more
#
#
#
#
#
#
#
#
#
#
#
# May 11, 2021
#
#
#
# Student Profile: Josephine Lando, MPP Class of 2023
#
#
#
# Read more
#
#
#
#
#
#
#
#
#
#
#
# May 07, 2021
#
#
#
# Student Profile: Victor Hinardi, MPP Class of 2023 and 2020 Data and Policy Summer Scholar
#
#
#
# Read more
#
#
#
#
#
#
#
#
#
#
#
# May 04, 2021
#
#
#
# Student Profile: Jeremy Xu, MPP Class of 2023
#
#
#
# Read more
#
#
#
#
#
#
#
#
#
#
#
# You might also be interested in...
#
#
#
#
#
#
#
#
#
#
#
#
#
# May 20, 2021
#
#
#
#
# Bay Area Networking Event
#
#
#
# Read more
#
#
#
#
#
#
#
#
#
#
#
# May 11, 2021
#
#
#
# Student Profile: Josephine Lando, MPP Class of 2023
#
#
#
# Read more
#
#
#
#
#
#
#
#
#
#
#
# May 07, 2021
#
#
#
# Student Profile: Victor Hinardi, MPP Class of 2023 and 2020 Data and Policy Summer Scholar
#
#
#
# Read more
#
#
#
#
#
#
#
#
#
#
#
# May 04, 2021
#
#
#
# Student Profile: Jeremy Xu, MPP Class of 2023
#
#
#
# Read more
#
#
#
#
#
#
#
#
#
# You might also be interested in...
#
#
#
#
#
#
#
#
#
#
#
#
#
# May 20, 2021
#
#
#
#
# Bay Area Networking Event
#
#
#
# Read more
#
#
#
#
#
#
#
#
#
#
#
# May 11, 2021
#
#
#
# Student Profile: Josephine Lando, MPP Class of 2023
#
#
#
# Read more
#
#
#
#
#
#
#
#
#
#
#
# May 07, 2021
#
#
#
# Student Profile: Victor Hinardi, MPP Class of 2023 and 2020 Data and Policy Summer Scholar
#
#
#
# Read more
#
#
#
#
#
#
#
#
#
#
#
# May 04, 2021
#
#
#
# Student Profile: Jeremy Xu, MPP Class of 2023
#
#
#
# Read more
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# May 20, 2021
#
#
#
#
# Bay Area Networking Event
#
#
#
# Read more
#
#
#
#
#
#
#
#
#
#
#
# May 11, 2021
#
#
#
# Student Profile: Josephine Lando, MPP Class of 2023
#
#
#
# Read more
#
#
#
#
#
#
#
#
#
#
#
# May 07, 2021
#
#
#
# Student Profile: Victor Hinardi, MPP Class of 2023 and 2020 Data and Policy Summer Scholar
#
#
#
# Read more
#
#
#
#
#
#
#
#
#
#
#
# May 04, 2021
#
#
#
# Student Profile: Jeremy Xu, MPP Class of 2023
#
#
#
# Read more
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# May 20, 2021
#
#
#
#
# Bay Area Networking Event
#
#
#
# Read more
#
#
#
#
#
#
#
#
#
#
#
# May 11, 2021
#
#
#
# Student Profile: Josephine Lando, MPP Class of 2023
#
#
#
# Read more
#
#
#
#
#
#
#
#
#
#
#
# May 07, 2021
#
#
#
# Student Profile: Victor Hinardi, MPP Class of 2023 and 2020 Data and Policy Summer Scholar
#
#
#
# Read more
#
#
#
#
#
#
#
#
#
#
#
# May 04, 2021
#
#
#
# Student Profile: Jeremy Xu, MPP Class of 2023
#
#
#
# Read more
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# May 20, 2021
#
#
#
#
# Bay Area Networking Event
#
#
#
# Read more
#
#
#
#
#
#
#
#
#
#
#
# May 11, 2021
#
#
#
# Student Profile: Josephine Lando, MPP Class of 2023
#
#
#
# Read more
#
#
#
#
#
#
#
#
#
#
#
# May 07, 2021
#
#
#
# Student Profile: Victor Hinardi, MPP Class of 2023 and 2020 Data and Policy Summer Scholar
#
#
#
# Read more
#
#
#
#
#
#
#
#
#
#
#
# May 04, 2021
#
#
#
# Student Profile: Jeremy Xu, MPP Class of 2023
#
#
#
# Read more
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# May 20, 2021
#
#
#
#
# Bay Area Networking Event
#
#
#
# Read more
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# May 20, 2021
#
#
#
# May 20, 2021
#
#
# Read more
#
#
#
#
#
#
#
#
#
# May 11, 2021
#
#
#
# Student Profile: Josephine Lando, MPP Class of 2023
#
#
#
# Read more
#
#
#
#
#
#
#
#
#
#
#
# May 11, 2021
#
#
# Read more
#
#
#
#
#
#
#
#
#
# May 07, 2021
#
#
#
# Student Profile: Victor Hinardi, MPP Class of 2023 and 2020 Data and Policy Summer Scholar
#
#
#
# Read more
#
#
#
#
#
#
#
#
#
#
#
# May 07, 2021
#
#
# Read more
#
#
#
#
#
#
#
#
#
# May 04, 2021
#
#
#
# Student Profile: Jeremy Xu, MPP Class of 2023
#
#
#
# Read more
#
#
#
#
#
#
#
#
#
#
#
# May 04, 2021
#
#
# Read more
#
#
#
#
#
#
# Prospective Students
#
#
#
# How to Apply
#
#
# Why Public Policy
#
#
# Financial Aid
#
#
# Events
#
#
#
#
# Current Students
#
#
#
# Academic Advising & Support
#
#
# Financial Aid for Students
#
#
# Courses
#
#
# Course Evaluations
#
#
# Find a Job or Internship
#
#
# Disability Resources
#
#
#
#
# Faculty & Staff
#
#
#
# Room Reservations
#
#
# Academic Calendar
#
#
# Faculty Resources
#
#
# Faculty Access
#
#
# Human Resources
#
#
#
#
# Alumni
#
#
#
# News and Events
#
#
# Alumni Directory
#
#
# Get Involved
#
#
# Donate Now
#
#
#
#
#
#
#
#
#
#
#
# Prospective Students
#
#
#
# How to Apply
#
#
# Why Public Policy
#
#
# Financial Aid
#
#
# Events
#
#
#
#
# Current Students
#
#
#
# Academic Advising & Support
#
#
# Financial Aid for Students
#
#
# Courses
#
#
# Course Evaluations
#
#
# Find a Job or Internship
#
#
# Disability Resources
#
#
#
#
# Faculty & Staff
#
#
#
# Room Reservations
#
#
# Academic Calendar
#
#
# Faculty Resources
#
#
# Faculty Access
#
#
# Human Resources
#
#
#
#
# Alumni
#
#
#
# News and Events
#
#
# Alumni Directory
#
#
# Get Involved
#
#
# Donate Now
#
#
#
#
#
#
#
#
#
# Prospective Students
#
#
#
# How to Apply
#
#
# Why Public Policy
#
#
# Financial Aid
#
#
# Events
#
#
#
#
# Current Students
#
#
#
# Academic Advising & Support
#
#
# Financial Aid for Students
#
#
# Courses
#
#
# Course Evaluations
#
#
# Find a Job or Internship
#
#
# Disability Resources
#
#
#
#
# Faculty & Staff
#
#
#
# Room Reservations
#
#
# Academic Calendar
#
#
# Faculty Resources
#
#
# Faculty Access
#
#
# Human Resources
#
#
#
#
# Alumni
#
#
#
# News and Events
#
#
# Alumni Directory
#
#
# Get Involved
#
#
# Donate Now
#
#
#
#
#
#
#
#
# How to Apply
#
#
# Why Public Policy
#
#
# Financial Aid
#
#
# Events
#
#
#
#
#
#
# Academic Advising & Support
#
#
# Financial Aid for Students
#
#
# Courses
#
#
# Course Evaluations
#
#
# Find a Job or Internship
#
#
# Disability Resources
#
#
#
#
#
#
# Room Reservations
#
#
# Academic Calendar
#
#
# Faculty Resources
#
#
# Faculty Access
#
#
# Human Resources
#
#
#
#
#
#
# News and Events
#
#
# Alumni Directory
#
#
# Get Involved
#
#
# Donate Now
#
#
#
#
#
# Footer menu
#
#
# The University of Chicago
#
#
# Apply
#
#
# Careers at Harris
#
#
# Courses
#
#
# Directions
#
#
# Privacy Notice
#
#
#
#
# Connect with Us
#
#
# Facebook
#
#
# Twitter
#
#
# LinkedIn
#
#
# Youtube
#
#
#
#
#
# Questions?
# Contact Us
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Questions?
# Contact Us
#
#
#
#
# Questions?
# Contact Us
#
#
#
# Questions?
# Contact Us
#
# Contact Us

# %% [markdown]
# ### Useful methods

# %% [markdown]
# 1. soup.select()
#
# BeautifulSoup has a .select() method which uses the SoupSieve package to run a CSS selector against a parsed document and return all the matching elements. Tag has a similar method which runs a CSS selector against the contents of a single tag.
#
# (The SoupSieve integration was added in Beautiful Soup 4.7.0. Earlier versions also have the .select() method, but only the most commonly-used CSS selectors are supported. If you installed Beautiful Soup through pip, SoupSieve was installed at the same time, so you don’t have to do anything extra.)

# %% [markdown]
# 2. soup.get_text()
#
# If you only want the human-readable text inside a document or tag, you can use the get_text() method. It returns all the text in a document or beneath a tag, as a single Unicode string

# %%
#homework7 Q2 target

# %%
bullets
# Out:
# ['18 graduate-level courses (1800 units of credit) with at least 12 Public Policy (PPHA) courses',
#  "6 core courses that providea foundation in critical analysis, reflecting Harris's belief that mastering quantitative and analytical skills prepares students to be effective public policy leaders",
#  'PPHA 30800 Analytical Politics I: Strategic Foundations or PPHA 41501 - PhD Game Theory(instructor approval required).',
#  'PPHA 31610 Analytical Politics II: Political Institutions',
#  'Statistics Sequence I.Choose one of the following:',
#  'PPHA 31002 Statistics for Data Analysis I',
#  'PPHA 31202 Advanced Statistics for Data Analysis I ',
#  'Any course in the PhD econometrics sequence (instructor approval required):PPHA 42000 or PPHA42100, or PPHA 42200',
#  'Statistics Sequence II.Choose one of the following:',
#  'PPHA 31102 Statistics for Data Analysis II:Regressions',
#  'PPHA 31302 Advanced Statistics for Data Analysis II',
#  'Any course in the PhD econometrics sequence (instructor approval required): PPHA 42000 or PPHA42100, or PPHA 42200',
#  'Microeconomics Sequence I. Choose from the following:',
#  'PPHA 32300 Principles of Microeconomics and Public Policy I',
#  'PPHA 32310 Advanced Microeconomics for Public Policy I',
#  'PPHA 44100 Principles of Microeconomics and Public Policy I (PhD sequence -instructor approval required)',
#  'Microeconomics Sequence II. Choose from the following:',
#  'PPHA 32400 Principles of Microeconomics and Public Policy II',
#  'PPHA 32410 Advanced Microeconomics for Public Policy II',
#  'PPHA 44200Principles of Microeconomics and Public Policy II (PhD sequence -instructor approval required)',
#  'Elective Options',
#  'MPP students can explore special academic interests and fieldsas well as participate in internships and independent research complementing required course work.',
#  'Students may choose to focus on an area of public policy, register for courses in departments and schools across the University, and take advantage of experiential opportunities to apply what they learn in theclassroom to real-world problems.']
